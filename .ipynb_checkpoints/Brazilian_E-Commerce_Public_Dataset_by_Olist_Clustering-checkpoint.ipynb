# %% [markdown]
# Name: Osama Sidahmed
#
# Date:20 Oct 2021

# %% [markdown]
# ### Dataset

# %% [markdown]
# This notebook includes my work on the data preparation and data clustering of the Brazilian E-Commerce Public Dataset by Olist version 6 dataset.
#
# The dataset was downloaded from the new [here](https://www.kaggle.com/olistbr/brazilian-ecommerce).
#
# As per the website, this is the **description** of the dataset:
#
# The dataset has information of 100k orders from 2016 to 2018 made at multiple marketplaces in Brazil. Its features allows viewing an order from multiple dimensions: from order status, price, payment and freight performance to customer location, product attributes and finally reviews written by customers. We also released a geolocation dataset that relates Brazilian zip codes to lat/lng coordinates.
# This is real commercial data, it has been anonymised, and references to the companies and partners in the review text have been replaced with the names of Game of Thrones great houses.
#
# Context:
#
# This dataset was generously provided by Olist, the largest department store in Brazilian marketplaces. Olist connects small businesses from all over Brazil to channels without hassle and with a single contract. Those merchants are able to sell their products through the Olist Store and ship them directly to the customers using Olist logistics partners. See more on our website: www.olist.com
# After a customer purchases the product from Olist Store a seller gets notified to fulfill that order. Once the customer receives the product, or the estimated delivery date is due, the customer gets a satisfaction survey by email where he can give a note for the purchase experience and write down some comments.
#
# Attention:
# 1.	An order might have multiple items.
# 2.	Each item might be fulfilled by a distinct seller.
# 3.	All text identifying stores and partners where replaced by the names of Game of Thrones great houses.

# %% [markdown]
# Example of a product listing on a marketplace:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Data Schema
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Objective (Problem Understanding)
# The main objective of this project is to apply various clustering algorithms to find customers with natural similarities.

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# Although the data on this project dictated the problem definition, it is important to mention that the data on its current state is not designed for such analysis before some munging. First off, the data is scattered on different tables requiring merging all tables together before we redefining it at the customer level instead of the order level that it is at initially.

# %% [markdown]
# #### Initial Exploratory Data Analysis

# %%
# Load some libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set preference to show all dataframes columns
pd.set_option('display.max_column', None)
pd.set_option('max_colwidth', None)

# %% [markdown]
# The dataset is composed of 9 csv files. The first step is to load all of the into dataframes.

# %%
df_customers = pd.read_csv("data/olist_customers_dataset.csv", index_col=0)
df_geolocation = pd.read_csv("data/olist_geolocation_dataset.csv", index_col=0)
df_order_items = pd.read_csv("data/olist_order_items_dataset.csv", index_col=0)
df_order_payments = pd.read_csv("data/olist_order_payments_dataset.csv", index_col=0)
df_order_reviews = pd.read_csv("data/olist_order_reviews_dataset.csv", index_col=0)
df_orders = pd.read_csv("data/olist_orders_dataset.csv", index_col=0)
df_products = pd.read_csv("data/olist_products_dataset.csv", index_col=0)
df_sellers = pd.read_csv("data/olist_sellers_dataset.csv", index_col=0)
df_product_category_name_translation = pd.read_csv("data/product_category_name_translation.csv", index_col=0)

# %%
# store the 9 dfs in a dictionary to ease manipulation
df_dict = {'df_customers': df_customers, 'df_geolocation': df_geolocation,'df_order_items': df_order_items,  \
           'df_order_payments': df_order_payments,  'df_order_reviews': df_order_reviews,  'df_orders': df_orders, \
           'df_products': df_products, 'df_sellers': df_sellers,'df_product_category_name_translation': df_product_category_name_translation}


# print a sample of each
for key, value in df_dict.items():
    print(key)
    display(value.sample(3))
    print('--------------------------------------------------------------------------------------------------------------------------')
# Out:
# df_customers
#                                                 customer_unique_id  \
# customer_id
# 214da6d258e415ee782fd14c108be3a2  486a411f40fe3cbdf049451bd713d2be
# 961f898c34ac62fa12fd8249612de4e6  170f73c3d7e5b15778aa114625ef0e8e
# 11ab6d2231a0af5746b44a810b62b0a1  a6cc6e3138236cf4795743335351594c
#
#                                   customer_zip_code_prefix   customer_city  \
# customer_id
# 214da6d258e415ee782fd14c108be3a2                     35380        urucania
# 961f898c34ac62fa12fd8249612de4e6                      1242       sao paulo
# 11ab6d2231a0af5746b44a810b62b0a1                     73700  padre bernardo
#
#                                  customer_state
# customer_id
# 214da6d258e415ee782fd14c108be3a2             MG
# 961f898c34ac62fa12fd8249612de4e6             SP
# 11ab6d2231a0af5746b44a810b62b0a1             GO
# --------------------------------------------------------------------------------------------------------------------------
# df_geolocation
#                              geolocation_lat  geolocation_lng  \
# geolocation_zip_code_prefix
# 65390                              -3.965071       -45.662828
# 20941                             -22.899514       -43.218126
# 98740                             -28.517963       -53.989466
#
#                             geolocation_city geolocation_state
# geolocation_zip_code_prefix
# 65390                            santa luzia                MA
# 20941                         rio de janeiro                RJ
# 98740                        augusto pestana                RS
# --------------------------------------------------------------------------------------------------------------------------
# df_order_items
#                                   order_item_id  \
# order_id
# b1746c7d13f52567b4cd6710249240c9              1
# 8c077233d04d9bca0a5bef45afddf354              1
# 7d00af7c23ec65f8e98e9d7a348130f4              1
#
#                                                         product_id  \
# order_id
# b1746c7d13f52567b4cd6710249240c9  d017a2151d543a9885604dc62a3d9dcc
# 8c077233d04d9bca0a5bef45afddf354  94475071013412139f862c0bd7e3bb37
# 7d00af7c23ec65f8e98e9d7a348130f4  2043cae78c8b731c405c7329a05154b2
#
#                                                          seller_id  \
# order_id
# b1746c7d13f52567b4cd6710249240c9  6560211a19b47992c3666cc44a7e94c0
# 8c077233d04d9bca0a5bef45afddf354  955fee9216a65b617aa5c0531780ce60
# 7d00af7c23ec65f8e98e9d7a348130f4  4830e40640734fc1c52cd21127c341d4
#
#                                   shipping_limit_date  price  freight_value
# order_id
# b1746c7d13f52567b4cd6710249240c9  2017-07-20 14:15:11   49.0           7.78
# 8c077233d04d9bca0a5bef45afddf354  2018-08-07 04:10:24   42.0          15.39
# 7d00af7c23ec65f8e98e9d7a348130f4  2018-05-18 18:16:29   69.0          19.45
# --------------------------------------------------------------------------------------------------------------------------
# df_order_payments
#                                   payment_sequential payment_type  \
# order_id
# 71425ecd58b4f20236e557902a9743f7                   2      voucher
# 4a086aa623133c7141b0c9c6759c79ad                   1  credit_card
# ff69de2237431040b7e8d1fcd79c0a7a                   1  credit_card
#
#                                   payment_installments  payment_value
# order_id
# 71425ecd58b4f20236e557902a9743f7                     1          28.67
# 4a086aa623133c7141b0c9c6759c79ad                     2          74.38
# ff69de2237431040b7e8d1fcd79c0a7a                    10         117.76
# --------------------------------------------------------------------------------------------------------------------------
# df_order_reviews
#                                                           order_id  \
# review_id
# e0eb04c8ab161f96dd15632bcd5d873f  82a71647905d5965a2d4c6e237ad3e61
# 95e2291759afb8251aa7ce538cce9458  cf229e9a3df6543d25bd826262a12a8a
# b5840ffc61a111d760b759fc343f861d  87064d517041a71950b9f0cf6d34b211
#
#                                   review_score review_comment_title  \
# review_id
# e0eb04c8ab161f96dd15632bcd5d873f             3                  NaN
# 95e2291759afb8251aa7ce538cce9458             4                  NaN
# b5840ffc61a111d760b759fc343f861d             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# review_id
# e0eb04c8ab161f96dd15632bcd5d873f                    NaN  2017-08-03 00:00:00
# 95e2291759afb8251aa7ce538cce9458                    NaN  2017-08-15 00:00:00
# b5840ffc61a111d760b759fc343f861d                    NaN  2017-05-14 00:00:00
#
#                                  review_answer_timestamp
# review_id
# e0eb04c8ab161f96dd15632bcd5d873f     2017-08-03 23:51:03
# 95e2291759afb8251aa7ce538cce9458     2017-08-16 08:27:36
# b5840ffc61a111d760b759fc343f861d     2017-05-14 21:31:15
# --------------------------------------------------------------------------------------------------------------------------
# df_orders
#                                                        customer_id  \
# order_id
# 4007c8123697940f0574798a18c6ad29  aafe511008ceeac11be1fdab57f9bd8e
# ef29bdd3a72229e6ea76fb22871eb176  ff83d65f64369c7efaa074eb0a13c433
# 87d003714879bdc9c2adfe35a47268a4  99bfe4238b5b10a3e83b388a471e3568
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 4007c8123697940f0574798a18c6ad29    delivered      2018-05-26 18:50:39
# ef29bdd3a72229e6ea76fb22871eb176    delivered      2018-01-15 22:45:22
# 87d003714879bdc9c2adfe35a47268a4    delivered      2017-12-06 22:33:42
#
#                                     order_approved_at  \
# order_id
# 4007c8123697940f0574798a18c6ad29  2018-05-26 19:10:19
# ef29bdd3a72229e6ea76fb22871eb176  2018-01-15 22:55:25
# 87d003714879bdc9c2adfe35a47268a4  2017-12-08 02:54:32
#
#                                  order_delivered_carrier_date  \
# order_id
# 4007c8123697940f0574798a18c6ad29          2018-05-29 12:47:00
# ef29bdd3a72229e6ea76fb22871eb176          2018-01-18 15:49:11
# 87d003714879bdc9c2adfe35a47268a4          2017-12-11 20:53:37
#
#                                  order_delivered_customer_date  \
# order_id
# 4007c8123697940f0574798a18c6ad29           2018-06-05 20:33:01
# ef29bdd3a72229e6ea76fb22871eb176           2018-01-24 19:49:15
# 87d003714879bdc9c2adfe35a47268a4           2018-01-02 20:29:10
#
#                                  order_estimated_delivery_date
# order_id
# 4007c8123697940f0574798a18c6ad29           2018-07-04 00:00:00
# ef29bdd3a72229e6ea76fb22871eb176           2018-02-09 00:00:00
# 87d003714879bdc9c2adfe35a47268a4           2018-01-09 00:00:00
# --------------------------------------------------------------------------------------------------------------------------
# df_products
#                                  product_category_name  product_name_lenght  \
# product_id
# 77922dd87928c2cf9225946dac2a27a7      moveis_decoracao                 60.0
# f78d57eae3aa976bdfd5f0db33141a79       cama_mesa_banho                 58.0
# d87fc3441d23a38e9921cd2fa603b931       casa_construcao                 55.0
#
#                                   product_description_lenght  \
# product_id
# 77922dd87928c2cf9225946dac2a27a7                       600.0
# f78d57eae3aa976bdfd5f0db33141a79                       204.0
# d87fc3441d23a38e9921cd2fa603b931                       652.0
#
#                                   product_photos_qty  product_weight_g  \
# product_id
# 77922dd87928c2cf9225946dac2a27a7                 1.0             650.0
# f78d57eae3aa976bdfd5f0db33141a79                 1.0            2100.0
# d87fc3441d23a38e9921cd2fa603b931                 1.0            3950.0
#
#                                   product_length_cm  product_height_cm  \
# product_id
# 77922dd87928c2cf9225946dac2a27a7               25.0               25.0
# f78d57eae3aa976bdfd5f0db33141a79               35.0               20.0
# d87fc3441d23a38e9921cd2fa603b931               30.0               35.0
#
#                                   product_width_cm
# product_id
# 77922dd87928c2cf9225946dac2a27a7              25.0
# f78d57eae3aa976bdfd5f0db33141a79              30.0
# d87fc3441d23a38e9921cd2fa603b931              30.0
# --------------------------------------------------------------------------------------------------------------------------
# df_sellers
#                                   seller_zip_code_prefix         seller_city  \
# seller_id
# 7dc8c42cc750eeafea6c85712ffee9bf                    5424           sao paulo
# 609e1a9a6c2539919b8205cf7c4e6ff0                   88359             brusque
# b2f4d63c7203f539a78252565ca32257                   28950  armacao dos buzios
#
#                                  seller_state
# seller_id
# 7dc8c42cc750eeafea6c85712ffee9bf           SP
# 609e1a9a6c2539919b8205cf7c4e6ff0           SC
# b2f4d63c7203f539a78252565ca32257           RJ
# --------------------------------------------------------------------------------------------------------------------------
# df_product_category_name_translation
#                                  product_category_name_english
# product_category_name
# fashion_bolsas_e_acessorios           fashion_bags_accessories
# moveis_colchao_e_estofado    furniture_mattress_and_upholstery
# market_place                                      market_place
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Data Dictionary**

# %% [markdown]
# `customer_id`:
# key to the orders dataset. Each order has a unique customer_id.
#
# `customer_unique_id`:
# unique identifier of a customer.
#
# `customer_zip_code_prefix`:
# first five digits of customer zip code
#
# `customer_city`:
# customer city name
#
# `customer_state`:
# customer state
#
# -------
# `geolocation_zip_code_prefix`:
# first 5 digits of zip code
#
# `geolocation_lat`:
# latitude
#
# `geolocation_lng`:
# longitude
#
# `geolocation_city`:
# city name
#
# `geolocation_state`:
# state
#
# -----
# `order_id`:
# order unique identifier
#
# `order_item_id`:
# sequential number identifying number of items included in the same order.
#
# `product_id`:
# product unique identifier
#
# `seller_id`:
# seller unique identifier
#
# `shipping_limit_date`:
# Shows the seller shipping limit date for handling the order over to the logistic partner.
#
# `price`:
# item price
#
# `freight_value`:
# item freight value item (if an order has more than one item the freight value is splitted between items)
#
# ------------
# `order_id`:
# unique identifier of an order.
#
# `payment_sequential`:
# a customer may pay an order with more than one payment method. If he does so, a sequence will be created to accommodate all payments.
#
# `payment_type`:
# method of payment chosen by the customer.
#
# `payment_installment`s:
# number of installments chosen by the customer.
#
# `payment_value`:
# transaction value.
#
# ----------
# `review_id`:
# unique review identifier
#
# `review_score`:
# Note ranging from 1 to 5 given by the customer on a satisfaction survey.
#
# `review_comment_title`:
# Comment title from the review left by the customer, in Portuguese.
#
# `review_comment_message`:
# Comment message from the review left by the customer, in Portuguese.
#
# `review_creation_date`:
# Shows the date in which the satisfaction survey was sent to the customer.
#
# `review_answer_timestamp`:
# Shows satisfaction survey answer timestamp.
#
# ------------
# `order_id`:
# unique identifier of the order.
#
# `order_status`:
# Reference to the order status (delivered, shipped, etc).
#
# `order_purchase_timestamp`:
# Shows the purchase timestamp.
#
# `order_approved_at`:
# Shows the payment approval timestamp.
#
# `order_delivered_carrier_date`:
# Shows the order posting timestamp. When it was handled to the logistic partner.
#
# `order_delivered_customer_date`:
# Shows the actual order delivery date to the customer.
#
# `order_estimated_delivery_date`:
# Shows the estimated delivery date that was informed to customer at the purchase moment.
#
# ---------------
# `product_id`:
# unique product identifier
#
# `product_category_name`:
# root category of product, in Portuguese.
#
# `product_name_lenght`:
# number of characters extracted from the product name.
#
# `product_description_lenght`:
# number of characters extracted from the product description.
#
# `product_photos_qty`:
# number of product published photos
#
# `product_weight_g`:
# product weight measured in grams.
#
# `product_length_cm`:
# product length measured in centimeters.
#
# `product_height_cm`:
# product height measured in centimeters.
#
# `product_width_cm`:
# product width measured in centimeters.
#
# -----------
# `seller_id`:
# seller unique identifier
#
# `seller_zip_code_prefix`:
# first 5 digits of seller zip code
#
# `seller_city`:
# seller city name
#
# `seller_state`:
# seller state
#
# ----------
# `product_category_name`:
# category name in Portuguese
#
# `product_category_name_english`:
# category name in English

# %% [markdown]
# For each order, we have data to show:
# - who bought the item and where they live (zip code, city, state, LAT and LONG)
# - order details, the item, the seller, the time the order was shipped, its price and cost of shipping
# - payment details, the type of payment (credit card, voucher, etc..) and the number of installments and the total payment value
# - order review, with score and comments in Spanish
# - order delivery details, when it was approved, estimated and actual delivery dates
# - order item details, size, weight and the listing number of photos
# - seller location details
# - English translation of product category names

# %% [markdown]
# Now, after looking at the data at a glance, we need to ask if our data is complete, accurate and relevant to our problem. Since we are going to do unsupervised learning here, mimicking a scenario where we are using all the data we have, we can safely assume that our data is compete (to be confirmed), accurate and relevant.
#
# We can see that the data is huge and is scattered in several tables with links represented by IDs and keys. We can take different approaches to get down to the final data to use in our analysis, since this is an unsupervised learning exercise, we will leave the step of reducing our features size to the end after we combine all dataframes in one.

# %% [markdown]
# #### The Plan

# %% [markdown]
# To follow a structured approach, we need to do the following to achieve our objective stated above:
# - Data preparation and processing:
#     - join all dataframes into one dataframe
#     - clean the dataframe for duplicated and missing data and impute data if applicable
#     - transform the data into a customer level data meaning that it the instance level will be customers instead of order. This step may require data grouping and summarizing and perhaps creating new features
#     - omit all irrelevant features
# - Modelling & Evaluation
#     - Use various unsupervised learning techniques to cluster customers
#
# *This is an initial plan, some changes and iterations may come along the way.*

# %% [markdown]
# #### Data Preparation

# %%
# magic function to see all active variables in the kernel
# %whos
# Out:
# Variable                                   Type                          Data/Info
# ----------------------------------------------------------------------------------
# OneHotEncoder                              type                          <class 'sklearn.preproces<...>_encoders.OneHotEncoder'>
# count_list                                 list                          n=2
# date_list                                  list                          n=8
# df_customers                               DataFrame                                              <...>n[99441 rows x 4 columns]
# df_dict                                    dict                          n=9
# df_geolocation                             DataFrame                                              <...>1000163 rows x 4 columns]
# df_geolocation_avg                         DataFrame                                              <...>n[19015 rows x 2 columns]
# df_list                                    list                          n=4
# df_ocj_m                                   DataFrame                                              <...>[14547 rows x 26 columns]
# df_order_customer_joined                   DataFrame                                              <...>118146 rows x 27 columns]
# df_order_customer_products_joined          DataFrame                                              <...>118146 rows x 35 columns]
# df_order_customer_products_seller_joined   DataFrame                                              <...>118146 rows x 39 columns]
# df_order_items                             DataFrame                                              <...>[112650 rows x 6 columns]
# df_order_joined                            DataFrame                                              <...>118434 rows x 23 columns]
# df_order_joined_temp                       DataFrame                                              <...>113425 rows x 13 columns]
# df_order_payments                          DataFrame                                              <...>[103886 rows x 4 columns]
# df_order_reviews                           DataFrame                                              <...>n[99224 rows x 6 columns]
# df_orders                                  DataFrame                                              <...>n[99441 rows x 7 columns]
# df_orders_no_translation                   DataFrame                                              <...>118146 rows x 43 columns]
# df_orders_translated                       DataFrame                            order_id  review_i<...>93996 rows x 102 columns]
# df_product_category_name_translation       DataFrame                                              <...>\n\n[71 rows x 1 columns]
# df_products                                DataFrame                                              <...>n[32951 rows x 8 columns]
# df_r_m                                     DataFrame                                              <...>n\n[551 rows x 6 columns]
# df_rocj_m                                  DataFrame                                              <...>\n[118 rows x 32 columns]
# df_sellers                                 DataFrame                                              <...>\n[3095 rows x 3 columns]
# df_temp                                    DataFrame                                              <...>00510 rows x 102 columns]
# encoder                                    OneHotEncoder                 OneHotEncoder(sparse=False)
# encodere                                   OneHotEncoder                 OneHotEncoder()
# json                                       module                        <module 'json' from 'C:\\<...>\lib\\json\\__init__.py'>
# key                                        str                           df_product_category_name_translation
# max_list                                   list                          n=3
# mean_list                                  list                          n=16
# np                                         module                        <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# nunique_list                               list                          n=4
# pd                                         module                        <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                                        module                        <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# reduce                                     builtin_function_or_method    <built-in function reduce>
# sum_list                                   Index                         Index(['payment_type_bole<...>],\n      dtype='object')
# to_delete                                  list                          n=9
# to_drop_columns                            list                          n=6
# value                                      DataFrame                                              <...>\n\n[71 rows x 1 columns]

# %% [markdown]
# ##### Join all dataframes into one dataframe

# %% [markdown]
# We have 8 tables to join. We will do the joining in steps based on the common links between tables.
# 1. `order_id`: df_order_items , df_order_payments, df_order_reviews, and df_orders --> df_order_joined
# 2. `customer_id`: df_order_joined and df_customers --> df_order_customer_joined
# 3. `product_id`: df_order_customer_joined and df_products --> df_order_customer_products_joined
# 4. `seller_id`: df_order_customer_products_joined and df_sellers --> df_order_customer_products_seller_joined
# 5. `zip_code_prefix`:df_order_customer_products_seller_joined and df_geolocation --> df_orders_no_translation
#
# Then we will sue the df_product_category_name_translation dataframe to get to our final df_orders_translated.

# %%
# #1 order_id: df_order_items , df_order_payments, df_order_reviews, and df_orders --> df_order_joined
################################################################# 
# Use join to combine all dataframes, remember that one order might have different items shipped by more that one seller
# # We will start joining the lots with the common index based on the Data Schema above
# # df_order_items , df_order_payments, df_order_reviews, df_orders
# df_list = [df_order_items , df_order_payments, df_order_reviews, df_orders]

from functools import reduce

df_list = [df_orders, df_order_items , df_order_payments, df_order_reviews]

df_order_joined_temp = (
    reduce(lambda x,y:x.join(y, on = 'order_id', lsuffix = 'l', rsuffix = 'r'), [df_orders, df_order_items]) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %%
df_order_joined_temp.sample()
# Out:
#                                                        customer_id  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f  7fda493f747b5ced48e6f6851c22b21e
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f    delivered      2017-04-27 17:36:40
#
#                                     order_approved_at  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f  2017-04-27 17:45:23
#
#                                  order_delivered_carrier_date  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f          2017-04-28 09:14:14
#
#                                  order_delivered_customer_date  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f           2017-05-12 12:47:50
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f           2017-06-06 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f  1b0e39ec889889ea1d492603d8512bfb
#
#                                                          seller_id  \
# order_id
# 8d8ab471d725805f57571b24aaf78b8f  e26901d5ab434ce92fd9b5c256820a4e
#
#                                   shipping_limit_date  price  freight_value
# order_id
# 8d8ab471d725805f57571b24aaf78b8f  2017-05-04 17:45:23   32.9           20.8

# %%
df_order_joined_temp.shape
# Out:
# (113425, 13)

# %%
df_order_joined_temp.head(3)
# Out:
#                                                        customer_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#                                  order_status order_purchase_timestamp  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
#
#                                     order_approved_at  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
# 53cdb2fc8bc7dce0b6741e2150273451  2018-07-26 03:24:27
# 47770eb9100c2d0c44946d9cf07ec65d  2018-08-08 08:55:23
#
#                                  order_delivered_carrier_date  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7          2017-10-04 19:55:00
# 53cdb2fc8bc7dce0b6741e2150273451          2018-07-26 14:31:00
# 47770eb9100c2d0c44946d9cf07ec65d          2018-08-08 13:50:00
#
#                                  order_delivered_customer_date  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-10 21:25:13
# 53cdb2fc8bc7dce0b6741e2150273451           2018-08-07 15:27:45
# 47770eb9100c2d0c44946d9cf07ec65d           2018-08-17 18:06:29
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-18 00:00:00            1.0
# 53cdb2fc8bc7dce0b6741e2150273451           2018-08-13 00:00:00            1.0
# 47770eb9100c2d0c44946d9cf07ec65d           2018-09-04 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  87285b34884572647811a353c7ac498a
# 53cdb2fc8bc7dce0b6741e2150273451  595fac2a385ac33a80bd5114aec74eb8
# 47770eb9100c2d0c44946d9cf07ec65d  aa4383b373c6aca5d8797843e5594415
#
#                                                          seller_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  3504c0cb71d7fa48d967e0e4c94d59d9
# 53cdb2fc8bc7dce0b6741e2150273451  289cdb325fb7e7f891c38608bf9e0962
# 47770eb9100c2d0c44946d9cf07ec65d  4869f7a5dfa277a7dca6462dcf3b52b2
#
#                                   shipping_limit_date   price  freight_value
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-06 11:07:15   29.99           8.72
# 53cdb2fc8bc7dce0b6741e2150273451  2018-07-30 03:24:27  118.70          22.76
# 47770eb9100c2d0c44946d9cf07ec65d  2018-08-13 08:55:23  159.90          19.22

# %%
df_orders.shape, df_order_items.shape
# Out:
# ((99441, 7), (112650, 6))

# %% [markdown]
# We notice that the resulting dataframe is 775 rows bigger (775 = 113425 - 112650 ) than the df_orders dataframe. Let us see why.

# %%
df_order_joined_temp[df_order_joined_temp['seller_id'].isna()].sample(3)
# Out:
#                                                        customer_id  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c  2b99e152f2351410951c503a2f6a2d7e
# 2c9c2c96702997c879d75f927b76165e  20e569f30c28c88ac2731a006e5bb3d8
# b91dd40b68675f4dc29339562895ca26  65d0d3b9b3fa9f109802465c10bdff6a
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c  unavailable      2017-11-21 19:20:25
# 2c9c2c96702997c879d75f927b76165e  unavailable      2017-09-24 10:45:10
# b91dd40b68675f4dc29339562895ca26  unavailable      2018-02-24 16:22:06
#
#                                     order_approved_at  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c  2017-11-21 19:29:26
# 2c9c2c96702997c879d75f927b76165e  2017-09-24 10:55:08
# b91dd40b68675f4dc29339562895ca26  2018-02-24 16:35:26
#
#                                  order_delivered_carrier_date  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c                          NaN
# 2c9c2c96702997c879d75f927b76165e                          NaN
# b91dd40b68675f4dc29339562895ca26                          NaN
#
#                                  order_delivered_customer_date  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c                           NaN
# 2c9c2c96702997c879d75f927b76165e                           NaN
# b91dd40b68675f4dc29339562895ca26                           NaN
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c           2017-12-12 00:00:00            NaN
# 2c9c2c96702997c879d75f927b76165e           2017-10-27 00:00:00            NaN
# b91dd40b68675f4dc29339562895ca26           2018-03-16 00:00:00            NaN
#
#                                  product_id seller_id shipping_limit_date  \
# order_id
# 00daac8efd71674d62356c2a306d1e4c        NaN       NaN                 NaN
# 2c9c2c96702997c879d75f927b76165e        NaN       NaN                 NaN
# b91dd40b68675f4dc29339562895ca26        NaN       NaN                 NaN
#
#                                   price  freight_value
# order_id
# 00daac8efd71674d62356c2a306d1e4c    NaN            NaN
# 2c9c2c96702997c879d75f927b76165e    NaN            NaN
# b91dd40b68675f4dc29339562895ca26    NaN            NaN

# %%
df_order_joined_temp[df_order_joined_temp['seller_id'].isna()].shape
# Out:
# (775, 13)

# %% [markdown]
# Ok, this is because there are 775 rows that do not have orders data associated. We will leave them for now and will deal with them later.

# %% [markdown]
# Now let us join the four dataframes together.

# %%
df_list = [df_orders, df_order_items , df_order_payments, df_order_reviews]

df_order_joined = (
    reduce(lambda x,y:x.join(y, on = 'order_id', lsuffix = 'l', rsuffix = 'r'), df_list) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %%
df_order_joined.shape
# Out:
# (118434, 23)

# %%
df_order_joined.sample(3)
# Out:
#                                                        customer_id  \
# order_id
# dacd9ea86285f197d0b7495e8af14781  1ee7676535dc405dbb88977050668100
# edbb939fffa4ee03b8ccf49ed3f6e66e  2f36d971005f4a8a072667fa2e5bf407
# ff359d1c749b2f33549ec323a0736175  60842c6f4e508a6db3a9bdc307bde294
#
#                                  order_status order_purchase_timestamp  \
# order_id
# dacd9ea86285f197d0b7495e8af14781    delivered      2018-04-18 20:51:20
# edbb939fffa4ee03b8ccf49ed3f6e66e    delivered      2018-04-26 23:33:22
# ff359d1c749b2f33549ec323a0736175    delivered      2018-05-15 11:09:53
#
#                                     order_approved_at  \
# order_id
# dacd9ea86285f197d0b7495e8af14781  2018-04-18 21:11:15
# edbb939fffa4ee03b8ccf49ed3f6e66e  2018-04-26 23:49:42
# ff359d1c749b2f33549ec323a0736175  2018-05-15 11:34:32
#
#                                  order_delivered_carrier_date  \
# order_id
# dacd9ea86285f197d0b7495e8af14781          2018-04-19 18:35:29
# edbb939fffa4ee03b8ccf49ed3f6e66e          2018-04-27 13:12:00
# ff359d1c749b2f33549ec323a0736175          2018-05-16 14:10:00
#
#                                  order_delivered_customer_date  \
# order_id
# dacd9ea86285f197d0b7495e8af14781           2018-04-30 21:17:21
# edbb939fffa4ee03b8ccf49ed3f6e66e           2018-05-15 17:14:26
# ff359d1c749b2f33549ec323a0736175           2018-05-22 21:04:07
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# dacd9ea86285f197d0b7495e8af14781           2018-05-28 00:00:00            1.0
# edbb939fffa4ee03b8ccf49ed3f6e66e           2018-05-25 00:00:00            1.0
# ff359d1c749b2f33549ec323a0736175           2018-06-08 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# dacd9ea86285f197d0b7495e8af14781  fa87bc5ccdd8ea6e54117916e485cb48
# edbb939fffa4ee03b8ccf49ed3f6e66e  63c91bb26c656cd5fe0d2ca82b632c84
# ff359d1c749b2f33549ec323a0736175  9b0ad21bbd4384f9ebc28a688e1e81cd
#
#                                                          seller_id  \
# order_id
# dacd9ea86285f197d0b7495e8af14781  1900267e848ceeba8fa32d80c1a5f5a8
# edbb939fffa4ee03b8ccf49ed3f6e66e  530ec6109d11eaaf87999465c6afee01
# ff359d1c749b2f33549ec323a0736175  128639473a139ac0f3e5f5ade55873a5
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# dacd9ea86285f197d0b7495e8af14781  2018-04-24 21:11:15  44.99          19.32
# edbb939fffa4ee03b8ccf49ed3f6e66e  2018-05-07 23:49:42  84.90          27.32
# ff359d1c749b2f33549ec323a0736175  2018-05-18 11:31:43  18.90          13.47
#
#                                   payment_sequential payment_type  \
# order_id
# dacd9ea86285f197d0b7495e8af14781                 6.0      voucher
# edbb939fffa4ee03b8ccf49ed3f6e66e                 1.0  credit_card
# ff359d1c749b2f33549ec323a0736175                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# dacd9ea86285f197d0b7495e8af14781                   1.0          12.33
# edbb939fffa4ee03b8ccf49ed3f6e66e                   1.0         112.22
# ff359d1c749b2f33549ec323a0736175                   1.0          32.37
#
#                                  order_id  review_score review_comment_title  \
# order_id
# dacd9ea86285f197d0b7495e8af14781      NaN           NaN                  NaN
# edbb939fffa4ee03b8ccf49ed3f6e66e      NaN           NaN                  NaN
# ff359d1c749b2f33549ec323a0736175      NaN           NaN                  NaN
#
#                                  review_comment_message review_creation_date  \
# order_id
# dacd9ea86285f197d0b7495e8af14781                    NaN                  NaN
# edbb939fffa4ee03b8ccf49ed3f6e66e                    NaN                  NaN
# ff359d1c749b2f33549ec323a0736175                    NaN                  NaN
#
#                                  review_answer_timestamp
# order_id
# dacd9ea86285f197d0b7495e8af14781                     NaN
# edbb939fffa4ee03b8ccf49ed3f6e66e                     NaN
# ff359d1c749b2f33549ec323a0736175                     NaN

# %%
#2 customer_id: df_order_joined and df_customers --> df_order_customer_joined
#############################################################################
df_list = [df_order_joined, df_customers]

df_order_customer_joined = (
    reduce(lambda x,y:x.join(y, on = 'customer_id', lsuffix = 'l', rsuffix = 'r'), df_list) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %% [markdown]
# .join() did not wok here, let us investigate why.

# %%
df_order_customer_joined.shape
# Out:
# (118434, 27)

# %%
df_order_customer_joined.sample(1)
# Out:
#                                                        customer_id  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  6964708c7ac9eb36c31193d480ec96f3
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c    delivered      2017-04-13 16:00:12
#
#                                     order_approved_at  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  2017-04-13 16:10:10
#
#                                  order_delivered_carrier_date  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c          2017-04-19 09:43:15
#
#                                  order_delivered_customer_date  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c           2017-05-05 12:26:47
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c           2017-05-09 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  d0877f0094337c414d23f5a3c7bad20c
#
#                                                          seller_id  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  656591be56071d4c9ef4e5fee78a578a
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  2017-04-19 16:10:10  430.0          45.47
#
#                                   payment_sequential payment_type  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c                   4.0         475.47
#
#                                  order_id  review_score review_comment_title  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c      NaN           NaN                  NaN
#
#                                  review_comment_message review_creation_date  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c                    NaN                  NaN
#
#                                  review_answer_timestamp  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c                     NaN
#
#                                                 customer_unique_id  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c  0104d8ef04b9df2891e69bc0e2e6dca4
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c                     86186         cambe
#
#                                  customer_state
# order_id
# 163f8eb1b8e1a57c3ff383c09e13d42c             PR

# %%
df_order_customer_joined[df_order_customer_joined['review_score'] > 1]
# Out:
# Empty DataFrame
# Columns: [customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, payment_sequential, payment_type, payment_installments, payment_value, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
df_order_customer_joined.shape
# Out:
# (118434, 27)

# %% [markdown]
# It seems we are on the right track, there is one problem thought, all reviews dataframes data appear to be empty from our first join. We need to check why.

# %%
df_order_reviews.sample(3)
# Out:
#                                                           order_id  \
# review_id
# ff2bb2b7bc183fce1b105e2a07abb833  4908cfa4f81ef32d94f2394f1cfbedfa
# 19877703e42fd9c95d90d1056b806f69  fe5dc4ba2f23ea7ef3c1f05229f658b1
# 73b1be63f6d1ae4d903c685eeb9164bc  4c0a4b63218c9a22187547fbfb338fc9
#
#                                   review_score review_comment_title  \
# review_id
# ff2bb2b7bc183fce1b105e2a07abb833             5                  NaN
# 19877703e42fd9c95d90d1056b806f69             5                  NaN
# 73b1be63f6d1ae4d903c685eeb9164bc             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# review_id
# ff2bb2b7bc183fce1b105e2a07abb833                    NaN  2017-06-23 00:00:00
# 19877703e42fd9c95d90d1056b806f69                    NaN  2017-10-28 00:00:00
# 73b1be63f6d1ae4d903c685eeb9164bc                    NaN  2018-01-19 00:00:00
#
#                                  review_answer_timestamp
# review_id
# ff2bb2b7bc183fce1b105e2a07abb833     2017-06-24 01:15:38
# 19877703e42fd9c95d90d1056b806f69     2017-10-30 18:54:15
# 73b1be63f6d1ae4d903c685eeb9164bc     2018-01-22 16:44:05

# %%
df_order_reviews['order_id'].value_counts()
# Out:
# c88b1d1b157a9999ce368f218a407141    3
# 8e17072ec97ce29f0e1f111e598b0c85    3
# df56136b8031ecd28e200bb18e6ddb2e    3
# 03c939fd7fd3b38f8485a0f95798f1f6    3
# 5cb890a68b91b6158d69257e4e2bc359    2
#                                    ..
# 5b4e9a12d219f34f5c2de9f8d620b19d    1
# a6da096d974acc000962856d7386448a    1
# 75e0647c26de647eca3421e9cc66c9da    1
# bad0467c52f23cdc71e9fa139d4a8afd    1
# 90531360ecb1eec2a1fbb265a0db0508    1
# Name: order_id, Length: 98673, dtype: int64

# %% [markdown]
# The reason is because the 'order_id' is not unique on this dataframe. Let us take an example to understand if it is a duplicate or it is intended data.

# %%
df_order_reviews.shape
# Out:
# (99224, 6)

# %%
df_order_reviews[df_order_reviews['order_id'] == 'df56136b8031ecd28e200bb18e6ddb2e']
# Out:
#                                                           order_id  \
# review_id
# c444278834184f72b1484dfe47de7f97  df56136b8031ecd28e200bb18e6ddb2e
# 72a1098d5b410ae50fbc0509d26daeb9  df56136b8031ecd28e200bb18e6ddb2e
# 44f3e54834d23c5570c1d010824d4d59  df56136b8031ecd28e200bb18e6ddb2e
#
#                                   review_score review_comment_title  \
# review_id
# c444278834184f72b1484dfe47de7f97             5                  NaN
# 72a1098d5b410ae50fbc0509d26daeb9             5                  NaN
# 44f3e54834d23c5570c1d010824d4d59             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# review_id
# c444278834184f72b1484dfe47de7f97                    NaN  2017-02-08 00:00:00
# 72a1098d5b410ae50fbc0509d26daeb9                    NaN  2017-02-07 00:00:00
# 44f3e54834d23c5570c1d010824d4d59                    NaN  2017-02-09 00:00:00
#
#                                  review_answer_timestamp
# review_id
# c444278834184f72b1484dfe47de7f97     2017-02-14 13:58:48
# 72a1098d5b410ae50fbc0509d26daeb9     2017-02-10 10:46:09
# 44f3e54834d23c5570c1d010824d4d59     2017-02-09 09:07:28

# %%
df_order_reviews[df_order_reviews['order_id'] == 'c88b1d1b157a9999ce368f218a407141']
# Out:
#                                                           order_id  \
# review_id
# ffb8cff872a625632ac983eb1f88843c  c88b1d1b157a9999ce368f218a407141
# 202b5f44d09cd3cfc0d6bd12f01b044c  c88b1d1b157a9999ce368f218a407141
# fb96ea2ef8cce1c888f4d45c8e22b793  c88b1d1b157a9999ce368f218a407141
#
#                                   review_score review_comment_title  \
# review_id
# ffb8cff872a625632ac983eb1f88843c             3                  NaN
# 202b5f44d09cd3cfc0d6bd12f01b044c             5                  NaN
# fb96ea2ef8cce1c888f4d45c8e22b793             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# review_id
# ffb8cff872a625632ac983eb1f88843c                    NaN  2017-07-22 00:00:00
# 202b5f44d09cd3cfc0d6bd12f01b044c                    NaN  2017-07-22 00:00:00
# fb96ea2ef8cce1c888f4d45c8e22b793                    NaN  2017-07-21 00:00:00
#
#                                  review_answer_timestamp
# review_id
# ffb8cff872a625632ac983eb1f88843c     2017-07-26 13:41:07
# 202b5f44d09cd3cfc0d6bd12f01b044c     2017-07-26 13:40:22
# fb96ea2ef8cce1c888f4d45c8e22b793     2017-07-26 13:45:15

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# We can see from these two example that they are reviews for the same order created in different times. Let us see how many of them we have.

# %%
(df_order_reviews['order_id'].value_counts() > 1).sum()
# Out:
# 547

# %% [markdown]
# We have 574 instances of duplicated reviews. This can be due to one of two reasons, either every review is associated with a partial fulfillment of an the same order, or the customer changed their mind and updated the review.
# Let us check the first assumption by checking if these orders have multiple fulfillments.

# %%
(df_order_reviews['order_id'].value_counts() > 1)
# Out:
# c88b1d1b157a9999ce368f218a407141     True
# 8e17072ec97ce29f0e1f111e598b0c85     True
# df56136b8031ecd28e200bb18e6ddb2e     True
# 03c939fd7fd3b38f8485a0f95798f1f6     True
# 5cb890a68b91b6158d69257e4e2bc359     True
#                                     ...
# 5b4e9a12d219f34f5c2de9f8d620b19d    False
# a6da096d974acc000962856d7386448a    False
# 75e0647c26de647eca3421e9cc66c9da    False
# bad0467c52f23cdc71e9fa139d4a8afd    False
# 90531360ecb1eec2a1fbb265a0db0508    False
# Name: order_id, Length: 98673, dtype: bool

# %%
df_order_reviews.groupby('order_id')['order_id'].transform('count')
# Out:
# review_id
# 7bc2406110b926393aa56f80a40eba40    1
# 80e641a11e56f04c1ad469d5645fdfde    1
# 228ce5500dc1d8e020d8d1322874b6f0    1
# e64fb393e7b32834bb789ff8bb30750e    1
# f7c4243c7fe1938f181bec41a392bdeb    1
#                                    ..
# 574ed12dd733e5fa530cfd4bbf39d7c9    1
# f3897127253a9592a73be9bdfdf4ed7a    1
# b3de70c89b1510c4cd3d0649fd302472    1
# 1adeb9d84d72fe4e337617733eb85149    1
# efe49f1d6f951dd88b51e6ccd4cc548f    1
# Name: order_id, Length: 99224, dtype: int64

# %%
df_order_reviews[df_order_reviews.duplicated(['order_id'])].shape
# Out:
# (551, 6)

# %%
df_order_reviews[df_order_reviews.duplicated(['order_id'])].sample()
# Out:
#                                                           order_id  \
# review_id
# 961c0cd56f464536b821fd6f60da4463  142b0e3de54c110a3109b26c79d6ec2e
#
#                                   review_score review_comment_title  \
# review_id
# 961c0cd56f464536b821fd6f60da4463             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# review_id
# 961c0cd56f464536b821fd6f60da4463                    NaN  2017-07-12 00:00:00
#
#                                  review_answer_timestamp
# review_id
# 961c0cd56f464536b821fd6f60da4463     2017-07-12 23:08:45

# %%
df_order_customer_joined.shape, df_order_customer_joined.index.unique().shape, df_order_customer_joined.shape[0] - df_order_customer_joined.index.unique().shape[0]
# Out:
# ((118434, 27), (99441,), 18993)

# %%
df_order_customer_joined[df_order_customer_joined['order_item_id'] > 1].shape
# Out:
# (14547, 27)

# %%
df_order_customer_joined[df_order_customer_joined['order_item_id'] > 1].sample()
# Out:
#                                                        customer_id  \
# order_id
# 6498d67586b0908cad595ae0c3638205  3aaa19d4d385baa53859ea43d47051ae
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 6498d67586b0908cad595ae0c3638205    delivered      2018-04-12 08:18:41
#
#                                     order_approved_at  \
# order_id
# 6498d67586b0908cad595ae0c3638205  2018-04-13 13:29:44
#
#                                  order_delivered_carrier_date  \
# order_id
# 6498d67586b0908cad595ae0c3638205          2018-04-18 21:08:32
#
#                                  order_delivered_customer_date  \
# order_id
# 6498d67586b0908cad595ae0c3638205           2018-05-07 16:28:39
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 6498d67586b0908cad595ae0c3638205           2018-05-04 00:00:00            2.0
#
#                                                         product_id  \
# order_id
# 6498d67586b0908cad595ae0c3638205  8e50f956978d187a7cd200b9b45fe9c4
#
#                                                          seller_id  \
# order_id
# 6498d67586b0908cad595ae0c3638205  15ead3a5037a918ddb520dfe39a3d2b9
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 6498d67586b0908cad595ae0c3638205  2018-04-19 13:29:44   27.0          18.77
#
#                                   payment_sequential payment_type  \
# order_id
# 6498d67586b0908cad595ae0c3638205                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 6498d67586b0908cad595ae0c3638205                   4.0          83.54
#
#                                  order_id  review_score review_comment_title  \
# order_id
# 6498d67586b0908cad595ae0c3638205      NaN           NaN                  NaN
#
#                                  review_comment_message review_creation_date  \
# order_id
# 6498d67586b0908cad595ae0c3638205                    NaN                  NaN
#
#                                  review_answer_timestamp  \
# order_id
# 6498d67586b0908cad595ae0c3638205                     NaN
#
#                                                 customer_unique_id  \
# order_id
# 6498d67586b0908cad595ae0c3638205  6428403ac3b03984c38fd083fa1647b0
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 6498d67586b0908cad595ae0c3638205                     24440   sao goncalo
#
#                                  customer_state
# order_id
# 6498d67586b0908cad595ae0c3638205             RJ

# %%
df_r_m = df_order_reviews[df_order_reviews.duplicated(['order_id'])] # data where is more than one review
df_ocj_m = df_order_customer_joined[df_order_customer_joined['order_item_id'] > 1] # data where is more than one shipment
df_ocj_m = df_ocj_m.drop(df_ocj_m.columns[17], axis = 1)
# df_ocj_m.index.name = 'order_id', df_ocj_m.reset_index()

df_rocj_m = pd.merge(df_r_m, df_ocj_m, on = 'order_id')

# %%
display(df_r_m.sample())
display(df_ocj_m.sample())
# Out:
#                                                           order_id  \
# review_id
# 6b53b5ee362ec284dcaca9a653645b58  5e4c365dd3cf7769a88981f408d069d3
#
#                                   review_score review_comment_title  \
# review_id
# 6b53b5ee362ec284dcaca9a653645b58             1                  NaN
#
#                                                                                                                                                                                                                     review_comment_message  \
# review_id
# 6b53b5ee362ec284dcaca9a653645b58  Ja tive problema com uma maquina Nespresso que comprei e depois me disseram que o parceiro de vcs nao tinha. Agora com o conjunto de lencol no qual nao recebi. E ainda tem muitos produtos que comprei
#
#                                  review_creation_date review_answer_timestamp
# review_id
# 6b53b5ee362ec284dcaca9a653645b58  2017-12-14 00:00:00     2017-12-14 13:23:36
#                                                        customer_id  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  1dbc055ccab23ed894267767e268e8a1
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 61a4e749e6975384980e883fc5653d8b    delivered      2017-07-21 15:08:23
#
#                                     order_approved_at  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  2017-07-21 15:55:29
#
#                                  order_delivered_carrier_date  \
# order_id
# 61a4e749e6975384980e883fc5653d8b          2017-08-01 18:42:13
#
#                                  order_delivered_customer_date  \
# order_id
# 61a4e749e6975384980e883fc5653d8b           2017-08-04 16:47:30
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 61a4e749e6975384980e883fc5653d8b           2017-08-14 00:00:00            4.0
#
#                                                         product_id  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  1bb0f142789375f5709d08b2f2355c2b
#
#                                                          seller_id  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  da8622b14eb17ae2831f4ac5b9dab84a
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  2017-07-27 15:55:29  249.9          32.23
#
#                                   payment_sequential payment_type  \
# order_id
# 61a4e749e6975384980e883fc5653d8b                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 61a4e749e6975384980e883fc5653d8b                   1.0        1591.24
#
#                                   review_score review_comment_title  \
# order_id
# 61a4e749e6975384980e883fc5653d8b           NaN                  NaN
#
#                                  review_comment_message review_creation_date  \
# order_id
# 61a4e749e6975384980e883fc5653d8b                    NaN                  NaN
#
#                                  review_answer_timestamp  \
# order_id
# 61a4e749e6975384980e883fc5653d8b                     NaN
#
#                                                 customer_unique_id  \
# order_id
# 61a4e749e6975384980e883fc5653d8b  4c21c589db03eb65cbc452fc470850cf
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 61a4e749e6975384980e883fc5653d8b                     35500   divinopolis
#
#                                  customer_state
# order_id
# 61a4e749e6975384980e883fc5653d8b             MG

# %%
df_ocj_m.columns[17]
# Out:
# 'review_score'

# %%
df_rocj_m.shape
# Out:
# (118, 32)

# %% [markdown]
# This proves that this not the case, the duplication is not because the customer reviewed each shipment, as we can see the merged dataframe is smaller than the merging dataframes. So we ill assume that the duplication is a result of the data being retained if the customer decided to updated their review.

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# Now let us use a different method to  merge the dataframes, but first we need to delete the empty columns.

# %%
to_drop_columns = ['order_id', 'review_score', 'review_comment_title', 
                   'review_comment_message', 'review_creation_date', 'review_answer_timestamp']
df_order_customer_joined = df_order_customer_joined.drop(to_drop_columns, axis = 1)

# %% [markdown]
# Check the columns were deleted.

# %%
df_order_customer_joined.sample(1)
# Out:
#                                                        customer_id  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  83f80dacec9b7214a86e64d568bc76d1
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b    delivered      2018-01-12 11:32:01
#
#                                     order_approved_at  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  2018-01-12 11:48:28
#
#                                  order_delivered_carrier_date  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b          2018-01-16 16:13:04
#
#                                  order_delivered_customer_date  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b           2018-01-22 17:21:48
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b           2018-02-07 00:00:00            2.0
#
#                                                         product_id  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  7a5c07212703b5f01ee199d29a29a587
#
#                                                          seller_id  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  432c37c9dfba871172ec162e20118b8c
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  2018-01-18 11:48:28   79.0          15.99
#
#                                   payment_sequential payment_type  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b                   1.0         189.98
#
#                                                 customer_unique_id  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b  d45226d0164cd17393fd77b1d3d92baa
#
#                                   customer_zip_code_prefix  \
# order_id
# 4c309580256bd11b9a9135a26a1a966b                      9530
#
#                                        customer_city customer_state
# order_id
# 4c309580256bd11b9a9135a26a1a966b  sao caetano do sul             SP

# %%
# merge
df_order_customer_joined = pd.merge(df_order_customer_joined, df_order_reviews, left_index= True, right_on='order_id') 
df_order_customer_joined = df_order_customer_joined.reset_index().set_index('order_id') # reset the index to order_id

# %%
df_order_customer_joined.shape
# Out:
# (118146, 27)

# %%
df_order_customer_joined.sample()
# Out:
#                                                          review_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  f483503a2a57a0f121ec0d9f72cab5c9
#
#                                                        customer_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  2de991e06dfea2ca925d906062ddb059
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d    delivered      2017-09-03 15:16:30
#
#                                     order_approved_at  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  2017-09-03 20:35:03
#
#                                  order_delivered_carrier_date  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d          2017-09-04 17:03:18
#
#                                  order_delivered_customer_date  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d           2017-09-05 20:35:46
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d           2017-09-15 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  c11485ba18bc927ccd486e58eaea6ef0
#
#                                                          seller_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  5b179e9e8cc7ab6fd113a46ca584da81
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  2017-09-08 20:35:03  129.9           9.72
#
#                                   payment_sequential payment_type  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d                  10.0         139.62
#
#                                                 customer_unique_id  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  0d7bc569f058a3bf7d95f9842c611b11
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d                      4662     sao paulo
#
#                                  customer_state  review_score  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d             SP             5
#
#                                  review_comment_title review_comment_message  \
# order_id
# 7942fdd6290ee4b2946bb066287bc91d                  NaN                    NaN
#
#                                  review_creation_date review_answer_timestamp
# order_id
# 7942fdd6290ee4b2946bb066287bc91d  2017-09-06 00:00:00     2017-09-07 00:50:52

# %% [markdown]
# Now let us see the impact of this duplication on our merged dataframe.

# %%
df_order_customer_joined[df_order_customer_joined.index.values == 'c88b1d1b157a9999ce368f218a407141']
# Out:
#                                                          review_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141  ffb8cff872a625632ac983eb1f88843c
# c88b1d1b157a9999ce368f218a407141  202b5f44d09cd3cfc0d6bd12f01b044c
# c88b1d1b157a9999ce368f218a407141  fb96ea2ef8cce1c888f4d45c8e22b793
#
#                                                        customer_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141  ae0fb7b01c548c4fd30f19f55453ec4a
# c88b1d1b157a9999ce368f218a407141  ae0fb7b01c548c4fd30f19f55453ec4a
# c88b1d1b157a9999ce368f218a407141  ae0fb7b01c548c4fd30f19f55453ec4a
#
#                                  order_status order_purchase_timestamp  \
# order_id
# c88b1d1b157a9999ce368f218a407141    delivered      2017-07-17 22:44:23
# c88b1d1b157a9999ce368f218a407141    delivered      2017-07-17 22:44:23
# c88b1d1b157a9999ce368f218a407141    delivered      2017-07-17 22:44:23
#
#                                     order_approved_at  \
# order_id
# c88b1d1b157a9999ce368f218a407141  2017-07-18 22:50:12
# c88b1d1b157a9999ce368f218a407141  2017-07-18 22:50:12
# c88b1d1b157a9999ce368f218a407141  2017-07-18 22:50:12
#
#                                  order_delivered_carrier_date  \
# order_id
# c88b1d1b157a9999ce368f218a407141          2017-07-20 15:27:41
# c88b1d1b157a9999ce368f218a407141          2017-07-20 15:27:41
# c88b1d1b157a9999ce368f218a407141          2017-07-20 15:27:41
#
#                                  order_delivered_customer_date  \
# order_id
# c88b1d1b157a9999ce368f218a407141           2017-07-21 17:06:30
# c88b1d1b157a9999ce368f218a407141           2017-07-21 17:06:30
# c88b1d1b157a9999ce368f218a407141           2017-07-21 17:06:30
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141           2017-08-01 00:00:00            1.0
# c88b1d1b157a9999ce368f218a407141           2017-08-01 00:00:00            1.0
# c88b1d1b157a9999ce368f218a407141           2017-08-01 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141  b1acb7e8152c90c9619897753a75c973
# c88b1d1b157a9999ce368f218a407141  b1acb7e8152c90c9619897753a75c973
# c88b1d1b157a9999ce368f218a407141  b1acb7e8152c90c9619897753a75c973
#
#                                                          seller_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141  cc419e0650a3c5ba77189a1882b7556a
# c88b1d1b157a9999ce368f218a407141  cc419e0650a3c5ba77189a1882b7556a
# c88b1d1b157a9999ce368f218a407141  cc419e0650a3c5ba77189a1882b7556a
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# c88b1d1b157a9999ce368f218a407141  2017-07-26 22:50:12  34.99           7.78
# c88b1d1b157a9999ce368f218a407141  2017-07-26 22:50:12  34.99           7.78
# c88b1d1b157a9999ce368f218a407141  2017-07-26 22:50:12  34.99           7.78
#
#                                   payment_sequential payment_type  \
# order_id
# c88b1d1b157a9999ce368f218a407141                 1.0  credit_card
# c88b1d1b157a9999ce368f218a407141                 1.0  credit_card
# c88b1d1b157a9999ce368f218a407141                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# c88b1d1b157a9999ce368f218a407141                   4.0          42.77
# c88b1d1b157a9999ce368f218a407141                   4.0          42.77
# c88b1d1b157a9999ce368f218a407141                   4.0          42.77
#
#                                                 customer_unique_id  \
# order_id
# c88b1d1b157a9999ce368f218a407141  b64ebaf3d11b7209fe566364cc359a51
# c88b1d1b157a9999ce368f218a407141  b64ebaf3d11b7209fe566364cc359a51
# c88b1d1b157a9999ce368f218a407141  b64ebaf3d11b7209fe566364cc359a51
#
#                                   customer_zip_code_prefix  \
# order_id
# c88b1d1b157a9999ce368f218a407141                      9690
# c88b1d1b157a9999ce368f218a407141                      9690
# c88b1d1b157a9999ce368f218a407141                      9690
#
#                                           customer_city customer_state  \
# order_id
# c88b1d1b157a9999ce368f218a407141  sao bernardo do campo             SP
# c88b1d1b157a9999ce368f218a407141  sao bernardo do campo             SP
# c88b1d1b157a9999ce368f218a407141  sao bernardo do campo             SP
#
#                                   review_score review_comment_title  \
# order_id
# c88b1d1b157a9999ce368f218a407141             3                  NaN
# c88b1d1b157a9999ce368f218a407141             5                  NaN
# c88b1d1b157a9999ce368f218a407141             5                  NaN
#
#                                  review_comment_message review_creation_date  \
# order_id
# c88b1d1b157a9999ce368f218a407141                    NaN  2017-07-22 00:00:00
# c88b1d1b157a9999ce368f218a407141                    NaN  2017-07-22 00:00:00
# c88b1d1b157a9999ce368f218a407141                    NaN  2017-07-21 00:00:00
#
#                                  review_answer_timestamp
# order_id
# c88b1d1b157a9999ce368f218a407141     2017-07-26 13:41:07
# c88b1d1b157a9999ce368f218a407141     2017-07-26 13:40:22
# c88b1d1b157a9999ce368f218a407141     2017-07-26 13:45:15

# %% [markdown]
# We notice that there now three rows with different review_id each for the same order (only for those orders with more than one review in the reviews dataframe), and this is expected. We will deal with this duplication later.

# %%
#3 product_id: df_order_customer_joined and df_products --> df_order_customer_products_joined
#############################################################################
df_list = [df_order_customer_joined, df_products]

df_order_customer_products_joined = (
    reduce(lambda x,y:x.join(y, on = 'product_id', lsuffix = 'l', rsuffix = 'r'), df_list) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %%
df_order_customer_products_joined.shape
# Out:
# (118146, 35)

# %%
df_order_customer_products_joined.sample()
# Out:
#                                                          review_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  10f9300f8637c13e5691f6354205006d
#
#                                                        customer_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  1dbb8fce4549ead4076d9146e9da0fe8
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0    delivered      2018-06-04 18:34:20
#
#                                     order_approved_at  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  2018-06-04 18:50:27
#
#                                  order_delivered_carrier_date  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0          2018-06-05 15:40:00
#
#                                  order_delivered_customer_date  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0           2018-06-08 22:26:31
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0           2018-07-05 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  2b0943c63387bbdc046d9a7692602388
#
#                                                          seller_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  9d681c7e12db302cb261e721040dde65
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  2018-06-08 18:50:27   29.9          16.32
#
#                                   payment_sequential payment_type  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                   1.0          46.22
#
#                                                 customer_unique_id  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  d1b909331ab7e40645edd582f0469d79
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                     13045      campinas
#
#                                  customer_state  review_score  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0             SP             4
#
#                                  review_comment_title  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                  NaN
#
#                                                                                                                                                                                                               review_comment_message  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  Respondi que sim para "recebi o produto correto" por falta de opção. Eu ainda não vi o produto. Não quis abrir a embalagem, pois é presente. Caso haja alguma desconformidade entrarei em contato.
#
#                                  review_creation_date review_answer_timestamp  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0  2018-06-09 00:00:00     2018-06-10 11:39:53
#
#                                  product_category_name  product_name_lenght  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0         esporte_lazer                 54.0
#
#                                   product_description_lenght  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                       586.0
#
#                                   product_photos_qty  product_weight_g  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0                 2.0            1050.0
#
#                                   product_length_cm  product_height_cm  \
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0               30.0               15.0
#
#                                   product_width_cm
# order_id
# 61af52f7cc6266b9aead2cc464aa48f0              20.0

# %%
#4 seller_id: df_order_customer_products_joined and df_sellers --> df_order_customer_products_seller_joined
#############################################################################
df_list = [df_order_customer_products_joined, df_sellers]

df_order_customer_products_seller_joined = (
    reduce(lambda x,y:x.join(y, on = 'seller_id', lsuffix = 'l', rsuffix = 'r'), df_list) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %%
df_order_customer_products_seller_joined.shape
# Out:
# (118146, 38)

# %%
df_order_customer_products_seller_joined.sample()
# Out:
#                                                          review_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  528f6263b85f98a712685846a79ee2f5
#
#                                                        customer_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  8a559a1732fcb3e7873b5a56267568c3
#
#                                  order_status order_purchase_timestamp  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9    delivered      2018-06-15 12:27:09
#
#                                     order_approved_at  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  2018-06-15 13:41:00
#
#                                  order_delivered_carrier_date  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9          2018-06-15 14:07:00
#
#                                  order_delivered_customer_date  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9           2018-06-18 18:26:38
#
#                                  order_estimated_delivery_date  order_item_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9           2018-07-13 00:00:00            1.0
#
#                                                         product_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  7810b42c3450a044431d95c59c00b600
#
#                                                          seller_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  d921b68bf747894be13a97ae52b0f386
#
#                                   shipping_limit_date  price  freight_value  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  2018-06-19 13:06:39  198.9          19.49
#
#                                   payment_sequential payment_type  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9                 1.0  credit_card
#
#                                   payment_installments  payment_value  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9                   4.0         218.39
#
#                                                 customer_unique_id  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  b9251f9f5e1811ec4dd0e59e8e538141
#
#                                   customer_zip_code_prefix customer_city  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9                      7724      caieiras
#
#                                  customer_state  review_score  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9             SP             5
#
#                                  review_comment_title  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9               Ótimo!
#
#                                                                                                        review_comment_message  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  Entrega super rápida, linda embalagem e o produto é impecável!! Amei...Super recomendo!!!!
#
#                                  review_creation_date review_answer_timestamp  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9  2018-06-19 00:00:00     2018-06-20 19:54:08
#
#                                  product_category_name  product_name_lenght  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9    relogios_presentes                 45.0
#
#                                   product_description_lenght  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9                       702.0
#
#                                   product_photos_qty  product_weight_g  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9                 1.0             367.0
#
#                                   product_length_cm  product_height_cm  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9               19.0               13.0
#
#                                   product_width_cm  seller_zip_code_prefix  \
# order_id
# 45e6fe309ebb856da45864abb8c53ff9              19.0                 35570.0
#
#                                  seller_city seller_state
# order_id
# 45e6fe309ebb856da45864abb8c53ff9     formiga           MG

# %%
print(f'There are {len(df_geolocation.index.unique())} unique zip_code_prefix values on the geolocation dataframe.')
# Out:
# There are 19015 unique zip_code_prefix values on the geolocation dataframe.

# %%
df_geolocation
# Out:
#                              geolocation_lat  geolocation_lng  \
# geolocation_zip_code_prefix
# 1037                              -23.545621       -46.639292
# 1046                              -23.546081       -46.644820
# 1046                              -23.546129       -46.642951
# 1041                              -23.544392       -46.639499
# 1035                              -23.541578       -46.641607
# ...                                      ...              ...
# 99950                             -28.068639       -52.010705
# 99900                             -27.877125       -52.224882
# 99950                             -28.071855       -52.014716
# 99980                             -28.388932       -51.846871
# 99950                             -28.070104       -52.018658
#
#                             geolocation_city geolocation_state
# geolocation_zip_code_prefix
# 1037                               sao paulo                SP
# 1046                               sao paulo                SP
# 1046                               sao paulo                SP
# 1041                               sao paulo                SP
# 1035                               sao paulo                SP
# ...                                      ...               ...
# 99950                               tapejara                RS
# 99900                         getulio vargas                RS
# 99950                               tapejara                RS
# 99980                        david canabarro                RS
# 99950                               tapejara                RS
#
# [1000163 rows x 4 columns]

# %%
print(f'There are {len(df_order_customer_products_seller_joined["customer_zip_code_prefix"].unique())} unique customer_zip_code_prefix values on the main dataframe.')
# Out:
# There are 14973 unique customer_zip_code_prefix values on the main dataframe.

# %% [markdown]
# Now, with respect to the fifth and last step, merging / joining with `df_geolocation`. Looking at the dataframe size and contents, it appears that many Lat and Long share the same code. This create a problem as we are only looking for one Lat/Long pair for each customer. Also, there no indication any where as to which one belongs to our subject. We could use GeoPandas (which is not necessary in our case) to use this information on the clustering process, however since it is not straight forward to extract the geolocation, we need to decide on whether to remove this data or use the average of Lat and Long where the zip code is the same, which is a sort of approximation to all locations sharing the same zip code to the center of that geography. The late seems to be a better off option that omitting the data all together.
#
# We could also use the same approach to find transform all sellers addresses.
#
# If we do the above, we will be able to remove the zip_code, city and state columns unless we want to learn some similarities of customers in the same city for instance where we need to hot one encode the city column.

# %%
# Average all Lat and Long at the 'geolocation_zip_code_prefix' level
df_geolocation_avg = df_geolocation.groupby('geolocation_zip_code_prefix').mean()
df_geolocation_avg
# Out:
#                              geolocation_lat  geolocation_lng
# geolocation_zip_code_prefix
# 1001                              -23.550190       -46.634024
# 1002                              -23.548146       -46.634979
# 1003                              -23.548994       -46.635731
# 1004                              -23.549799       -46.634757
# 1005                              -23.549456       -46.636733
# ...                                      ...              ...
# 99960                             -27.953722       -52.025511
# 99965                             -28.183372       -52.039850
# 99970                             -28.343766       -51.874689
# 99980                             -28.389129       -51.843836
# 99990                             -28.329595       -51.769362
#
# [19015 rows x 2 columns]

# %% [markdown]
# Ass we are going to join on column other the index, we need to reset the index to keep the order_id as a column on the dataframe otherwise it will be dropped automatically.

# %%
df_order_customer_products_seller_joined.reset_index(inplace = True)

# %%
# 5 zip_code_prefix :df_order_customer_products_seller_joined and df_geolocation --> df_orders_no_translation
############################################################################
## We need to use merge here for column-to-column operation

# merge
df_orders_no_translation = pd.merge(df_order_customer_products_seller_joined, df_geolocation_avg, 
                                    left_on ='customer_zip_code_prefix',  
                                    right_on='geolocation_zip_code_prefix', how = 'left')

# %%
df_orders_no_translation.rename(columns={'geolocation_lat': 'customer_geolocation_lat', 
                                         'geolocation_lng': 'customer_geolocation_lng'}, inplace = True)

# %%
df_orders_no_translation.head(1)
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-10-06 11:07:15  29.99           8.72                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
#
#    customer_zip_code_prefix customer_city customer_state  review_score  \
# 0                      3149     sao paulo             SP             4
#
#   review_comment_title  \
# 0                  NaN
#
#                                                                                                                                                        review_comment_message  \
# 0  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio bem amassada e danificada, o que ficará chato, pois se trata de um presente.
#
#   review_creation_date review_answer_timestamp  product_category_name  \
# 0  2017-10-11 00:00:00     2017-10-12 03:43:48  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
#
#    seller_zip_code_prefix seller_city seller_state  customer_geolocation_lat  \
# 0                  9350.0        maua           SP                -23.576983
#
#    customer_geolocation_lng
# 0                -46.587161

# %% [markdown]
# Do the same for the seller geolocation.

# %%
# 5 zip_code_prefix :df_order_customer_products_seller_joined and df_geolocation --> df_orders_no_translation
############################################################################
## We need to use merge here for column-to-column operation

# merge
df_orders_no_translation = pd.merge(df_orders_no_translation, df_geolocation_avg, 
                                    left_on ='seller_zip_code_prefix',  
                                    right_on='geolocation_zip_code_prefix', how = 'left') 
# df_orders_no_translation = df_orders_no_translation.reset_index().set_index('order_id') # reset the index to order_id

# %%
df_orders_no_translation.rename(columns={'geolocation_lat': 'seller_geolocation_lat', 
                                         'geolocation_lng': 'seller_geolocation_lng'}, inplace = True)

# %%
df_orders_no_translation.head(1)
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-10-06 11:07:15  29.99           8.72                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
#
#    customer_zip_code_prefix customer_city customer_state  review_score  \
# 0                      3149     sao paulo             SP             4
#
#   review_comment_title  \
# 0                  NaN
#
#                                                                                                                                                        review_comment_message  \
# 0  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio bem amassada e danificada, o que ficará chato, pois se trata de um presente.
#
#   review_creation_date review_answer_timestamp  product_category_name  \
# 0  2017-10-11 00:00:00     2017-10-12 03:43:48  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
#
#    seller_zip_code_prefix seller_city seller_state  customer_geolocation_lat  \
# 0                  9350.0        maua           SP                -23.576983
#
#    customer_geolocation_lng  seller_geolocation_lat  seller_geolocation_lng
# 0                -46.587161              -23.680729              -46.444238

# %% [markdown]
# To make sure we have done things right, let us check that the first customer geolocation value was done right.

# %%
df_geolocation[df_geolocation.index.to_series() == 3149].mean()
# Out:
# C:\Users\omass\AppData\Local\Temp/ipykernel_56892/3871122972.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_geolocation[df_geolocation.index.to_series() == 3149].mean()
# geolocation_lat   -23.576983
# geolocation_lng   -46.587161
# dtype: float64

# %%
df_geolocation_avg[df_geolocation_avg.index.to_series() == 3149].mean()
# Out:
# geolocation_lat   -23.576983
# geolocation_lng   -46.587161
# dtype: float64

# %% [markdown]
# Now the very last step on getting all the data in one place is to translate the production category.

# %%
df_product_category_name_translation.sample(3)
# Out:
#                                 product_category_name_english
# product_category_name
# cine_foto                                          cine_photo
# eletroportateis                              small_appliances
# industria_comercio_e_negocios  industry_commerce_and_business

# %%
df_product_category_name_translation.shape
# Out:
# (71, 1)

# %%
df_list = [df_orders_no_translation, df_product_category_name_translation]

df_orders_translated = (
    reduce(lambda x,y:x.join(y, on = 'product_category_name', lsuffix = 'l', rsuffix = 'r'), df_list) # same a chaining joins
#       .rename_axis('user_id').reset_index() # user id back as a column if needed
)

# %%
df_orders_translated.sample()
# Out:
#                                order_id                         review_id  \
# 29936  a1deb5a1e93bdf89bc4e5e00ec3691d6  435296c9e51d508185485972dd030381
#
#                             customer_id order_status order_purchase_timestamp  \
# 29936  00949af96107ff1f55bc0f09e913686d    delivered      2018-03-31 11:35:12
#
#          order_approved_at order_delivered_carrier_date  \
# 29936  2018-03-31 12:15:06          2018-04-04 20:42:18
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 29936           2018-04-05 21:51:43           2018-04-17 00:00:00
#
#        order_item_id                        product_id  \
# 29936            1.0  bee2e070c39f3dd2f6883a17a5f0da45
#
#                               seller_id  shipping_limit_date  price  \
# 29936  4e922959ae960d389249c378d1c939f5  2018-04-10 12:15:06  180.0
#
#        freight_value  payment_sequential payment_type  payment_installments  \
# 29936           9.56                 1.0  credit_card                   2.0
#
#        payment_value                customer_unique_id  \
# 29936         189.56  3cc4acd6cfe6acb5f129a560961f2ef6
#
#        customer_zip_code_prefix customer_city customer_state  review_score  \
# 29936                      5335     sao paulo             SP             4
#
#       review_comment_title review_comment_message review_creation_date  \
# 29936                  NaN                    NaN  2018-04-06 00:00:00
#
#       review_answer_timestamp   product_category_name  product_name_lenght  \
# 29936     2018-04-09 18:44:20  informatica_acessorios                 53.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 29936                       871.0                 4.0             175.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 29936               20.0               20.0              20.0
#
#        seller_zip_code_prefix seller_city seller_state  \
# 29936                 12327.0     jacarei           SP
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 29936                -23.546188                -46.753607
#
#        seller_geolocation_lat  seller_geolocation_lng  \
# 29936              -23.302318              -45.971888
#
#       product_category_name_english
# 29936         computers_accessories

# %%
df_orders_translated.shape
# Out:
# (118146, 44)

# %% [markdown]
# Delete the non-English version of product category column.

# %%
df_orders_translated = df_orders_translated.drop('product_category_name', axis = 1)

# %%
df_orders_translated.shape
# Out:
# (118146, 43)

# %% [markdown]
# By now we have all the data in one dataframe, we can move to the next step.

# %% [markdown]
# ##### Clean all dataframes for duplicated and missing data and impute data if applicable

# %% [markdown]
# In our journey to get all dataframes together in our final dataframe `df_orders_translated` we have seen some issues that we saved dealing with for this stage of our data processing:
# - There are some orders with no corresponding customer and shipment data because their 'order_status' has been been either canceled or unshipped etc...
# - Some orders have more than one review for the same customer
# - Others?

# %%
df_orders_translated.sample()
# Out:
#                                order_id                         review_id  \
# 23035  73e85a295c3028a2283eb8182a8ac56b  f4264ec5bff13e774e78dc454da3e957
#
#                             customer_id order_status order_purchase_timestamp  \
# 23035  6d75b739e1547399c38335db5a099405    delivered      2018-07-30 15:43:54
#
#          order_approved_at order_delivered_carrier_date  \
# 23035  2018-08-02 13:42:54          2018-07-31 12:57:00
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 23035           2018-08-27 21:54:40           2018-08-22 00:00:00
#
#        order_item_id                        product_id  \
# 23035            1.0  450c25d98ed6923154a934554475bf13
#
#                               seller_id  shipping_limit_date  price  \
# 23035  dbdd0ec73a4817971d962698f2fea022  2018-08-02 18:30:46  399.0
#
#        freight_value  payment_sequential payment_type  payment_installments  \
# 23035         144.29                 1.0  credit_card                   1.0
#
#        payment_value                customer_unique_id  \
# 23035         543.29  4d96714bb58abb631a3752375807bbc1
#
#        customer_zip_code_prefix customer_city customer_state  review_score  \
# 23035                      6458       barueri             SP             1
#
#       review_comment_title  \
# 23035       nao entregaram
#
#                                                                                            review_comment_message  \
# 23035  Ja e a segunda encomenda que não chega na data prevista. A anterior demorou muito e essa ainda não chegou
#
#       review_creation_date review_answer_timestamp  product_name_lenght  \
# 23035  2018-08-24 00:00:00     2018-08-24 17:18:06                 60.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 23035                      1946.0                 4.0           19150.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 23035               87.0               76.0              16.0
#
#        seller_zip_code_prefix seller_city seller_state  \
# 23035                 60710.0   fortaleza           CE
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 23035                -23.491277                -46.825905
#
#        seller_geolocation_lat  seller_geolocation_lng  \
# 23035               -3.786627              -38.567945
#
#       product_category_name_english
# 23035                 health_beauty

# %% [markdown]
# Let us tackle these issues one by one, starting off by the empty orders.

# %%
df_orders_translated[df_orders_translated['order_status'] != 'delivered'].sample(3)
# Out:
#                                order_id                         review_id  \
# 48856  6db84e80e54c938d5112dbdd6494b7f4  6df890a527e1fb392a4a84ab46149871
# 73967  123e27a1a4d0b2481d8618ac3dff7d4e  a87c19be40ccbb6551217e26332a1bbc
# 63077  59fecfd658937396ab6180c0b9a99a89  cea9dc44e77e1d293ba2d3f70ce8974f
#
#                             customer_id order_status order_purchase_timestamp  \
# 48856  18f2f5c1d2fea458573243db3cf88810     invoiced      2018-05-08 14:09:19
# 73967  1fe4c3902c5bd6510a869b3d4fd3843b     canceled      2016-10-08 12:44:32
# 63077  bd3a17ff830fe6350a15f97c540fc81e      shipped      2017-12-15 14:25:41
#
#          order_approved_at order_delivered_carrier_date  \
# 48856  2018-05-08 14:30:36                          NaN
# 73967  2016-10-18 15:19:08                          NaN
# 63077  2017-12-16 02:35:28          2017-12-19 21:48:58
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 48856                           NaN           2018-05-18 00:00:00
# 73967                           NaN           2016-11-18 00:00:00
# 63077                           NaN           2018-01-10 00:00:00
#
#        order_item_id                        product_id  \
# 48856            1.0  64976272fa76578e7bb56f6d6d942ef6
# 73967            NaN                               NaN
# 63077            1.0  612be997cd3154e32e1e585d478571b1
#
#                               seller_id  shipping_limit_date  price  \
# 48856  06e5eefc71ec47ae763c5c6f8db7064f  2018-05-14 14:30:06  339.9
# 73967                               NaN                  NaN    NaN
# 63077  977f9f63dd360c2a32ece2f93ad6d306  2017-12-21 02:35:28  128.8
#
#        freight_value  payment_sequential payment_type  payment_installments  \
# 48856           9.56                 1.0  credit_card                   1.0
# 73967            NaN                 1.0  credit_card                  10.0
# 63077          43.13                 1.0       boleto                   1.0
#
#        payment_value                customer_unique_id  \
# 48856          50.31  3dab7fa08366df68b2addc01b7614e70
# 73967         221.84  123ecbb4fb560cff85dd1072dd0a613d
# 63077         171.93  49febe048a36ba9a2b5212478c270358
#
#        customer_zip_code_prefix   customer_city customer_state  review_score  \
# 48856                     93265          esteio             RS             2
# 73967                     22421  rio de janeiro             RJ             1
# 63077                      6823  embu das artes             SP             1
#
#        review_comment_title  \
# 48856  Não recebi o produto
# 73967                   NaN
# 63077                   NaN
#
#                                                                                                                                                                                   review_comment_message  \
# 48856                                                                                                      Não recebi o produto, e tento entrar em contato e não consigo sair do atendimento automático
# 73967  Fiquei extremamente desapontada. Comprei 2 bonecos pelo site e duas semanas depois a compra cancelada por falta do produto. Perdi a oportunidade de comprar em outra loja e o produto se esgotou.
# 63077                                                                                                                                                                                                NaN
#
#       review_creation_date review_answer_timestamp  product_name_lenght  \
# 48856  2018-05-20 00:00:00     2018-05-20 13:42:56                 58.0
# 73967  2016-11-20 00:00:00     2016-11-20 11:35:00                  NaN
# 63077  2018-01-13 00:00:00     2018-01-13 11:43:43                 51.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 48856                      1859.0                 3.0             150.0
# 73967                         NaN                 NaN               NaN
# 63077                       513.0                 1.0           18900.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 48856               17.0                7.0              17.0
# 73967                NaN                NaN               NaN
# 63077               62.0               35.0              52.0
#
#        seller_zip_code_prefix   seller_city seller_state  \
# 48856                 91350.0  porto alegre           RS
# 73967                     NaN           NaN          NaN
# 63077                 14910.0     tabatinga           SP
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 48856                -29.852319                -51.170153
# 73967                -22.982140                -43.206875
# 63077                -23.669873                -46.802043
#
#        seller_geolocation_lat  seller_geolocation_lng  \
# 48856              -30.015528              -51.162708
# 73967                     NaN                     NaN
# 63077              -21.737063              -48.687601
#
#       product_category_name_english
# 48856     construction_tools_safety
# 73967                           NaN
# 63077                          baby

# %%
df_orders_translated[df_orders_translated['order_status'] != 'delivered'].shape
# Out:
# (3284, 43)

# %% [markdown]
# hmmm, how many order_state do we have?

# %%
df_orders_translated['order_status'].value_counts()
# Out:
# delivered      114862
# shipped          1168
# canceled          730
# unavailable       638
# invoiced          372
# processing        370
# created             3
# approved            3
# Name: order_status, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.scatter(df_orders_translated['order_status'], df_orders_translated['product_category_name_english'].isna())
plt.show()

# %%
df_orders_translated[df_orders_translated['order_status'] == 'delivered'].shape[0]/ df_orders_translated.shape[0] * 100
# Out:
# 97.22038833307941

# %% [markdown]
# We can see that orders with delivered status represent about 97% of all orders. As the dates for these orders are Null we can safely delete these order entries as they represent less than 3% of the data.

# %%
df_orders_translated = df_orders_translated[df_orders_translated['order_status'] == 'delivered']

# %%
df_orders_translated.shape
# Out:
# (114862, 43)

# %% [markdown]
# Duplicates?

# %%
df_orders_translated.duplicated().any()
# Out:
# False

# %%
df_orders_translated.transpose().duplicated().any()
# Out:
# False

# %% [markdown]
# There are no either duplicated rows nor duplicated column on our dataframe.

# %% [markdown]
# Let us look at Null data.

# %% [markdown]
#  Get the dataframe summary:

# %%
df_orders_translated.describe().transpose()
# Out:
#                                count          mean           std          min  \
# order_item_id               114862.0      1.194607      0.685732     1.000000
# price                       114862.0    119.772174    181.422029     0.850000
# freight_value               114862.0     19.974091     15.703281     0.000000
# payment_sequential          114859.0      1.091564      0.688852     1.000000
# payment_installments        114859.0      2.937837      2.773738     0.000000
# payment_value               114859.0    171.255856    263.764568     0.000000
# customer_zip_code_prefix    114862.0  35085.104064  29874.422091  1003.000000
# review_score                114862.0      4.080488      1.347659     1.000000
# product_name_lenght         113236.0     48.804665     10.015609     5.000000
# product_description_lenght  113236.0    784.755793    650.268562     4.000000
# product_photos_qty          113236.0      2.206842      1.718225     1.000000
# product_weight_g            114842.0   2103.556721   3769.464735     0.000000
# product_length_cm           114842.0     30.227051     16.113012     7.000000
# product_height_cm           114842.0     16.571995     13.417303     2.000000
# product_width_cm            114842.0     23.059490     11.727611     6.000000
# seller_zip_code_prefix      114862.0  24463.485478  27596.646909  1001.000000
# customer_geolocation_lat    114560.0    -21.246355      5.553769   -33.689948
# customer_geolocation_lng    114560.0    -46.207349      4.039503   -72.668881
# seller_geolocation_lat      114601.0    -22.795308      2.697001   -32.079231
# seller_geolocation_lng      114601.0    -47.239956      2.340550   -63.893565
#
#                                      25%           50%           75%  \
# order_item_id                   1.000000      1.000000      1.000000
# price                          39.900000     74.900000    132.900000
# freight_value                  13.080000     16.280000     21.150000
# payment_sequential              1.000000      1.000000      1.000000
# payment_installments            1.000000      2.000000      4.000000
# payment_value                  60.720000    108.000000    188.690000
# customer_zip_code_prefix    11250.000000  24310.000000  58884.000000
# review_score                    4.000000      5.000000      5.000000
# product_name_lenght            42.000000     52.000000     57.000000
# product_description_lenght    346.000000    600.000000    983.000000
# product_photos_qty              1.000000      1.000000      3.000000
# product_weight_g              300.000000    700.000000   1800.000000
# product_length_cm              18.000000     25.000000     38.000000
# product_height_cm               8.000000     13.000000     20.000000
# product_width_cm               15.000000     20.000000     30.000000
# seller_zip_code_prefix       6429.000000  13660.000000  28035.000000
# customer_geolocation_lat      -23.591520    -22.928999    -20.196980
# customer_geolocation_lng      -48.112804    -46.632926    -43.659990
# seller_geolocation_lat        -23.607473    -23.425556    -21.757321
# seller_geolocation_lng        -48.829744    -46.753595    -46.518679
#
#                                      max
# order_item_id                  21.000000
# price                        6735.000000
# freight_value                 409.680000
# payment_sequential             26.000000
# payment_installments           24.000000
# payment_value               13664.080000
# customer_zip_code_prefix    99980.000000
# review_score                    5.000000
# product_name_lenght            76.000000
# product_description_lenght   3992.000000
# product_photos_qty             20.000000
# product_weight_g            40425.000000
# product_length_cm             105.000000
# product_height_cm             105.000000
# product_width_cm              118.000000
# seller_zip_code_prefix      99730.000000
# customer_geolocation_lat       42.184003
# customer_geolocation_lng       -8.723762
# seller_geolocation_lat         -2.501242
# seller_geolocation_lng        -34.855616

# %% [markdown]
# Ok, so an average order would have a price of 120, fright value of 20 (14% of the total cost), 3 installments, review score of 4, name and description lengths of 48 and 785 characters, 2 images, weights around 2 Kg, 30 X 17 X 23 cm in size.
#
# It is striking to see that the price for some items went as high as 6735 compared to the average of 120, however this seems to be an outlier as the price std is 182.
#
# Also, the looking at the payment installments, the average buyer buys the product in ~ 3 installments.
#
# As for the score, an average of 4 out of 5 is high but is not surprising.
#
# It is interesting to see that most orders / products had 2 images only. It is also interesting to see that the average weight is around 2 Kg, no wonder that average cost of fright is ~14% of the total item cost - fright inclusive.
#
# Looking at the mean customers and the sellers geolocations, it appears that they are centered differently, which makes sense if the sellers are centered around the Brazilian capital while the customers are scattered around the country.

# %% [markdown]
# The Graph below shows the missing values in each column of our dataframe (be reminded that few steps back we got rid of most of the Null data row-wise).The dashed vertical line represents the 3% limit of missing data. It is clear that the data is in good shape as the majority of columns are only missing a far lower percentage than 3%. some a lit close and off course with the exception of the review title and review message columns that are missing more than 60 percent of the data. It will be wise to omit these two columns.

# %%
plt.figure(figsize=(12, 18))
plt.barh( df_orders_translated.columns.tolist(), df_orders_translated.isna().sum().tolist())
plt.axvline((df_orders_translated.shape[0]*0.03), color='k', linestyle='dashed', linewidth=1)
plt.show()

# %% [markdown]
# Remove columns:'review_comment_title','review_comment_message'

# %%
df_orders_translated = df_orders_translated.drop(['review_comment_title','review_comment_message'], axis = 1)

# %%
df_orders_translated.shape, print('review_comment_title and review_comment_message columns removed.')
# Out:
# review_comment_title and review_comment_message columns removed.
# ((114862, 41), None)

# %% [markdown]
# As of the other columns that have null values, let us look at them one by one and see whether we need to delete the respective Null rows or impute them if necessary and possible.

# %%
df_orders_translated.isna().sum()
# Out:
# order_id                            0
# review_id                           0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date        2
# order_delivered_customer_date       8
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# review_score                        0
# review_creation_date                0
# review_answer_timestamp             0
# product_name_lenght              1626
# product_description_lenght       1626
# product_photos_qty               1626
# product_weight_g                   20
# product_length_cm                  20
# product_height_cm                  20
# product_width_cm                   20
# seller_zip_code_prefix              0
# seller_city                         0
# seller_state                        0
# customer_geolocation_lat          302
# customer_geolocation_lng          302
# seller_geolocation_lat            261
# seller_geolocation_lng            261
# product_category_name_english    1649
# dtype: int64

# %%
df_orders_translated[df_orders_translated['product_name_lenght'].isna()].sample(3)
# Out:
#                                order_id                         review_id  \
# 45819  5312f3d56a531aaf51a7b9b3e38905cf  bebc43af8958c47f3cbb8a6c0a1834bd
# 99509  99d4cf1fbaf4104549feed3c138f63f7  6c3c9ada6c8e944efcbfaf633e003248
# 38280  0de497b1f069927c15c241a833bb67d0  c90cd8ac72188db11d80723b01e175d1
#
#                             customer_id order_status order_purchase_timestamp  \
# 45819  e66cf38a4613e6c515fa66440545edfd    delivered      2017-11-27 21:54:52
# 99509  a0ba455ec2854970e286ce33e4823416    delivered      2018-01-25 22:32:50
# 38280  49a385b4c7bfe2a0c2e12220bb169dab    delivered      2017-07-11 11:56:29
#
#          order_approved_at order_delivered_carrier_date  \
# 45819  2017-11-27 22:17:48          2017-12-04 11:09:34
# 99509  2018-01-25 22:56:57          2018-01-29 17:27:06
# 38280  2017-07-11 12:23:45          2017-07-14 17:51:37
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 45819           2017-12-05 18:03:14           2017-12-18 00:00:00
# 99509           2018-02-08 23:51:53           2018-02-23 00:00:00
# 38280           2017-07-26 18:43:53           2017-08-04 00:00:00
#
#        order_item_id                        product_id  \
# 45819            1.0  8be128ce3f51211048f4b891e9303381
# 99509            1.0  bb1c86c0b1cd8da99fbd48d798abcca0
# 38280            1.0  b8c2cf7e813b0eb7ec62f7459217b22c
#
#                               seller_id  shipping_limit_date   price  \
# 45819  46dc3b2cc0980fb8ec44634e21d2718e  2017-12-03 22:17:48  259.99
# 99509  f419677537694f0462a91990df6ca44f  2018-01-31 22:56:57   29.95
# 38280  25c5c91f63607446a97b143d2d535d31  2017-07-19 12:23:45  320.00
#
#        freight_value  payment_sequential payment_type  payment_installments  \
# 45819          19.26                 1.0  credit_card                   1.0
# 99509          17.92                 2.0      voucher                   1.0
# 38280          19.49                 1.0  credit_card                   1.0
#
#        payment_value                customer_unique_id  \
# 45819         279.25  ff16d29e19b92c63503939641cb423da
# 99509          11.85  fda1438f0badd2e3724bd6c459e1cf68
# 38280         339.49  7725ee39818a24b0127ee4d6a6fba237
#
#        customer_zip_code_prefix     customer_city customer_state  \
# 45819                     28800        rio bonito             RJ
# 99509                     44052  feira de santana             BA
# 38280                      4363         sao paulo             SP
#
#        review_score review_creation_date review_answer_timestamp  \
# 45819             5  2017-12-06 00:00:00     2017-12-07 23:31:01
# 99509             3  2018-02-09 00:00:00     2018-02-12 10:38:48
# 38280             5  2017-07-27 00:00:00     2017-07-28 12:14:39
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 45819                  NaN                         NaN                 NaN
# 99509                  NaN                         NaN                 NaN
# 38280                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 45819            3300.0               28.0               20.0
# 99509             830.0               19.0                6.0
# 38280            1800.0               40.0               23.0
#
#        product_width_cm  seller_zip_code_prefix            seller_city  \
# 45819              40.0                 22240.0         rio de janeiro
# 99509              26.0                  9750.0  sao bernardo do campo
# 38280              13.0                 35680.0                 itauna
#
#       seller_state  customer_geolocation_lat  customer_geolocation_lng  \
# 45819           RJ                -22.711928                -42.630041
# 99509           SP                -12.244609                -38.943747
# 38280           MG                -23.646505                -46.666226
#
#        seller_geolocation_lat  seller_geolocation_lng  \
# 45819              -22.935263              -43.187264
# 99509              -23.688119              -46.553222
# 38280              -20.077863              -44.576134
#
#       product_category_name_english
# 45819                           NaN
# 99509                           NaN
# 38280                           NaN

# %% [markdown]
# Checking the instances where the product_name_lenght, product_description_lenght, and product_photos_qt are Null, it appears to be a sort of corruption in the data as it is unlikely to get products sold without at least a name. These columns will surely not be removed later, so it will be wise to remove the Null-value instances from the dataframe as they represent less that ~1% of the instances.

# %%
df_orders_translated = df_orders_translated[~df_orders_translated['product_name_lenght'].isna()]

# %%
df_orders_translated.shape
# Out:
# (113236, 41)

# %% [markdown]
# Checking the remaining Null values.

# %%
df_orders_translated.T.isna().any().sum()
# Out:
# 606

# %%
df_orders_translated.isna().sum()
# Out:
# order_id                           0
# review_id                          0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                 14
# order_delivered_carrier_date       2
# order_delivered_customer_date      8
# order_estimated_delivery_date      0
# order_item_id                      0
# product_id                         0
# seller_id                          0
# shipping_limit_date                0
# price                              0
# freight_value                      0
# payment_sequential                 3
# payment_type                       3
# payment_installments               3
# payment_value                      3
# customer_unique_id                 0
# customer_zip_code_prefix           0
# customer_city                      0
# customer_state                     0
# review_score                       0
# review_creation_date               0
# review_answer_timestamp            0
# product_name_lenght                0
# product_description_lenght         0
# product_photos_qty                 0
# product_weight_g                   1
# product_length_cm                  1
# product_height_cm                  1
# product_width_cm                   1
# seller_zip_code_prefix             0
# seller_city                        0
# seller_state                       0
# customer_geolocation_lat         297
# customer_geolocation_lng         297
# seller_geolocation_lat           260
# seller_geolocation_lng           260
# product_category_name_english     23
# dtype: int64

# %% [markdown]
# We will go ahead and remove the the rest for the same reason.

# %%
df_orders_translated = df_orders_translated[~df_orders_translated.T.isna().any()]

# %%
df_orders_translated.shape
# Out:
# (112630, 41)

# %% [markdown]
# Now let us look at the columns datatypes.

# %%
df_orders_translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112630 entries, 0 to 118145
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112630 non-null  object
#  1   review_id                      112630 non-null  object
#  2   customer_id                    112630 non-null  object
#  3   order_status                   112630 non-null  object
#  4   order_purchase_timestamp       112630 non-null  object
#  5   order_approved_at              112630 non-null  object
#  6   order_delivered_carrier_date   112630 non-null  object
#  7   order_delivered_customer_date  112630 non-null  object
#  8   order_estimated_delivery_date  112630 non-null  object
#  9   order_item_id                  112630 non-null  float64
#  10  product_id                     112630 non-null  object
#  11  seller_id                      112630 non-null  object
#  12  shipping_limit_date            112630 non-null  object
#  13  price                          112630 non-null  float64
#  14  freight_value                  112630 non-null  float64
#  15  payment_sequential             112630 non-null  float64
#  16  payment_type                   112630 non-null  object
#  17  payment_installments           112630 non-null  float64
#  18  payment_value                  112630 non-null  float64
#  19  customer_unique_id             112630 non-null  object
#  20  customer_zip_code_prefix       112630 non-null  int64
#  21  customer_city                  112630 non-null  object
#  22  customer_state                 112630 non-null  object
#  23  review_score                   112630 non-null  int64
#  24  review_creation_date           112630 non-null  object
#  25  review_answer_timestamp        112630 non-null  object
#  26  product_name_lenght            112630 non-null  float64
#  27  product_description_lenght     112630 non-null  float64
#  28  product_photos_qty             112630 non-null  float64
#  29  product_weight_g               112630 non-null  float64
#  30  product_length_cm              112630 non-null  float64
#  31  product_height_cm              112630 non-null  float64
#  32  product_width_cm               112630 non-null  float64
#  33  seller_zip_code_prefix         112630 non-null  float64
#  34  seller_city                    112630 non-null  object
#  35  seller_state                   112630 non-null  object
#  36  customer_geolocation_lat       112630 non-null  float64
#  37  customer_geolocation_lng       112630 non-null  float64
#  38  seller_geolocation_lat         112630 non-null  float64
#  39  seller_geolocation_lng         112630 non-null  float64
#  40  product_category_name_english  112630 non-null  object
# dtypes: float64(18), int64(2), object(21)
# memory usage: 36.1+ MB

# %%
df_orders_translated.head(1)
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-10-06 11:07:15  29.99           8.72                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
#
#    customer_zip_code_prefix customer_city customer_state  review_score  \
# 0                      3149     sao paulo             SP             4
#
#   review_creation_date review_answer_timestamp  product_name_lenght  \
# 0  2017-10-11 00:00:00     2017-10-12 03:43:48                 40.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               19.0                8.0              13.0
#
#    seller_zip_code_prefix seller_city seller_state  customer_geolocation_lat  \
# 0                  9350.0        maua           SP                -23.576983
#
#    customer_geolocation_lng  seller_geolocation_lat  seller_geolocation_lng  \
# 0                -46.587161              -23.680729              -46.444238
#
#   product_category_name_english
# 0                    housewares

# %% [markdown]
# There is some work to be done here, there are several columns that need data type change:
# - All date and datatime columns need to be changed:
#     - order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, shipping_limit_date, review_creation_date, and review_answer_timestamp
# - Many integer data type like columns has float data type that needs to be changes:
#     - order_item_id, payment_sequential, payment_installments, product_photos_qty, customer_zip_code_prefix, and seller_zip_code_prefix

# %%
df_list = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 
           'order_estimated_delivery_date', 'shipping_limit_date', 'review_creation_date', 'review_answer_timestamp']
df_orders_translated[df_list] = df_orders_translated[df_list].astype('datetime64[ns]')

# %%
# We will leave customer_zip_code_prefix, and seller_zip_code_prefix our for now as they will be treated differentlly
df_list = ['order_item_id', 'payment_sequential', 'payment_installments', 'product_photos_qty']
df_orders_translated[df_list] = df_orders_translated[df_list].astype(int, errors='ignore')

# %%
df_orders_translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112630 entries, 0 to 118145
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112630 non-null  object
#  1   review_id                      112630 non-null  object
#  2   customer_id                    112630 non-null  object
#  3   order_status                   112630 non-null  object
#  4   order_purchase_timestamp       112630 non-null  datetime64[ns]
#  5   order_approved_at              112630 non-null  datetime64[ns]
#  6   order_delivered_carrier_date   112630 non-null  datetime64[ns]
#  7   order_delivered_customer_date  112630 non-null  datetime64[ns]
#  8   order_estimated_delivery_date  112630 non-null  datetime64[ns]
#  9   order_item_id                  112630 non-null  int32
#  10  product_id                     112630 non-null  object
#  11  seller_id                      112630 non-null  object
#  12  shipping_limit_date            112630 non-null  datetime64[ns]
#  13  price                          112630 non-null  float64
#  14  freight_value                  112630 non-null  float64
#  15  payment_sequential             112630 non-null  int32
#  16  payment_type                   112630 non-null  object
#  17  payment_installments           112630 non-null  int32
#  18  payment_value                  112630 non-null  float64
#  19  customer_unique_id             112630 non-null  object
#  20  customer_zip_code_prefix       112630 non-null  int64
#  21  customer_city                  112630 non-null  object
#  22  customer_state                 112630 non-null  object
#  23  review_score                   112630 non-null  int64
#  24  review_creation_date           112630 non-null  datetime64[ns]
#  25  review_answer_timestamp        112630 non-null  datetime64[ns]
#  26  product_name_lenght            112630 non-null  float64
#  27  product_description_lenght     112630 non-null  float64
#  28  product_photos_qty             112630 non-null  int32
#  29  product_weight_g               112630 non-null  float64
#  30  product_length_cm              112630 non-null  float64
#  31  product_height_cm              112630 non-null  float64
#  32  product_width_cm               112630 non-null  float64
#  33  seller_zip_code_prefix         112630 non-null  float64
#  34  seller_city                    112630 non-null  object
#  35  seller_state                   112630 non-null  object
#  36  customer_geolocation_lat       112630 non-null  float64
#  37  customer_geolocation_lng       112630 non-null  float64
#  38  seller_geolocation_lat         112630 non-null  float64
#  39  seller_geolocation_lng         112630 non-null  float64
#  40  product_category_name_english  112630 non-null  object
# dtypes: datetime64[ns](8), float64(14), int32(4), int64(2), object(13)
# memory usage: 34.4+ MB

# %% [markdown]
# ##### Transform the data into a customer level  & Omit all irrelevant features

# %% [markdown]
# Now, we want to get our dataframe into the customer level instead of the order level. First we need to remember that we may have many rows with identical customer_id due to:
# - some customers may have ordered more than one item / order
# - Some orders have more than one shipment
#
# That means we need to find a way of getting the data into the customer level in the best way possible.
# So let us have a look again at the dataframe from the perspective of customer_id.

# %%
df_orders_translated['customer_id'].value_counts()
# Out:
# 270c23a11d024a44c896d1894b261a83    63
# 13aa59158da63ba0e93ec6ac2c07aacb    38
# 92cd3ec6e2d643d4ebd0e3d6238f69e2    26
# d22f25a9fadfb1abbc2e29395b1239f4    24
# 6ee2f17e3b6c33d6a9557f280edd2925    24
#                                     ..
# 37477516d7b6f959ce137f49f1842a72     1
# e53d099c01ad635b7dca18573d4ab1ad     1
# fd07331c4101d0fdb0a32655958da8d5     1
# 74286e84c53dc33b9ea00c5b20274a5e     1
# edb027a75a1449115f6b43211ae02a24     1
# Name: customer_id, Length: 93996, dtype: int64

# %%
print(f' Orders with unique customers represent {(df_orders_translated["customer_id"].nunique()/df_orders_translated.shape[0] * 100):2.2f} % of the total orders.')
# Out:
#  Orders with unique customers represent 83.46 % of the total orders.

# %%
print(f' Single order instance customers represent {((df_orders_translated["customer_id"].value_counts() < 2).sum()/df_orders_translated.shape[0] * 100):2.2f} % of the total orders.')
# Out:
#  Single order instance customers represent 72.54 % of the total orders.

# %%
df_orders_translated['customer_id'].unique()
# Out:
# array(['9ef432eb6251297304e76186b10a928d',
#        'b0830fb4747a6c6d20dea0b8c802d7ef',
#        '41ce2a54c0b03bf3443c3d931a367089', ...,
#        '1aa71eb042121263aafbe80c1b562c9c',
#        'b331b74b18dc79bcdf6532d51e1637c1',
#        'edb027a75a1449115f6b43211ae02a24'], dtype=object)

# %% [markdown]
# There are around 72% of of orders that have been undertaken by single time buyers (or rather single order instance) while the rest of 28% have been undertaken by more-than-one-time buyers. This means that the frequent buyers subcategory is a significant one (frequent buyers are those buying more than once in the lifetime of this dataset).

# %%
len(df_orders_translated['customer_id'].unique())
# Out:
# 93996

# %% [markdown]
# Now, we need to reduce our dataframe to 93,996 customer. This is straight forward for all the so-called single buyers instances as each order instance represents a customer instance. The part that need some manipulation is the 28% portion of the dataframe.
#
# To reduce more than one order instance into one customer instance, we need to examine our columns again and find a way to summarize the instances without losing information, or rather retain as much information as possible.

# %% [markdown]
# It will be wise at this stage to drop *some* unnecessary columns that are either represented by other columns or do not seem to be relevant.

# %% [markdown]
# Before moving on, it will be helping if we rearrange some columns, namely:
# - transform the dimensions into volume
# - transform the dates into periods

# %%
df_orders_translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112630 entries, 0 to 118145
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112630 non-null  object
#  1   review_id                      112630 non-null  object
#  2   customer_id                    112630 non-null  object
#  3   order_status                   112630 non-null  object
#  4   order_purchase_timestamp       112630 non-null  datetime64[ns]
#  5   order_approved_at              112630 non-null  datetime64[ns]
#  6   order_delivered_carrier_date   112630 non-null  datetime64[ns]
#  7   order_delivered_customer_date  112630 non-null  datetime64[ns]
#  8   order_estimated_delivery_date  112630 non-null  datetime64[ns]
#  9   order_item_id                  112630 non-null  int32
#  10  product_id                     112630 non-null  object
#  11  seller_id                      112630 non-null  object
#  12  shipping_limit_date            112630 non-null  datetime64[ns]
#  13  price                          112630 non-null  float64
#  14  freight_value                  112630 non-null  float64
#  15  payment_sequential             112630 non-null  int32
#  16  payment_type                   112630 non-null  object
#  17  payment_installments           112630 non-null  int32
#  18  payment_value                  112630 non-null  float64
#  19  customer_unique_id             112630 non-null  object
#  20  customer_zip_code_prefix       112630 non-null  int64
#  21  customer_city                  112630 non-null  object
#  22  customer_state                 112630 non-null  object
#  23  review_score                   112630 non-null  int64
#  24  review_creation_date           112630 non-null  datetime64[ns]
#  25  review_answer_timestamp        112630 non-null  datetime64[ns]
#  26  product_name_lenght            112630 non-null  float64
#  27  product_description_lenght     112630 non-null  float64
#  28  product_photos_qty             112630 non-null  int32
#  29  product_weight_g               112630 non-null  float64
#  30  product_length_cm              112630 non-null  float64
#  31  product_height_cm              112630 non-null  float64
#  32  product_width_cm               112630 non-null  float64
#  33  seller_zip_code_prefix         112630 non-null  float64
#  34  seller_city                    112630 non-null  object
#  35  seller_state                   112630 non-null  object
#  36  customer_geolocation_lat       112630 non-null  float64
#  37  customer_geolocation_lng       112630 non-null  float64
#  38  seller_geolocation_lat         112630 non-null  float64
#  39  seller_geolocation_lng         112630 non-null  float64
#  40  product_category_name_english  112630 non-null  object
# dtypes: datetime64[ns](8), float64(14), int32(4), int64(2), object(13)
# memory usage: 34.4+ MB

# %% [markdown]
# ##### Transform dimensions into volume

# %%
# Transform dimensions into volum3 cm^3
df_orders_translated['order_volume'] = df_orders_translated['product_length_cm'] * \
df_orders_translated['product_height_cm'] * \
df_orders_translated['product_width_cm']

# %%
# drop the three columns
df_orders_translated.drop(columns = ['product_length_cm', 'product_height_cm', 'product_width_cm'], inplace = True)

# %% [markdown]
# ##### Transform the dates into periods

# %% [markdown]
# We will use the purchase date `order_purchase_timestamp` as the reference and calculate the period in days for other columns to the reference. It seems that the `order_approved_at` is always few hour after the reference which will lead to a Zero-value but we will check this after the transformation.

# %% [markdown]
# The columns are: \
# order_purchase_timestamp
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# order_estimated_delivery_date
# shipping_limit_date
# review_creation_date
# review_answer_timestamp

# %%
# transform the dates into periods
date_list = ['order_purchase_timestamp',
'order_approved_at',
'order_delivered_carrier_date',
'order_delivered_customer_date',
'order_estimated_delivery_date',
'shipping_limit_date',
'review_creation_date',
'review_answer_timestamp']

df_orders_translated[date_list] = df_orders_translated[date_list].apply\
(lambda x: (pd.to_datetime(x) - pd.to_datetime(df_orders_translated['order_purchase_timestamp']))\
 //np.timedelta64(1, 'D'))

# %%
# delete the refernce columns
df_orders_translated.drop(columns = 'order_purchase_timestamp', inplace = True)

# %%
df_orders_translated.sample(2)
# Out:
#                                order_id                         review_id  \
# 30008  5eeb092ebe54bc6f635f566588d2e908  23e7efab08692246c8e0585d87e1fc1a
# 36458  387d33b2be3d1d8dd063941d1b57d3fb  3ffed17f5010b9c6d33706b790732482
#
#                             customer_id order_status  order_approved_at  \
# 30008  b67e09339b0e590a3e6dd7c502badc8f    delivered                  0
# 36458  a3631211bc272aaab72fad2aa11125f9    delivered                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 30008                             3                              8
# 36458                            27                             32
#
#        order_estimated_delivery_date  order_item_id  \
# 30008                             25              1
# 36458                             40              2
#
#                              product_id                         seller_id  \
# 30008  7e93d6b6ef018d488da72952ce48fb9a  46dc3b2cc0980fb8ec44634e21d2718e
# 36458  f3fddc967610429e8ee3cf2d089817bf  a2e874074c877c5a05abae80ad6e488f
#
#        shipping_limit_date   price  freight_value  payment_sequential  \
# 30008                    4  269.99          29.27                   1
# 36458                   27    7.96          11.85                   1
#
#       payment_type  payment_installments  payment_value  \
# 30008  credit_card                     4         299.26
# 36458  credit_card                     2          39.62
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 30008  168b650549ccf26c55e7040bce0ad370                     99060
# 36458  1abb39330620468379baa8d035a9cca2                      4302
#
#       customer_city customer_state  review_score  review_creation_date  \
# 30008   passo fundo             RS             5                     9
# 36458     sao paulo             SP             1                    32
#
#        review_answer_timestamp  product_name_lenght  \
# 30008                       10                 53.0
# 36458                       33                 31.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 30008                       735.0                   2            2800.0
# 36458                       137.0                   1             150.0
#
#        seller_zip_code_prefix            seller_city seller_state  \
# 30008                 22240.0         rio de janeiro           RJ
# 36458                 15070.0  sao jose do rio preto           SP
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 30008                -28.275845                -52.375008
# 36458                -23.621975                -46.636790
#
#        seller_geolocation_lat  seller_geolocation_lng  \
# 30008              -22.935263              -43.187264
# 36458              -20.818007              -49.362320
#
#       product_category_name_english  order_volume
# 30008                sports_leisure       20880.0
# 36458                    housewares        2592.0

# %% [markdown]
# Let us also delete the following columns as they are not needed any more:
# - `order_status`: we deleted all non-delivered rows earlier
# - `customer_zip_code_prefix`,  `seller_zip_code_prefix`, `customer_city`, `customer_state`, `seller_city`, `seller_state`: we have Lat and Long in the dataframe instead
# - `seller_geolocation_lat`, `seller_geolocation_lng`: this will make reducing the dataframe down to the customer level easier

# %%
# delete columns
to_delete = ['order_status', 'customer_zip_code_prefix', 'seller_zip_code_prefix', \
            'customer_city', 'customer_state', 'seller_city', 'seller_state', \
             'seller_geolocation_lat', 'seller_geolocation_lng']
df_orders_translated.drop(columns = to_delete, inplace = True)

# %%
df_orders_translated.shape
# Out:
# (112630, 29)

# %%
df_orders_translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112630 entries, 0 to 118145
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112630 non-null  object
#  1   review_id                      112630 non-null  object
#  2   customer_id                    112630 non-null  object
#  3   order_approved_at              112630 non-null  int64
#  4   order_delivered_carrier_date   112630 non-null  int64
#  5   order_delivered_customer_date  112630 non-null  int64
#  6   order_estimated_delivery_date  112630 non-null  int64
#  7   order_item_id                  112630 non-null  int32
#  8   product_id                     112630 non-null  object
#  9   seller_id                      112630 non-null  object
#  10  shipping_limit_date            112630 non-null  int64
#  11  price                          112630 non-null  float64
#  12  freight_value                  112630 non-null  float64
#  13  payment_sequential             112630 non-null  int32
#  14  payment_type                   112630 non-null  object
#  15  payment_installments           112630 non-null  int32
#  16  payment_value                  112630 non-null  float64
#  17  customer_unique_id             112630 non-null  object
#  18  review_score                   112630 non-null  int64
#  19  review_creation_date           112630 non-null  int64
#  20  review_answer_timestamp        112630 non-null  int64
#  21  product_name_lenght            112630 non-null  float64
#  22  product_description_lenght     112630 non-null  float64
#  23  product_photos_qty             112630 non-null  int32
#  24  product_weight_g               112630 non-null  float64
#  25  customer_geolocation_lat       112630 non-null  float64
#  26  customer_geolocation_lng       112630 non-null  float64
#  27  product_category_name_english  112630 non-null  object
#  28  order_volume                   112630 non-null  float64
# dtypes: float64(9), int32(4), int64(8), object(8)
# memory usage: 24.1+ MB

# %% [markdown]
# Let us take few examples of these instances with a common customer_id starting by the most frequent buyer '270c23a11d024a44c896d1894b261a83' with a record of 63 instances, and let us analyze it:

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83']
# Out:
#                                order_id                         review_id  \
# 84816  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84817  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84818  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84819  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84820  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# ...                                 ...                               ...
# 84874  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84875  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84876  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84877  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84878  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84816  270c23a11d024a44c896d1894b261a83                  0
# 84817  270c23a11d024a44c896d1894b261a83                  0
# 84818  270c23a11d024a44c896d1894b261a83                  0
# 84819  270c23a11d024a44c896d1894b261a83                  0
# 84820  270c23a11d024a44c896d1894b261a83                  0
# ...                                 ...                ...
# 84874  270c23a11d024a44c896d1894b261a83                  0
# 84875  270c23a11d024a44c896d1894b261a83                  0
# 84876  270c23a11d024a44c896d1894b261a83                  0
# 84877  270c23a11d024a44c896d1894b261a83                  0
# 84878  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84816                             1                              5
# 84817                             1                              5
# 84818                             1                              5
# 84819                             1                              5
# 84820                             1                              5
# ...                             ...                            ...
# 84874                             1                              5
# 84875                             1                              5
# 84876                             1                              5
# 84877                             1                              5
# 84878                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84816                             21              1
# 84817                             21              1
# 84818                             21              1
# 84819                             21              1
# 84820                             21              1
# ...                              ...            ...
# 84874                             21              3
# 84875                             21              3
# 84876                             21              3
# 84877                             21              3
# 84878                             21              3
#
#                              product_id                         seller_id  \
# 84816  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84817  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84818  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84819  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84820  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# ...                                 ...                               ...
# 84874  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84875  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84876  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84877  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84878  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84816                    6  12.99          23.21                  17
# 84817                    6  12.99          23.21                   1
# 84818                    6  12.99          23.21                  13
# 84819                    6  12.99          23.21                  16
# 84820                    6  12.99          23.21                  19
# ...                    ...    ...            ...                 ...
# 84874                    6  83.80           5.12                  15
# 84875                    6  83.80           5.12                  20
# 84876                    6  83.80           5.12                  14
# 84877                    6  83.80           5.12                   9
# 84878                    6  83.80           5.12                   6
#
#       payment_type  payment_installments  payment_value  \
# 84816      voucher                     1          16.70
# 84817      voucher                     1           2.61
# 84818      voucher                     1          16.70
# 84819      voucher                     1          16.70
# 84820      voucher                     1           0.24
# ...            ...                   ...            ...
# 84874      voucher                     1          16.70
# 84875      voucher                     1           4.61
# 84876      voucher                     1          16.70
# 84877      voucher                     1           2.61
# 84878      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84816  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84817  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84818  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84819  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84820  9a736b248f67d166d2fbb006bcb877c3             5                     6
# ...                                 ...           ...                   ...
# 84874  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84875  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84876  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84877  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84878  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84816                        9                 37.0
# 84817                        9                 37.0
# 84818                        9                 37.0
# 84819                        9                 37.0
# 84820                        9                 37.0
# ...                        ...                  ...
# 84874                        9                 56.0
# 84875                        9                 56.0
# 84876                        9                 56.0
# 84877                        9                 56.0
# 84878                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84816                        86.0                   2            1300.0
# 84817                        86.0                   2            1300.0
# 84818                        86.0                   2            1300.0
# 84819                        86.0                   2            1300.0
# 84820                        86.0                   2            1300.0
# ...                           ...                 ...               ...
# 84874                       548.0                   8             450.0
# 84875                       548.0                   8             450.0
# 84876                       548.0                   8             450.0
# 84877                       548.0                   8             450.0
# 84878                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84816                -23.586366                -46.571079
# 84817                -23.586366                -46.571079
# 84818                -23.586366                -46.571079
# 84819                -23.586366                -46.571079
# 84820                -23.586366                -46.571079
# ...                         ...                       ...
# 84874                -23.586366                -46.571079
# 84875                -23.586366                -46.571079
# 84876                -23.586366                -46.571079
# 84877                -23.586366                -46.571079
# 84878                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84816                bed_bath_table       18450.0
# 84817                bed_bath_table       18450.0
# 84818                bed_bath_table       18450.0
# 84819                bed_bath_table       18450.0
# 84820                bed_bath_table       18450.0
# ...                             ...           ...
# 84874                    housewares        6600.0
# 84875                    housewares        6600.0
# 84876                    housewares        6600.0
# 84877                    housewares        6600.0
# 84878                    housewares        6600.0
#
# [63 rows x 29 columns]

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83'].describe().transpose()
# Out:
#                                count          mean           std          min  \
# order_approved_at               63.0      0.000000  0.000000e+00     0.000000
# order_delivered_carrier_date    63.0      1.000000  0.000000e+00     1.000000
# order_delivered_customer_date   63.0      5.000000  0.000000e+00     5.000000
# order_estimated_delivery_date   63.0     21.000000  0.000000e+00    21.000000
# order_item_id                   63.0      2.000000  8.230549e-01     1.000000
# shipping_limit_date             63.0      6.000000  0.000000e+00     6.000000
# price                           63.0     36.593333  3.364827e+01    12.990000
# freight_value                   63.0     17.180000  8.596205e+00     5.120000
# payment_sequential              63.0     11.000000  6.103938e+00     1.000000
# payment_installments            63.0      1.000000  0.000000e+00     1.000000
# payment_value                   63.0      7.681905  7.194057e+00     0.240000
# review_score                    63.0      5.000000  0.000000e+00     5.000000
# review_creation_date            63.0      6.000000  0.000000e+00     6.000000
# review_answer_timestamp         63.0      9.000000  0.000000e+00     9.000000
# product_name_lenght             63.0     43.333333  9.028628e+00    37.000000
# product_description_lenght      63.0    240.000000  2.195382e+02    86.000000
# product_photos_qty              63.0      4.000000  2.851146e+00     2.000000
# product_weight_g                63.0   1016.666667  4.039123e+02   450.000000
# customer_geolocation_lat        63.0    -23.586366  1.074375e-14   -23.586366
# customer_geolocation_lng        63.0    -46.571079  1.432500e-14   -46.571079
# order_volume                    63.0  14500.000000  5.631013e+03  6600.000000
#
#                                        25%           50%           75%  \
# order_approved_at                 0.000000      0.000000      0.000000
# order_delivered_carrier_date      1.000000      1.000000      1.000000
# order_delivered_customer_date     5.000000      5.000000      5.000000
# order_estimated_delivery_date    21.000000     21.000000     21.000000
# order_item_id                     1.000000      2.000000      3.000000
# shipping_limit_date               6.000000      6.000000      6.000000
# price                            12.990000     12.990000     83.800000
# freight_value                     5.120000     23.210000     23.210000
# payment_sequential                6.000000     11.000000     16.000000
# payment_installments              1.000000      1.000000      1.000000
# payment_value                     2.610000      2.610000     16.700000
# review_score                      5.000000      5.000000      5.000000
# review_creation_date              6.000000      6.000000      6.000000
# review_answer_timestamp           9.000000      9.000000      9.000000
# product_name_lenght              37.000000     37.000000     56.000000
# product_description_lenght       86.000000     86.000000    548.000000
# product_photos_qty                2.000000      2.000000      8.000000
# product_weight_g                450.000000   1300.000000   1300.000000
# customer_geolocation_lat        -23.586366    -23.586366    -23.586366
# customer_geolocation_lng        -46.571079    -46.571079    -46.571079
# order_volume                   6600.000000  18450.000000  18450.000000
#
#                                         max
# order_approved_at                  0.000000
# order_delivered_carrier_date       1.000000
# order_delivered_customer_date      5.000000
# order_estimated_delivery_date     21.000000
# order_item_id                      3.000000
# shipping_limit_date                6.000000
# price                             83.800000
# freight_value                     23.210000
# payment_sequential                21.000000
# payment_installments               1.000000
# payment_value                     16.700000
# review_score                       5.000000
# review_creation_date               6.000000
# review_answer_timestamp            9.000000
# product_name_lenght               56.000000
# product_description_lenght       548.000000
# product_photos_qty                 8.000000
# product_weight_g                1300.000000
# customer_geolocation_lat         -23.586366
# customer_geolocation_lng         -46.571079
# order_volume                   18450.000000

# %% [markdown]
# Some striking observations about this buyer:
# - they tend to buy less expensive products compared to the average person of 120
# - although they bought all their orders in one installment and buy inexpensive products, they tended to use an average of 11 different payment methods per order, this is not normal
# - they scored 5 all the time, a very satisfied buyer indeed
# - The products they bought have more weight than average
#
# The question is, for such a buyer, how can we capture this information in one row without distorting the information we have?

# %% [markdown]
# Looking at the dataframe above we can also notice the following:

# %%
df_orders_translated.head()
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 1  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 2  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 3  53cdb2fc8bc7dce0b6741e2150273451  8d5266042046a06655c8db133d120ba5
# 4  47770eb9100c2d0c44946d9cf07ec65d  e73b67b67587f7644d5bd1a52deb1b01
#
#                         customer_id  order_approved_at  \
# 0  9ef432eb6251297304e76186b10a928d                  0
# 1  9ef432eb6251297304e76186b10a928d                  0
# 2  9ef432eb6251297304e76186b10a928d                  0
# 3  b0830fb4747a6c6d20dea0b8c802d7ef                  1
# 4  41ce2a54c0b03bf3443c3d931a367089                  0
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0                             2                              8
# 1                             2                              8
# 2                             2                              8
# 3                             1                             13
# 4                             0                              9
#
#    order_estimated_delivery_date  order_item_id  \
# 0                             15              1
# 1                             15              1
# 2                             15              1
# 3                             19              1
# 4                             26              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0                    4   29.99           8.72                   1
# 1                    4   29.99           8.72                   3
# 2                    4   29.99           8.72                   2
# 3                    5  118.70          22.76                   1
# 4                    5  159.90          19.22                   1
#
#   payment_type  payment_installments  payment_value  \
# 0  credit_card                     1          18.12
# 1      voucher                     1           2.00
# 2      voucher                     1          18.59
# 3       boleto                     1         141.46
# 4  credit_card                     3         179.12
#
#                  customer_unique_id  review_score  review_creation_date  \
# 0  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 1  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 2  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 3  af07308b275d755c9edb36a90c618231             4                    14
# 4  3a653a41f6f9fc3d2a113cf8398680e8             5                     9
#
#    review_answer_timestamp  product_name_lenght  product_description_lenght  \
# 0                        9                 40.0                       268.0
# 1                        9                 40.0                       268.0
# 2                        9                 40.0                       268.0
# 3                       14                 29.0                       178.0
# 4                       14                 46.0                       232.0
#
#    product_photos_qty  product_weight_g  customer_geolocation_lat  \
# 0                   4             500.0                -23.576983
# 1                   4             500.0                -23.576983
# 2                   4             500.0                -23.576983
# 3                   1             400.0                -12.177924
# 4                   1             420.0                -16.745150
#
#    customer_geolocation_lng product_category_name_english  order_volume
# 0                -46.587161                    housewares        1976.0
# 1                -46.587161                    housewares        1976.0
# 2                -46.587161                    housewares        1976.0
# 3                -44.660711                     perfumery        4693.0
# 4                -48.514783                          auto        9576.0

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83']['order_id'].unique()
# Out:
# array(['895ab968e7bb0d5659d16cd74cd1650c'], dtype=object)

# %% [markdown]
# This is one order only!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# This does not look right, let us see the order_item_id column to understand more.

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['order_item_id'].value_counts()
# Out:
# 1    21
# 2    21
# 3    21
# Name: order_item_id, dtype: int64

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['payment_sequential'].value_counts()
# Out:
# 17    3
# 11    3
# 9     3
# 14    3
# 20    3
# 15    3
# 7     3
# 10    3
# 5     3
# 3     3
# 8     3
# 1     3
# 18    3
# 12    3
# 2     3
# 21    3
# 4     3
# 19    3
# 16    3
# 13    3
# 6     3
# Name: payment_sequential, dtype: int64

# %% [markdown]
# It is clear now as to why this customer has 63 records on the dataframe that looked initially to me as 63 possible orders (if we do not consider the order_id column), the reasons are that:
# - the order has been sent in 3 shipments
# - every shipment is associated with 21 payment methods
#
# This sum up to 3 X 21 = 63 records

# %% [markdown]
# Let us confirm this by looking at the product_category_name_english column.

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['product_category_name_english'].value_counts()
# Out:
# bed_bath_table    42
# housewares        21
# Name: product_category_name_english, dtype: int64

# %% [markdown]
# hmmmmm...

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['seller_id'].value_counts()
# Out:
# 822166ed1e47908f7cfb49946d03c726    42
# 3d0cd21d41671c46f82cd11176bf7277    21
# Name: seller_id, dtype: int64

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['order_delivered_customer_date'].value_counts()
# Out:
# 5    63
# Name: order_delivered_customer_date, dtype: int64

# %%
df_orders_translated[df_orders_translated['customer_id'] == 
                     '270c23a11d024a44c896d1894b261a83']['product_id'].value_counts()
# Out:
# ebf9bc6cd600eadd681384e3116fda85    42
# 5ddab10d5e0a23acb99acf56b62b3276    21
# Name: product_id, dtype: int64

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83'].groupby('payment_sequential').apply(display)
# Out:
#                                order_id                         review_id  \
# 84817  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84838  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84859  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84817  270c23a11d024a44c896d1894b261a83                  0
# 84838  270c23a11d024a44c896d1894b261a83                  0
# 84859  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84817                             1                              5
# 84838                             1                              5
# 84859                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84817                             21              1
# 84838                             21              2
# 84859                             21              3
#
#                              product_id                         seller_id  \
# 84817  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84838  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84859  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84817                    6  12.99          23.21                   1
# 84838                    6  12.99          23.21                   1
# 84859                    6  83.80           5.12                   1
#
#       payment_type  payment_installments  payment_value  \
# 84817      voucher                     1           2.61
# 84838      voucher                     1           2.61
# 84859      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84817  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84838  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84859  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84817                        9                 37.0
# 84838                        9                 37.0
# 84859                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84817                        86.0                   2            1300.0
# 84838                        86.0                   2            1300.0
# 84859                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84817                -23.586366                -46.571079
# 84838                -23.586366                -46.571079
# 84859                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84817                bed_bath_table       18450.0
# 84838                bed_bath_table       18450.0
# 84859                    housewares        6600.0
#                                order_id                         review_id  \
# 84823  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84844  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84865  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84823  270c23a11d024a44c896d1894b261a83                  0
# 84844  270c23a11d024a44c896d1894b261a83                  0
# 84865  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84823                             1                              5
# 84844                             1                              5
# 84865                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84823                             21              1
# 84844                             21              2
# 84865                             21              3
#
#                              product_id                         seller_id  \
# 84823  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84844  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84865  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84823                    6  12.99          23.21                   2
# 84844                    6  12.99          23.21                   2
# 84865                    6  83.80           5.12                   2
#
#       payment_type  payment_installments  payment_value  \
# 84823      voucher                     1           2.61
# 84844      voucher                     1           2.61
# 84865      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84823  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84844  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84865  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84823                        9                 37.0
# 84844                        9                 37.0
# 84865                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84823                        86.0                   2            1300.0
# 84844                        86.0                   2            1300.0
# 84865                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84823                -23.586366                -46.571079
# 84844                -23.586366                -46.571079
# 84865                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84823                bed_bath_table       18450.0
# 84844                bed_bath_table       18450.0
# 84865                    housewares        6600.0
#                                order_id                         review_id  \
# 84828  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84849  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84870  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84828  270c23a11d024a44c896d1894b261a83                  0
# 84849  270c23a11d024a44c896d1894b261a83                  0
# 84870  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84828                             1                              5
# 84849                             1                              5
# 84870                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84828                             21              1
# 84849                             21              2
# 84870                             21              3
#
#                              product_id                         seller_id  \
# 84828  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84849  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84870  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84828                    6  12.99          23.21                   3
# 84849                    6  12.99          23.21                   3
# 84870                    6  83.80           5.12                   3
#
#       payment_type  payment_installments  payment_value  \
# 84828      voucher                     1           2.61
# 84849      voucher                     1           2.61
# 84870      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84828  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84849  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84870  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84828                        9                 37.0
# 84849                        9                 37.0
# 84870                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84828                        86.0                   2            1300.0
# 84849                        86.0                   2            1300.0
# 84870                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84828                -23.586366                -46.571079
# 84849                -23.586366                -46.571079
# 84870                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84828                bed_bath_table       18450.0
# 84849                bed_bath_table       18450.0
# 84870                    housewares        6600.0
#                                order_id                         review_id  \
# 84821  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84842  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84863  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84821  270c23a11d024a44c896d1894b261a83                  0
# 84842  270c23a11d024a44c896d1894b261a83                  0
# 84863  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84821                             1                              5
# 84842                             1                              5
# 84863                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84821                             21              1
# 84842                             21              2
# 84863                             21              3
#
#                              product_id                         seller_id  \
# 84821  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84842  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84863  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84821                    6  12.99          23.21                   4
# 84842                    6  12.99          23.21                   4
# 84863                    6  83.80           5.12                   4
#
#       payment_type  payment_installments  payment_value  \
# 84821      voucher                     1           2.61
# 84842      voucher                     1           2.61
# 84863      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84821  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84842  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84863  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84821                        9                 37.0
# 84842                        9                 37.0
# 84863                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84821                        86.0                   2            1300.0
# 84842                        86.0                   2            1300.0
# 84863                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84821                -23.586366                -46.571079
# 84842                -23.586366                -46.571079
# 84863                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84821                bed_bath_table       18450.0
# 84842                bed_bath_table       18450.0
# 84863                    housewares        6600.0
#                                order_id                         review_id  \
# 84829  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84850  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84871  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84829  270c23a11d024a44c896d1894b261a83                  0
# 84850  270c23a11d024a44c896d1894b261a83                  0
# 84871  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84829                             1                              5
# 84850                             1                              5
# 84871                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84829                             21              1
# 84850                             21              2
# 84871                             21              3
#
#                              product_id                         seller_id  \
# 84829  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84850  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84871  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84829                    6  12.99          23.21                   5
# 84850                    6  12.99          23.21                   5
# 84871                    6  83.80           5.12                   5
#
#       payment_type  payment_installments  payment_value  \
# 84829      voucher                     1           2.61
# 84850      voucher                     1           2.61
# 84871      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84829  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84850  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84871  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84829                        9                 37.0
# 84850                        9                 37.0
# 84871                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84829                        86.0                   2            1300.0
# 84850                        86.0                   2            1300.0
# 84871                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84829                -23.586366                -46.571079
# 84850                -23.586366                -46.571079
# 84871                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84829                bed_bath_table       18450.0
# 84850                bed_bath_table       18450.0
# 84871                    housewares        6600.0
#                                order_id                         review_id  \
# 84836  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84857  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84878  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84836  270c23a11d024a44c896d1894b261a83                  0
# 84857  270c23a11d024a44c896d1894b261a83                  0
# 84878  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84836                             1                              5
# 84857                             1                              5
# 84878                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84836                             21              1
# 84857                             21              2
# 84878                             21              3
#
#                              product_id                         seller_id  \
# 84836  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84857  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84878  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84836                    6  12.99          23.21                   6
# 84857                    6  12.99          23.21                   6
# 84878                    6  83.80           5.12                   6
#
#       payment_type  payment_installments  payment_value  \
# 84836      voucher                     1           2.61
# 84857      voucher                     1           2.61
# 84878      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84836  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84857  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84878  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84836                        9                 37.0
# 84857                        9                 37.0
# 84878                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84836                        86.0                   2            1300.0
# 84857                        86.0                   2            1300.0
# 84878                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84836                -23.586366                -46.571079
# 84857                -23.586366                -46.571079
# 84878                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84836                bed_bath_table       18450.0
# 84857                bed_bath_table       18450.0
# 84878                    housewares        6600.0
#                                order_id                         review_id  \
# 84831  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84852  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84873  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84831  270c23a11d024a44c896d1894b261a83                  0
# 84852  270c23a11d024a44c896d1894b261a83                  0
# 84873  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84831                             1                              5
# 84852                             1                              5
# 84873                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84831                             21              1
# 84852                             21              2
# 84873                             21              3
#
#                              product_id                         seller_id  \
# 84831  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84852  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84873  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84831                    6  12.99          23.21                   7
# 84852                    6  12.99          23.21                   7
# 84873                    6  83.80           5.12                   7
#
#       payment_type  payment_installments  payment_value  \
# 84831      voucher                     1            2.6
# 84852      voucher                     1            2.6
# 84873      voucher                     1            2.6
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84831  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84852  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84873  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84831                        9                 37.0
# 84852                        9                 37.0
# 84873                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84831                        86.0                   2            1300.0
# 84852                        86.0                   2            1300.0
# 84873                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84831                -23.586366                -46.571079
# 84852                -23.586366                -46.571079
# 84873                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84831                bed_bath_table       18450.0
# 84852                bed_bath_table       18450.0
# 84873                    housewares        6600.0
#                                order_id                         review_id  \
# 84826  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84847  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84868  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84826  270c23a11d024a44c896d1894b261a83                  0
# 84847  270c23a11d024a44c896d1894b261a83                  0
# 84868  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84826                             1                              5
# 84847                             1                              5
# 84868                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84826                             21              1
# 84847                             21              2
# 84868                             21              3
#
#                              product_id                         seller_id  \
# 84826  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84847  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84868  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84826                    6  12.99          23.21                   8
# 84847                    6  12.99          23.21                   8
# 84868                    6  83.80           5.12                   8
#
#       payment_type  payment_installments  payment_value  \
# 84826      voucher                     1           0.41
# 84847      voucher                     1           0.41
# 84868      voucher                     1           0.41
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84826  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84847  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84868  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84826                        9                 37.0
# 84847                        9                 37.0
# 84868                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84826                        86.0                   2            1300.0
# 84847                        86.0                   2            1300.0
# 84868                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84826                -23.586366                -46.571079
# 84847                -23.586366                -46.571079
# 84868                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84826                bed_bath_table       18450.0
# 84847                bed_bath_table       18450.0
# 84868                    housewares        6600.0
#                                order_id                         review_id  \
# 84835  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84856  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84877  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84835  270c23a11d024a44c896d1894b261a83                  0
# 84856  270c23a11d024a44c896d1894b261a83                  0
# 84877  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84835                             1                              5
# 84856                             1                              5
# 84877                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84835                             21              1
# 84856                             21              2
# 84877                             21              3
#
#                              product_id                         seller_id  \
# 84835  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84856  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84877  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84835                    6  12.99          23.21                   9
# 84856                    6  12.99          23.21                   9
# 84877                    6  83.80           5.12                   9
#
#       payment_type  payment_installments  payment_value  \
# 84835      voucher                     1           2.61
# 84856      voucher                     1           2.61
# 84877      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84835  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84856  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84877  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84835                        9                 37.0
# 84856                        9                 37.0
# 84877                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84835                        86.0                   2            1300.0
# 84856                        86.0                   2            1300.0
# 84877                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84835                -23.586366                -46.571079
# 84856                -23.586366                -46.571079
# 84877                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84835                bed_bath_table       18450.0
# 84856                bed_bath_table       18450.0
# 84877                    housewares        6600.0
#                                order_id                         review_id  \
# 84830  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84851  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84872  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84830  270c23a11d024a44c896d1894b261a83                  0
# 84851  270c23a11d024a44c896d1894b261a83                  0
# 84872  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84830                             1                              5
# 84851                             1                              5
# 84872                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84830                             21              1
# 84851                             21              2
# 84872                             21              3
#
#                              product_id                         seller_id  \
# 84830  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84851  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84872  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84830                    6  12.99          23.21                  10
# 84851                    6  12.99          23.21                  10
# 84872                    6  83.80           5.12                  10
#
#       payment_type  payment_installments  payment_value  \
# 84830      voucher                     1           16.7
# 84851      voucher                     1           16.7
# 84872      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84830  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84851  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84872  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84830                        9                 37.0
# 84851                        9                 37.0
# 84872                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84830                        86.0                   2            1300.0
# 84851                        86.0                   2            1300.0
# 84872                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84830                -23.586366                -46.571079
# 84851                -23.586366                -46.571079
# 84872                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84830                bed_bath_table       18450.0
# 84851                bed_bath_table       18450.0
# 84872                    housewares        6600.0
#                                order_id                         review_id  \
# 84827  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84848  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84869  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84827  270c23a11d024a44c896d1894b261a83                  0
# 84848  270c23a11d024a44c896d1894b261a83                  0
# 84869  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84827                             1                              5
# 84848                             1                              5
# 84869                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84827                             21              1
# 84848                             21              2
# 84869                             21              3
#
#                              product_id                         seller_id  \
# 84827  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84848  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84869  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84827                    6  12.99          23.21                  11
# 84848                    6  12.99          23.21                  11
# 84869                    6  83.80           5.12                  11
#
#       payment_type  payment_installments  payment_value  \
# 84827      voucher                     1           16.7
# 84848      voucher                     1           16.7
# 84869      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84827  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84848  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84869  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84827                        9                 37.0
# 84848                        9                 37.0
# 84869                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84827                        86.0                   2            1300.0
# 84848                        86.0                   2            1300.0
# 84869                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84827                -23.586366                -46.571079
# 84848                -23.586366                -46.571079
# 84869                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84827                bed_bath_table       18450.0
# 84848                bed_bath_table       18450.0
# 84869                    housewares        6600.0
#                                order_id                         review_id  \
# 84824  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84845  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84866  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84824  270c23a11d024a44c896d1894b261a83                  0
# 84845  270c23a11d024a44c896d1894b261a83                  0
# 84866  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84824                             1                              5
# 84845                             1                              5
# 84866                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84824                             21              1
# 84845                             21              2
# 84866                             21              3
#
#                              product_id                         seller_id  \
# 84824  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84845  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84866  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84824                    6  12.99          23.21                  12
# 84845                    6  12.99          23.21                  12
# 84866                    6  83.80           5.12                  12
#
#       payment_type  payment_installments  payment_value  \
# 84824      voucher                     1           16.7
# 84845      voucher                     1           16.7
# 84866      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84824  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84845  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84866  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84824                        9                 37.0
# 84845                        9                 37.0
# 84866                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84824                        86.0                   2            1300.0
# 84845                        86.0                   2            1300.0
# 84866                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84824                -23.586366                -46.571079
# 84845                -23.586366                -46.571079
# 84866                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84824                bed_bath_table       18450.0
# 84845                bed_bath_table       18450.0
# 84866                    housewares        6600.0
#                                order_id                         review_id  \
# 84818  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84839  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84860  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84818  270c23a11d024a44c896d1894b261a83                  0
# 84839  270c23a11d024a44c896d1894b261a83                  0
# 84860  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84818                             1                              5
# 84839                             1                              5
# 84860                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84818                             21              1
# 84839                             21              2
# 84860                             21              3
#
#                              product_id                         seller_id  \
# 84818  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84839  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84860  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84818                    6  12.99          23.21                  13
# 84839                    6  12.99          23.21                  13
# 84860                    6  83.80           5.12                  13
#
#       payment_type  payment_installments  payment_value  \
# 84818      voucher                     1           16.7
# 84839      voucher                     1           16.7
# 84860      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84818  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84839  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84860  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84818                        9                 37.0
# 84839                        9                 37.0
# 84860                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84818                        86.0                   2            1300.0
# 84839                        86.0                   2            1300.0
# 84860                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84818                -23.586366                -46.571079
# 84839                -23.586366                -46.571079
# 84860                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84818                bed_bath_table       18450.0
# 84839                bed_bath_table       18450.0
# 84860                    housewares        6600.0
#                                order_id                         review_id  \
# 84834  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84855  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84876  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84834  270c23a11d024a44c896d1894b261a83                  0
# 84855  270c23a11d024a44c896d1894b261a83                  0
# 84876  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84834                             1                              5
# 84855                             1                              5
# 84876                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84834                             21              1
# 84855                             21              2
# 84876                             21              3
#
#                              product_id                         seller_id  \
# 84834  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84855  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84876  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84834                    6  12.99          23.21                  14
# 84855                    6  12.99          23.21                  14
# 84876                    6  83.80           5.12                  14
#
#       payment_type  payment_installments  payment_value  \
# 84834      voucher                     1           16.7
# 84855      voucher                     1           16.7
# 84876      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84834  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84855  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84876  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84834                        9                 37.0
# 84855                        9                 37.0
# 84876                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84834                        86.0                   2            1300.0
# 84855                        86.0                   2            1300.0
# 84876                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84834                -23.586366                -46.571079
# 84855                -23.586366                -46.571079
# 84876                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84834                bed_bath_table       18450.0
# 84855                bed_bath_table       18450.0
# 84876                    housewares        6600.0
#                                order_id                         review_id  \
# 84832  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84853  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84874  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84832  270c23a11d024a44c896d1894b261a83                  0
# 84853  270c23a11d024a44c896d1894b261a83                  0
# 84874  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84832                             1                              5
# 84853                             1                              5
# 84874                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84832                             21              1
# 84853                             21              2
# 84874                             21              3
#
#                              product_id                         seller_id  \
# 84832  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84853  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84874  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84832                    6  12.99          23.21                  15
# 84853                    6  12.99          23.21                  15
# 84874                    6  83.80           5.12                  15
#
#       payment_type  payment_installments  payment_value  \
# 84832      voucher                     1           16.7
# 84853      voucher                     1           16.7
# 84874      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84832  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84853  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84874  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84832                        9                 37.0
# 84853                        9                 37.0
# 84874                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84832                        86.0                   2            1300.0
# 84853                        86.0                   2            1300.0
# 84874                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84832                -23.586366                -46.571079
# 84853                -23.586366                -46.571079
# 84874                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84832                bed_bath_table       18450.0
# 84853                bed_bath_table       18450.0
# 84874                    housewares        6600.0
#                                order_id                         review_id  \
# 84819  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# ...
#                                order_id                         review_id  \
# 84816  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84837  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84858  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84816  270c23a11d024a44c896d1894b261a83                  0
# 84837  270c23a11d024a44c896d1894b261a83                  0
# 84858  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84816                             1                              5
# 84837                             1                              5
# 84858                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84816                             21              1
# 84837                             21              2
# 84858                             21              3
#
#                              product_id                         seller_id  \
# 84816  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84837  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84858  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84816                    6  12.99          23.21                  17
# 84837                    6  12.99          23.21                  17
# 84858                    6  83.80           5.12                  17
#
#       payment_type  payment_installments  payment_value  \
# 84816      voucher                     1           16.7
# 84837      voucher                     1           16.7
# 84858      voucher                     1           16.7
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84816  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84837  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84858  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84816                        9                 37.0
# 84837                        9                 37.0
# 84858                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84816                        86.0                   2            1300.0
# 84837                        86.0                   2            1300.0
# 84858                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84816                -23.586366                -46.571079
# 84837                -23.586366                -46.571079
# 84858                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84816                bed_bath_table       18450.0
# 84837                bed_bath_table       18450.0
# 84858                    housewares        6600.0
#                                order_id                         review_id  \
# 84825  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84846  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84867  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84825  270c23a11d024a44c896d1894b261a83                  0
# 84846  270c23a11d024a44c896d1894b261a83                  0
# 84867  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84825                             1                              5
# 84846                             1                              5
# 84867                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84825                             21              1
# 84846                             21              2
# 84867                             21              3
#
#                              product_id                         seller_id  \
# 84825  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84846  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84867  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84825                    6  12.99          23.21                  18
# 84846                    6  12.99          23.21                  18
# 84867                    6  83.80           5.12                  18
#
#       payment_type  payment_installments  payment_value  \
# 84825      voucher                     1           1.31
# 84846      voucher                     1           1.31
# 84867      voucher                     1           1.31
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84825  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84846  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84867  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84825                        9                 37.0
# 84846                        9                 37.0
# 84867                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84825                        86.0                   2            1300.0
# 84846                        86.0                   2            1300.0
# 84867                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84825                -23.586366                -46.571079
# 84846                -23.586366                -46.571079
# 84867                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84825                bed_bath_table       18450.0
# 84846                bed_bath_table       18450.0
# 84867                    housewares        6600.0
#                                order_id                         review_id  \
# 84820  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84841  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84862  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84820  270c23a11d024a44c896d1894b261a83                  0
# 84841  270c23a11d024a44c896d1894b261a83                  0
# 84862  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84820                             1                              5
# 84841                             1                              5
# 84862                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84820                             21              1
# 84841                             21              2
# 84862                             21              3
#
#                              product_id                         seller_id  \
# 84820  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84841  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84862  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84820                    6  12.99          23.21                  19
# 84841                    6  12.99          23.21                  19
# 84862                    6  83.80           5.12                  19
#
#       payment_type  payment_installments  payment_value  \
# 84820      voucher                     1           0.24
# 84841      voucher                     1           0.24
# 84862      voucher                     1           0.24
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84820  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84841  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84862  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84820                        9                 37.0
# 84841                        9                 37.0
# 84862                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84820                        86.0                   2            1300.0
# 84841                        86.0                   2            1300.0
# 84862                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84820                -23.586366                -46.571079
# 84841                -23.586366                -46.571079
# 84862                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84820                bed_bath_table       18450.0
# 84841                bed_bath_table       18450.0
# 84862                    housewares        6600.0
#                                order_id                         review_id  \
# 84833  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84854  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84875  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84833  270c23a11d024a44c896d1894b261a83                  0
# 84854  270c23a11d024a44c896d1894b261a83                  0
# 84875  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84833                             1                              5
# 84854                             1                              5
# 84875                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84833                             21              1
# 84854                             21              2
# 84875                             21              3
#
#                              product_id                         seller_id  \
# 84833  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84854  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84875  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84833                    6  12.99          23.21                  20
# 84854                    6  12.99          23.21                  20
# 84875                    6  83.80           5.12                  20
#
#       payment_type  payment_installments  payment_value  \
# 84833      voucher                     1           4.61
# 84854      voucher                     1           4.61
# 84875      voucher                     1           4.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84833  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84854  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84875  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84833                        9                 37.0
# 84854                        9                 37.0
# 84875                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84833                        86.0                   2            1300.0
# 84854                        86.0                   2            1300.0
# 84875                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84833                -23.586366                -46.571079
# 84854                -23.586366                -46.571079
# 84875                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84833                bed_bath_table       18450.0
# 84854                bed_bath_table       18450.0
# 84875                    housewares        6600.0
#                                order_id                         review_id  \
# 84822  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84843  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84864  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84822  270c23a11d024a44c896d1894b261a83                  0
# 84843  270c23a11d024a44c896d1894b261a83                  0
# 84864  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84822                             1                              5
# 84843                             1                              5
# 84864                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84822                             21              1
# 84843                             21              2
# 84864                             21              3
#
#                              product_id                         seller_id  \
# 84822  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84843  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84864  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84822                    6  12.99          23.21                  21
# 84843                    6  12.99          23.21                  21
# 84864                    6  83.80           5.12                  21
#
#       payment_type  payment_installments  payment_value  \
# 84822      voucher                     1           0.28
# 84843      voucher                     1           0.28
# 84864      voucher                     1           0.28
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84822  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84843  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84864  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84822                        9                 37.0
# 84843                        9                 37.0
# 84864                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84822                        86.0                   2            1300.0
# 84843                        86.0                   2            1300.0
# 84864                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84822                -23.586366                -46.571079
# 84843                -23.586366                -46.571079
# 84864                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84822                bed_bath_table       18450.0
# 84843                bed_bath_table       18450.0
# 84864                    housewares        6600.0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# So, 3 items shopped to this customer, 2 items (bed_bath_table category) form one seller and 1 item (housewares category) from another seller. Each one of these items is associated with one payment_sequential.
#
# The order items have been purchased at the same time and received by the customer at the same time 6 days later.

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83'].groupby('order_item_id').apply(display)
# Out:
#                                order_id                         review_id  \
# 84816  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84817  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84818  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84819  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84820  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84821  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84822  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84823  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84824  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84825  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84826  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84827  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84828  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84829  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84830  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84831  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84832  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84833  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84834  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84835  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84836  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84816  270c23a11d024a44c896d1894b261a83                  0
# 84817  270c23a11d024a44c896d1894b261a83                  0
# 84818  270c23a11d024a44c896d1894b261a83                  0
# 84819  270c23a11d024a44c896d1894b261a83                  0
# 84820  270c23a11d024a44c896d1894b261a83                  0
# 84821  270c23a11d024a44c896d1894b261a83                  0
# 84822  270c23a11d024a44c896d1894b261a83                  0
# 84823  270c23a11d024a44c896d1894b261a83                  0
# 84824  270c23a11d024a44c896d1894b261a83                  0
# 84825  270c23a11d024a44c896d1894b261a83                  0
# 84826  270c23a11d024a44c896d1894b261a83                  0
# 84827  270c23a11d024a44c896d1894b261a83                  0
# 84828  270c23a11d024a44c896d1894b261a83                  0
# 84829  270c23a11d024a44c896d1894b261a83                  0
# 84830  270c23a11d024a44c896d1894b261a83                  0
# 84831  270c23a11d024a44c896d1894b261a83                  0
# 84832  270c23a11d024a44c896d1894b261a83                  0
# 84833  270c23a11d024a44c896d1894b261a83                  0
# 84834  270c23a11d024a44c896d1894b261a83                  0
# 84835  270c23a11d024a44c896d1894b261a83                  0
# 84836  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84816                             1                              5
# 84817                             1                              5
# 84818                             1                              5
# 84819                             1                              5
# 84820                             1                              5
# 84821                             1                              5
# 84822                             1                              5
# 84823                             1                              5
# 84824                             1                              5
# 84825                             1                              5
# 84826                             1                              5
# 84827                             1                              5
# 84828                             1                              5
# 84829                             1                              5
# 84830                             1                              5
# 84831                             1                              5
# 84832                             1                              5
# 84833                             1                              5
# 84834                             1                              5
# 84835                             1                              5
# 84836                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84816                             21              1
# 84817                             21              1
# 84818                             21              1
# 84819                             21              1
# 84820                             21              1
# 84821                             21              1
# 84822                             21              1
# 84823                             21              1
# 84824                             21              1
# 84825                             21              1
# 84826                             21              1
# 84827                             21              1
# 84828                             21              1
# 84829                             21              1
# 84830                             21              1
# 84831                             21              1
# 84832                             21              1
# 84833                             21              1
# 84834                             21              1
# 84835                             21              1
# 84836                             21              1
#
#                              product_id                         seller_id  \
# 84816  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84817  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84818  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84819  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84820  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84821  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84822  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84823  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84824  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84825  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84826  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84827  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84828  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84829  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84830  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84831  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84832  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84833  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84834  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84835  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84836  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84816                    6  12.99          23.21                  17
# 84817                    6  12.99          23.21                   1
# 84818                    6  12.99          23.21                  13
# 84819                    6  12.99          23.21                  16
# 84820                    6  12.99          23.21                  19
# 84821                    6  12.99          23.21                   4
# 84822                    6  12.99          23.21                  21
# 84823                    6  12.99          23.21                   2
# 84824                    6  12.99          23.21                  12
# 84825                    6  12.99          23.21                  18
# 84826                    6  12.99          23.21                   8
# 84827                    6  12.99          23.21                  11
# 84828                    6  12.99          23.21                   3
# 84829                    6  12.99          23.21                   5
# 84830                    6  12.99          23.21                  10
# 84831                    6  12.99          23.21                   7
# 84832                    6  12.99          23.21                  15
# 84833                    6  12.99          23.21                  20
# 84834                    6  12.99          23.21                  14
# 84835                    6  12.99          23.21                   9
# 84836                    6  12.99          23.21                   6
#
#       payment_type  payment_installments  payment_value  \
# 84816      voucher                     1          16.70
# 84817      voucher                     1           2.61
# 84818      voucher                     1          16.70
# 84819      voucher                     1          16.70
# 84820      voucher                     1           0.24
# 84821      voucher                     1           2.61
# 84822      voucher                     1           0.28
# 84823      voucher                     1           2.61
# 84824      voucher                     1          16.70
# 84825      voucher                     1           1.31
# 84826      voucher                     1           0.41
# 84827      voucher                     1          16.70
# 84828      voucher                     1           2.61
# 84829      voucher                     1           2.61
# 84830      voucher                     1          16.70
# 84831      voucher                     1           2.60
# 84832      voucher                     1          16.70
# 84833      voucher                     1           4.61
# 84834      voucher                     1          16.70
# 84835      voucher                     1           2.61
# 84836      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84816  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84817  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84818  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84819  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84820  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84821  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84822  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84823  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84824  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84825  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84826  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84827  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84828  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84829  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84830  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84831  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84832  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84833  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84834  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84835  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84836  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84816                        9                 37.0
# 84817                        9                 37.0
# 84818                        9                 37.0
# 84819                        9                 37.0
# 84820                        9                 37.0
# 84821                        9                 37.0
# 84822                        9                 37.0
# 84823                        9                 37.0
# 84824                        9                 37.0
# 84825                        9                 37.0
# 84826                        9                 37.0
# 84827                        9                 37.0
# 84828                        9                 37.0
# 84829                        9                 37.0
# 84830                        9                 37.0
# 84831                        9                 37.0
# 84832                        9                 37.0
# 84833                        9                 37.0
# 84834                        9                 37.0
# 84835                        9                 37.0
# 84836                        9                 37.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84816                        86.0                   2            1300.0
# 84817                        86.0                   2            1300.0
# 84818                        86.0                   2            1300.0
# 84819                        86.0                   2            1300.0
# 84820                        86.0                   2            1300.0
# 84821                        86.0                   2            1300.0
# 84822                        86.0                   2            1300.0
# 84823                        86.0                   2            1300.0
# 84824                        86.0                   2            1300.0
# 84825                        86.0                   2            1300.0
# 84826                        86.0                   2            1300.0
# 84827                        86.0                   2            1300.0
# 84828                        86.0                   2            1300.0
# 84829                        86.0                   2            1300.0
# 84830                        86.0                   2            1300.0
# 84831                        86.0                   2            1300.0
# 84832                        86.0                   2            1300.0
# 84833                        86.0                   2            1300.0
# 84834                        86.0                   2            1300.0
# 84835                        86.0                   2            1300.0
# 84836                        86.0                   2            1300.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84816                -23.586366                -46.571079
# 84817                -23.586366                -46.571079
# 84818                -23.586366                -46.571079
# 84819                -23.586366                -46.571079
# 84820                -23.586366                -46.571079
# 84821                -23.586366                -46.571079
# 84822                -23.586366                -46.571079
# 84823                -23.586366                -46.571079
# 84824                -23.586366                -46.571079
# 84825                -23.586366                -46.571079
# 84826                -23.586366                -46.571079
# 84827                -23.586366                -46.571079
# 84828                -23.586366                -46.571079
# 84829                -23.586366                -46.571079
# 84830                -23.586366                -46.571079
# 84831                -23.586366                -46.571079
# 84832                -23.586366                -46.571079
# 84833                -23.586366                -46.571079
# 84834                -23.586366                -46.571079
# 84835                -23.586366                -46.571079
# 84836                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84816                bed_bath_table       18450.0
# 84817                bed_bath_table       18450.0
# 84818                bed_bath_table       18450.0
# 84819                bed_bath_table       18450.0
# 84820                bed_bath_table       18450.0
# 84821                bed_bath_table       18450.0
# 84822                bed_bath_table       18450.0
# 84823                bed_bath_table       18450.0
# 84824                bed_bath_table       18450.0
# 84825                bed_bath_table       18450.0
# 84826                bed_bath_table       18450.0
# 84827                bed_bath_table       18450.0
# 84828                bed_bath_table       18450.0
# 84829                bed_bath_table       18450.0
# 84830                bed_bath_table       18450.0
# 84831                bed_bath_table       18450.0
# 84832                bed_bath_table       18450.0
# 84833                bed_bath_table       18450.0
# 84834                bed_bath_table       18450.0
# 84835                bed_bath_table       18450.0
# 84836                bed_bath_table       18450.0
#                                order_id                         review_id  \
# 84837  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84838  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84839  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84840  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84841  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84842  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84843  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84844  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84845  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84846  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84847  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84848  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84849  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84850  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84851  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84852  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84853  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84854  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84855  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84856  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84857  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84837  270c23a11d024a44c896d1894b261a83                  0
# 84838  270c23a11d024a44c896d1894b261a83                  0
# 84839  270c23a11d024a44c896d1894b261a83                  0
# 84840  270c23a11d024a44c896d1894b261a83                  0
# 84841  270c23a11d024a44c896d1894b261a83                  0
# 84842  270c23a11d024a44c896d1894b261a83                  0
# 84843  270c23a11d024a44c896d1894b261a83                  0
# 84844  270c23a11d024a44c896d1894b261a83                  0
# 84845  270c23a11d024a44c896d1894b261a83                  0
# 84846  270c23a11d024a44c896d1894b261a83                  0
# 84847  270c23a11d024a44c896d1894b261a83                  0
# 84848  270c23a11d024a44c896d1894b261a83                  0
# 84849  270c23a11d024a44c896d1894b261a83                  0
# 84850  270c23a11d024a44c896d1894b261a83                  0
# 84851  270c23a11d024a44c896d1894b261a83                  0
# 84852  270c23a11d024a44c896d1894b261a83                  0
# 84853  270c23a11d024a44c896d1894b261a83                  0
# 84854  270c23a11d024a44c896d1894b261a83                  0
# 84855  270c23a11d024a44c896d1894b261a83                  0
# 84856  270c23a11d024a44c896d1894b261a83                  0
# 84857  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84837                             1                              5
# 84838                             1                              5
# 84839                             1                              5
# 84840                             1                              5
# 84841                             1                              5
# 84842                             1                              5
# 84843                             1                              5
# 84844                             1                              5
# 84845                             1                              5
# 84846                             1                              5
# 84847                             1                              5
# 84848                             1                              5
# 84849                             1                              5
# 84850                             1                              5
# 84851                             1                              5
# 84852                             1                              5
# 84853                             1                              5
# 84854                             1                              5
# 84855                             1                              5
# 84856                             1                              5
# 84857                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84837                             21              2
# 84838                             21              2
# 84839                             21              2
# 84840                             21              2
# 84841                             21              2
# 84842                             21              2
# 84843                             21              2
# 84844                             21              2
# 84845                             21              2
# 84846                             21              2
# 84847                             21              2
# 84848                             21              2
# 84849                             21              2
# 84850                             21              2
# 84851                             21              2
# 84852                             21              2
# 84853                             21              2
# 84854                             21              2
# 84855                             21              2
# 84856                             21              2
# 84857                             21              2
#
#                              product_id                         seller_id  \
# 84837  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84838  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84839  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84840  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84841  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84842  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84843  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84844  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84845  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84846  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84847  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84848  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84849  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84850  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84851  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84852  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84853  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84854  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84855  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84856  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84857  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84837                    6  12.99          23.21                  17
# 84838                    6  12.99          23.21                   1
# 84839                    6  12.99          23.21                  13
# 84840                    6  12.99          23.21                  16
# 84841                    6  12.99          23.21                  19
# 84842                    6  12.99          23.21                   4
# 84843                    6  12.99          23.21                  21
# 84844                    6  12.99          23.21                   2
# 84845                    6  12.99          23.21                  12
# 84846                    6  12.99          23.21                  18
# 84847                    6  12.99          23.21                   8
# 84848                    6  12.99          23.21                  11
# 84849                    6  12.99          23.21                   3
# 84850                    6  12.99          23.21                   5
# 84851                    6  12.99          23.21                  10
# 84852                    6  12.99          23.21                   7
# 84853                    6  12.99          23.21                  15
# 84854                    6  12.99          23.21                  20
# 84855                    6  12.99          23.21                  14
# 84856                    6  12.99          23.21                   9
# 84857                    6  12.99          23.21                   6
#
#       payment_type  payment_installments  payment_value  \
# 84837      voucher                     1          16.70
# 84838      voucher                     1           2.61
# 84839      voucher                     1          16.70
# 84840      voucher                     1          16.70
# 84841      voucher                     1           0.24
# 84842      voucher                     1           2.61
# 84843      voucher                     1           0.28
# 84844      voucher                     1           2.61
# 84845      voucher                     1          16.70
# 84846      voucher                     1           1.31
# 84847      voucher                     1           0.41
# 84848      voucher                     1          16.70
# 84849      voucher                     1           2.61
# 84850      voucher                     1           2.61
# 84851      voucher                     1          16.70
# 84852      voucher                     1           2.60
# 84853      voucher                     1          16.70
# 84854      voucher                     1           4.61
# 84855      voucher                     1          16.70
# 84856      voucher                     1           2.61
# 84857      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84837  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84838  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84839  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84840  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84841  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84842  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84843  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84844  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84845  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84846  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84847  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84848  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84849  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84850  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84851  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84852  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84853  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84854  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84855  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84856  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84857  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84837                        9                 37.0
# 84838                        9                 37.0
# 84839                        9                 37.0
# 84840                        9                 37.0
# 84841                        9                 37.0
# 84842                        9                 37.0
# 84843                        9                 37.0
# 84844                        9                 37.0
# 84845                        9                 37.0
# 84846                        9                 37.0
# 84847                        9                 37.0
# 84848                        9                 37.0
# 84849                        9                 37.0
# 84850                        9                 37.0
# 84851                        9                 37.0
# 84852                        9                 37.0
# 84853                        9                 37.0
# 84854                        9                 37.0
# 84855                        9                 37.0
# 84856                        9                 37.0
# 84857                        9                 37.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84837                        86.0                   2            1300.0
# 84838                        86.0                   2            1300.0
# 84839                        86.0                   2            1300.0
# 84840                        86.0                   2            1300.0
# 84841                        86.0                   2            1300.0
# 84842                        86.0                   2            1300.0
# 84843                        86.0                   2            1300.0
# 84844                        86.0                   2            1300.0
# 84845                        86.0                   2            1300.0
# 84846                        86.0                   2            1300.0
# 84847                        86.0                   2            1300.0
# 84848                        86.0                   2            1300.0
# 84849                        86.0                   2            1300.0
# 84850                        86.0                   2            1300.0
# 84851                        86.0                   2            1300.0
# 84852                        86.0                   2            1300.0
# 84853                        86.0                   2            1300.0
# 84854                        86.0                   2            1300.0
# 84855                        86.0                   2            1300.0
# 84856                        86.0                   2            1300.0
# 84857                        86.0                   2            1300.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84837                -23.586366                -46.571079
# 84838                -23.586366                -46.571079
# 84839                -23.586366                -46.571079
# 84840                -23.586366                -46.571079
# 84841                -23.586366                -46.571079
# 84842                -23.586366                -46.571079
# 84843                -23.586366                -46.571079
# 84844                -23.586366                -46.571079
# 84845                -23.586366                -46.571079
# 84846                -23.586366                -46.571079
# 84847                -23.586366                -46.571079
# 84848                -23.586366                -46.571079
# 84849                -23.586366                -46.571079
# 84850                -23.586366                -46.571079
# 84851                -23.586366                -46.571079
# 84852                -23.586366                -46.571079
# 84853                -23.586366                -46.571079
# 84854                -23.586366                -46.571079
# 84855                -23.586366                -46.571079
# 84856                -23.586366                -46.571079
# 84857                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84837                bed_bath_table       18450.0
# 84838                bed_bath_table       18450.0
# 84839                bed_bath_table       18450.0
# 84840                bed_bath_table       18450.0
# 84841                bed_bath_table       18450.0
# 84842                bed_bath_table       18450.0
# 84843                bed_bath_table       18450.0
# 84844                bed_bath_table       18450.0
# 84845                bed_bath_table       18450.0
# 84846                bed_bath_table       18450.0
# 84847                bed_bath_table       18450.0
# 84848                bed_bath_table       18450.0
# 84849                bed_bath_table       18450.0
# 84850                bed_bath_table       18450.0
# 84851                bed_bath_table       18450.0
# 84852                bed_bath_table       18450.0
# 84853                bed_bath_table       18450.0
# 84854                bed_bath_table       18450.0
# 84855                bed_bath_table       18450.0
# 84856                bed_bath_table       18450.0
# 84857                bed_bath_table       18450.0
#                                order_id                         review_id  \
# 84858  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84859  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84860  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84861  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84862  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84863  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84864  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84865  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84866  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84867  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84868  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84869  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84870  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84871  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84872  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84873  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84874  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84875  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84876  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84877  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84878  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84858  270c23a11d024a44c896d1894b261a83                  0
# 84859  270c23a11d024a44c896d1894b261a83                  0
# 84860  270c23a11d024a44c896d1894b261a83                  0
# 84861  270c23a11d024a44c896d1894b261a83                  0
# 84862  270c23a11d024a44c896d1894b261a83                  0
# 84863  270c23a11d024a44c896d1894b261a83                  0
# 84864  270c23a11d024a44c896d1894b261a83                  0
# 84865  270c23a11d024a44c896d1894b261a83                  0
# 84866  270c23a11d024a44c896d1894b261a83                  0
# 84867  270c23a11d024a44c896d1894b261a83                  0
# 84868  270c23a11d024a44c896d1894b261a83                  0
# 84869  270c23a11d024a44c896d1894b261a83                  0
# 84870  270c23a11d024a44c896d1894b261a83                  0
# 84871  270c23a11d024a44c896d1894b261a83                  0
# 84872  270c23a11d024a44c896d1894b261a83                  0
# 84873  270c23a11d024a44c896d1894b261a83                  0
# 84874  270c23a11d024a44c896d1894b261a83                  0
# 84875  270c23a11d024a44c896d1894b261a83                  0
# 84876  270c23a11d024a44c896d1894b261a83                  0
# 84877  270c23a11d024a44c896d1894b261a83                  0
# 84878  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84858                             1                              5
# 84859                             1                              5
# 84860                             1                              5
# 84861                             1                              5
# 84862                             1                              5
# 84863                             1                              5
# 84864                             1                              5
# 84865                             1                              5
# 84866                             1                              5
# 84867                             1                              5
# 84868                             1                              5
# 84869                             1                              5
# 84870                             1                              5
# 84871                             1                              5
# 84872                             1                              5
# 84873                             1                              5
# 84874                             1                              5
# 84875                             1                              5
# 84876                             1                              5
# 84877                             1                              5
# 84878                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84858                             21              3
# 84859                             21              3
# 84860                             21              3
# 84861                             21              3
# 84862                             21              3
# 84863                             21              3
# 84864                             21              3
# 84865                             21              3
# 84866                             21              3
# 84867                             21              3
# 84868                             21              3
# 84869                             21              3
# 84870                             21              3
# 84871                             21              3
# 84872                             21              3
# 84873                             21              3
# 84874                             21              3
# 84875                             21              3
# 84876                             21              3
# 84877                             21              3
# 84878                             21              3
#
#                              product_id                         seller_id  \
# 84858  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84859  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84860  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84861  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84862  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84863  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84864  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84865  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84866  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84867  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84868  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84869  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84870  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84871  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84872  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84873  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84874  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84875  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84876  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84877  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84878  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84858                    6   83.8           5.12                  17
# 84859                    6   83.8           5.12                   1
# 84860                    6   83.8           5.12                  13
# 84861                    6   83.8           5.12                  16
# 84862                    6   83.8           5.12                  19
# 84863                    6   83.8           5.12                   4
# 84864                    6   83.8           5.12                  21
# 84865                    6   83.8           5.12                   2
# 84866                    6   83.8           5.12                  12
# 84867                    6   83.8           5.12                  18
# 84868                    6   83.8           5.12                   8
# 84869                    6   83.8           5.12                  11
# 84870                    6   83.8           5.12                   3
# 84871                    6   83.8           5.12                   5
# 84872                    6   83.8           5.12                  10
# 84873                    6   83.8           5.12                   7
# 84874                    6   83.8           5.12                  15
# 84875                    6   83.8           5.12                  20
# 84876                    6   83.8           5.12                  14
# 84877                    6   83.8           5.12                   9
# 84878                    6   83.8           5.12                   6
#
#       payment_type  payment_installments  payment_value  \
# 84858      voucher                     1          16.70
# 84859      voucher                     1           2.61
# 84860      voucher                     1          16.70
# 84861      voucher                     1          16.70
# 84862      voucher                     1           0.24
# 84863      voucher                     1           2.61
# 84864      voucher                     1           0.28
# 84865      voucher                     1           2.61
# 84866      voucher                     1          16.70
# 84867      voucher                     1           1.31
# 84868      voucher                     1           0.41
# 84869      voucher                     1          16.70
# 84870      voucher                     1           2.61
# 84871      voucher                     1           2.61
# 84872      voucher                     1          16.70
# 84873      voucher                     1           2.60
# 84874      voucher                     1          16.70
# 84875      voucher                     1           4.61
# 84876      voucher                     1          16.70
# 84877      voucher                     1           2.61
# 84878      voucher                     1           2.61
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84858  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84859  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84860  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84861  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84862  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84863  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84864  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84865  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84866  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84867  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84868  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84869  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84870  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84871  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84872  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84873  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84874  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84875  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84876  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84877  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84878  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84858                        9                 56.0
# 84859                        9                 56.0
# 84860                        9                 56.0
# 84861                        9                 56.0
# 84862                        9                 56.0
# 84863                        9                 56.0
# 84864                        9                 56.0
# 84865                        9                 56.0
# 84866                        9                 56.0
# 84867                        9                 56.0
# 84868                        9                 56.0
# 84869                        9                 56.0
# 84870                        9                 56.0
# 84871                        9                 56.0
# 84872                        9                 56.0
# 84873                        9                 56.0
# 84874                        9                 56.0
# 84875                        9                 56.0
# 84876                        9                 56.0
# 84877                        9                 56.0
# 84878                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84858                       548.0                   8             450.0
# 84859                       548.0                   8             450.0
# 84860                       548.0                   8             450.0
# 84861                       548.0                   8             450.0
# 84862                       548.0                   8             450.0
# 84863                       548.0                   8             450.0
# 84864                       548.0                   8             450.0
# 84865                       548.0                   8             450.0
# 84866                       548.0                   8             450.0
# 84867                       548.0                   8             450.0
# 84868                       548.0                   8             450.0
# 84869                       548.0                   8             450.0
# 84870                       548.0                   8             450.0
# 84871                       548.0                   8             450.0
# 84872                       548.0                   8             450.0
# 84873                       548.0                   8             450.0
# 84874                       548.0                   8             450.0
# 84875                       548.0                   8             450.0
# 84876                       548.0                   8             450.0
# 84877                       548.0                   8             450.0
# 84878                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84858                -23.586366                -46.571079
# 84859                -23.586366                -46.571079
# 84860                -23.586366                -46.571079
# 84861                -23.586366                -46.571079
# 84862                -23.586366                -46.571079
# 84863                -23.586366                -46.571079
# 84864                -23.586366                -46.571079
# 84865                -23.586366                -46.571079
# 84866                -23.586366                -46.571079
# 84867                -23.586366                -46.571079
# 84868                -23.586366                -46.571079
# 84869                -23.586366                -46.571079
# 84870                -23.586366                -46.571079
# 84871                -23.586366                -46.571079
# 84872                -23.586366                -46.571079
# 84873                -23.586366                -46.571079
# 84874                -23.586366                -46.571079
# 84875                -23.586366                -46.571079
# 84876                -23.586366                -46.571079
# 84877                -23.586366                -46.571079
# 84878                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84858                    housewares        6600.0
# 84859                    housewares        6600.0
# 84860                    housewares        6600.0
# 84861                    housewares        6600.0
# 84862                    housewares        6600.0
# 84863                    housewares        6600.0
# 84864                    housewares        6600.0
# 84865                    housewares        6600.0
# 84866                    housewares        6600.0
# 84867                    housewares        6600.0
# 84868                    housewares        6600.0
# 84869                    housewares        6600.0
# 84870                    housewares        6600.0
# 84871                    housewares        6600.0
# 84872                    housewares        6600.0
# 84873                    housewares        6600.0
# 84874                    housewares        6600.0
# 84875                    housewares        6600.0
# 84876                    housewares        6600.0
# 84877                    housewares        6600.0
# 84878                    housewares        6600.0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# On the objective of reducing the this data to one one instance, we can:
# 1. group by order_item_id and get the sum of payment_value and store it as payment_value
# 2. group by order_item_id and get the max of payment_sequential and store it as payment_sequential
# Every other column value is just a duplicate of other instances in the same group by.

# %%
# df_temp = df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83'].copy()
df_orders_translated['payment_value'] = df_orders_translated.groupby(['order_id','order_item_id'])['payment_value'].transform('sum')

# %%
# df_orders_translated.groupby('order_item_id').apply(display)

# %%
df_orders_translated['payment_sequential'] = df_orders_translated.groupby(['order_id','order_item_id'])['payment_sequential'].transform('max')

# %%
# df_orders_translated.groupby('order_item_id').apply(display)

# %%
df_orders_translated.duplicated().sum()
# Out:
# 2194

# %% [markdown]
# This two groupby operations takes us down to 3 rows instead of the 63.

# %%
df_orders_translated[~df_orders_translated.duplicated()]
# Out:
#                                 order_id                         review_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 1       e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 3       53cdb2fc8bc7dce0b6741e2150273451  8d5266042046a06655c8db133d120ba5
# 4       47770eb9100c2d0c44946d9cf07ec65d  e73b67b67587f7644d5bd1a52deb1b01
# 5       949d5b44dbf5de918fe9c16f97b45f8a  359d03e676b3c069f62cadba8dd3f6e8
# ...                                  ...                               ...
# 118141  63943bddc261676b46f01ca7ac2f7bd8  29bb71b2760d0f876dfa178a76bc4734
# 118142  83c1379a015df1e13d02aae0204711ab  371579771219f6db2d830d50805977bb
# 118143  11c177c8e97725db2631073c19f07b62  8ab6855b9fe9b812cd03a480a25058a1
# 118144  11c177c8e97725db2631073c19f07b62  8ab6855b9fe9b812cd03a480a25058a1
# 118145  66dea50a8b16d9b4dee7af250b4be1a5  dc9c59b4688062c25758c2be4cafc523
#
#                              customer_id  order_approved_at  \
# 0       9ef432eb6251297304e76186b10a928d                  0
# 1       9ef432eb6251297304e76186b10a928d                  0
# 3       b0830fb4747a6c6d20dea0b8c802d7ef                  1
# 4       41ce2a54c0b03bf3443c3d931a367089                  0
# 5       f88197465ea7920adcdbec7375364d82                  0
# ...                                  ...                ...
# 118141  1fca14ff2861355f6e5f14306ff977a7                  0
# 118142  1aa71eb042121263aafbe80c1b562c9c                  0
# 118143  b331b74b18dc79bcdf6532d51e1637c1                  0
# 118144  b331b74b18dc79bcdf6532d51e1637c1                  0
# 118145  edb027a75a1449115f6b43211ae02a24                  0
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# 0                                  2                              8
# 1                                  2                              8
# 3                                  1                             13
# 4                                  0                              9
# 5                                  3                             13
# ...                              ...                            ...
# 118141                             1                             22
# 118142                             1                             24
# 118143                             3                             17
# 118144                             3                             17
# 118145                             1                              7
#
#         order_estimated_delivery_date  order_item_id  \
# 0                                  15              1
# 1                                  15              1
# 3                                  19              1
# 4                                  26              1
# 5                                  26              1
# ...                               ...            ...
# 118141                             23              1
# 118142                             30              1
# 118143                             37              1
# 118144                             37              2
# 118145                             25              1
#
#                               product_id                         seller_id  \
# 0       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3       595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4       aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 5       d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# ...                                  ...                               ...
# 118141  f1d4ce8c6dd66c47bbaa8c6781c2a923  1f9ab4708f3056ede07124aad39a2554
# 118142  b80910977a37536adeddd63663f916ad  d50d79cb34e38265a8649c383dcffd48
# 118143  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 118144  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 118145  006619bbed68b000c8ba3f8725d5409e  ececbfcff9804a2d6b40f589df8eef2b
#
#         shipping_limit_date   price  freight_value  payment_sequential  \
# 0                         4   29.99           8.72                   3
# 1                         4   29.99           8.72                   3
# 3                         5  118.70          22.76                   1
# 4                         5  159.90          19.22                   1
# 5                         5   45.00          27.20                   1
# ...                     ...     ...            ...                 ...
# 118141                    6  174.90          20.10                   1
# 118142                    9  205.99          65.02                   1
# 118143                    4  179.99          40.59                   1
# 118144                    4  179.99          40.59                   1
# 118145                    6   68.50          18.36                   1
#
#        payment_type  payment_installments  payment_value  \
# 0       credit_card                     1          38.71
# 1           voucher                     1          38.71
# 3            boleto                     1         141.46
# 4       credit_card                     3         179.12
# 5       credit_card                     1          72.20
# ...             ...                   ...            ...
# 118141  credit_card                     3         195.00
# 118142  credit_card                     5         271.01
# 118143  credit_card                     4         441.16
# 118144  credit_card                     4         441.16
# 118145   debit_card                     1          86.86
#
#                       customer_unique_id  review_score  review_creation_date  \
# 0       7c396fd4830fd04220f754e42b4e5bff             4                     8
# 1       7c396fd4830fd04220f754e42b4e5bff             4                     8
# 3       af07308b275d755c9edb36a90c618231             4                    14
# 4       3a653a41f6f9fc3d2a113cf8398680e8             5                     9
# 5       7c142cf63193a1473d2e66489a9ae977             5                    14
# ...                                  ...           ...                   ...
# 118141  da62f9e57a76d978d02ab5362c509660             4                    22
# 118142  737520a9aad80b3fbbdad19b66b37b30             5                    25
# 118143  5097a5312c8b157bb7be58ae360ef43c             2                    17
# 118144  5097a5312c8b157bb7be58ae360ef43c             2                    17
# 118145  60350aa974b26ff12caad89e55993bd6             5                     8
#
#         review_answer_timestamp  product_name_lenght  \
# 0                             9                 40.0
# 1                             9                 40.0
# 3                            14                 29.0
# 4                            14                 46.0
# 5                            16                 59.0
# ...                         ...                  ...
# 118141                       24                 52.0
# 118142                       26                 51.0
# 118143                       18                 59.0
# 118144                       18                 59.0
# 118145                        8                 45.0
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 0                            268.0                   4             500.0
# 1                            268.0                   4             500.0
# 3                            178.0                   1             400.0
# 4                            232.0                   1             420.0
# 5                            468.0                   3             450.0
# ...                            ...                 ...               ...
# 118141                       828.0                   4            4950.0
# 118142                       500.0                   2           13300.0
# 118143                      1893.0                   1            6550.0
# 118144                      1893.0                   1            6550.0
# 118145                       569.0                   1             150.0
#
#         customer_geolocation_lat  customer_geolocation_lng  \
# 0                     -23.576983                -46.587161
# 1                     -23.576983                -46.587161
# 3                     -12.177924                -44.660711
# 4                     -16.745150                -48.514783
# 5                      -5.774190                -35.271143
# ...                          ...                       ...
# 118141                -24.001500                -46.449864
# 118142                -17.898358                -39.373630
# 118143                -22.562825                -42.694574
# 118144                -22.562825                -42.694574
# 118145                -25.764308                -49.720376
#
#        product_category_name_english  order_volume
# 0                         housewares        1976.0
# 1                         housewares        1976.0
# 3                          perfumery        4693.0
# 4                               auto        9576.0
# 5                           pet_shop        6000.0
# ...                              ...           ...
# 118141                          baby       16000.0
# 118142             home_appliances_2       63360.0
# 118143         computers_accessories        8000.0
# 118144         computers_accessories        8000.0
# 118145                 health_beauty        1680.0
#
# [110436 rows x 29 columns]

# %% [markdown]
# Delete the duplicated:

# %%
df_orders_translated.drop_duplicates(inplace = True)

# %%
df_orders_translated.head()
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 1  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 3  53cdb2fc8bc7dce0b6741e2150273451  8d5266042046a06655c8db133d120ba5
# 4  47770eb9100c2d0c44946d9cf07ec65d  e73b67b67587f7644d5bd1a52deb1b01
# 5  949d5b44dbf5de918fe9c16f97b45f8a  359d03e676b3c069f62cadba8dd3f6e8
#
#                         customer_id  order_approved_at  \
# 0  9ef432eb6251297304e76186b10a928d                  0
# 1  9ef432eb6251297304e76186b10a928d                  0
# 3  b0830fb4747a6c6d20dea0b8c802d7ef                  1
# 4  41ce2a54c0b03bf3443c3d931a367089                  0
# 5  f88197465ea7920adcdbec7375364d82                  0
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0                             2                              8
# 1                             2                              8
# 3                             1                             13
# 4                             0                              9
# 5                             3                             13
#
#    order_estimated_delivery_date  order_item_id  \
# 0                             15              1
# 1                             15              1
# 3                             19              1
# 4                             26              1
# 5                             26              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 5  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0                    4   29.99           8.72                   3
# 1                    4   29.99           8.72                   3
# 3                    5  118.70          22.76                   1
# 4                    5  159.90          19.22                   1
# 5                    5   45.00          27.20                   1
#
#   payment_type  payment_installments  payment_value  \
# 0  credit_card                     1          38.71
# 1      voucher                     1          38.71
# 3       boleto                     1         141.46
# 4  credit_card                     3         179.12
# 5  credit_card                     1          72.20
#
#                  customer_unique_id  review_score  review_creation_date  \
# 0  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 1  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 3  af07308b275d755c9edb36a90c618231             4                    14
# 4  3a653a41f6f9fc3d2a113cf8398680e8             5                     9
# 5  7c142cf63193a1473d2e66489a9ae977             5                    14
#
#    review_answer_timestamp  product_name_lenght  product_description_lenght  \
# 0                        9                 40.0                       268.0
# 1                        9                 40.0                       268.0
# 3                       14                 29.0                       178.0
# 4                       14                 46.0                       232.0
# 5                       16                 59.0                       468.0
#
#    product_photos_qty  product_weight_g  customer_geolocation_lat  \
# 0                   4             500.0                -23.576983
# 1                   4             500.0                -23.576983
# 3                   1             400.0                -12.177924
# 4                   1             420.0                -16.745150
# 5                   3             450.0                 -5.774190
#
#    customer_geolocation_lng product_category_name_english  order_volume
# 0                -46.587161                    housewares        1976.0
# 1                -46.587161                    housewares        1976.0
# 3                -44.660711                     perfumery        4693.0
# 4                -48.514783                          auto        9576.0
# 5                -35.271143                      pet_shop        6000.0

# %%
# df_orders_translated.groupby('product_id').apply(display)

# %% [markdown]
# Now we need to group by the product_id and get the total number of order_item_id.

# %%
df_orders_translated['order_item_id'] = df_orders_translated.groupby(['order_id','product_id'])['order_item_id'].transform('max')

# %%
# df_orders_translated.groupby('product_id').apply(display)

# %% [markdown]
# Drop duplicates again.

# %%
df_orders_translated.drop_duplicates(inplace = True)

# %%
df_orders_translated.head()
# Out:
#                            order_id                         review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 1  e481f51cbdc54678b7cc49136f2d6af7  a54f0611adc9ed256b57ede6b6eb5114
# 3  53cdb2fc8bc7dce0b6741e2150273451  8d5266042046a06655c8db133d120ba5
# 4  47770eb9100c2d0c44946d9cf07ec65d  e73b67b67587f7644d5bd1a52deb1b01
# 5  949d5b44dbf5de918fe9c16f97b45f8a  359d03e676b3c069f62cadba8dd3f6e8
#
#                         customer_id  order_approved_at  \
# 0  9ef432eb6251297304e76186b10a928d                  0
# 1  9ef432eb6251297304e76186b10a928d                  0
# 3  b0830fb4747a6c6d20dea0b8c802d7ef                  1
# 4  41ce2a54c0b03bf3443c3d931a367089                  0
# 5  f88197465ea7920adcdbec7375364d82                  0
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0                             2                              8
# 1                             2                              8
# 3                             1                             13
# 4                             0                              9
# 5                             3                             13
#
#    order_estimated_delivery_date  order_item_id  \
# 0                             15              1
# 1                             15              1
# 3                             19              1
# 4                             26              1
# 5                             26              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 5  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0                    4   29.99           8.72                   3
# 1                    4   29.99           8.72                   3
# 3                    5  118.70          22.76                   1
# 4                    5  159.90          19.22                   1
# 5                    5   45.00          27.20                   1
#
#   payment_type  payment_installments  payment_value  \
# 0  credit_card                     1          38.71
# 1      voucher                     1          38.71
# 3       boleto                     1         141.46
# 4  credit_card                     3         179.12
# 5  credit_card                     1          72.20
#
#                  customer_unique_id  review_score  review_creation_date  \
# 0  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 1  7c396fd4830fd04220f754e42b4e5bff             4                     8
# 3  af07308b275d755c9edb36a90c618231             4                    14
# 4  3a653a41f6f9fc3d2a113cf8398680e8             5                     9
# 5  7c142cf63193a1473d2e66489a9ae977             5                    14
#
#    review_answer_timestamp  product_name_lenght  product_description_lenght  \
# 0                        9                 40.0                       268.0
# 1                        9                 40.0                       268.0
# 3                       14                 29.0                       178.0
# 4                       14                 46.0                       232.0
# 5                       16                 59.0                       468.0
#
#    product_photos_qty  product_weight_g  customer_geolocation_lat  \
# 0                   4             500.0                -23.576983
# 1                   4             500.0                -23.576983
# 3                   1             400.0                -12.177924
# 4                   1             420.0                -16.745150
# 5                   3             450.0                 -5.774190
#
#    customer_geolocation_lng product_category_name_english  order_volume
# 0                -46.587161                    housewares        1976.0
# 1                -46.587161                    housewares        1976.0
# 3                -44.660711                     perfumery        4693.0
# 4                -48.514783                          auto        9576.0
# 5                -35.271143                      pet_shop        6000.0

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83']
# Out:
#                                order_id                         review_id  \
# 84816  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
# 84858  895ab968e7bb0d5659d16cd74cd1650c  eef5dbca8d37dfce6db7d7b16dd0525e
#
#                             customer_id  order_approved_at  \
# 84816  270c23a11d024a44c896d1894b261a83                  0
# 84858  270c23a11d024a44c896d1894b261a83                  0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84816                             1                              5
# 84858                             1                              5
#
#        order_estimated_delivery_date  order_item_id  \
# 84816                             21              2
# 84858                             21              3
#
#                              product_id                         seller_id  \
# 84816  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84858  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 84816                    6  12.99          23.21                  21
# 84858                    6  83.80           5.12                  21
#
#       payment_type  payment_installments  payment_value  \
# 84816      voucher                     1         161.32
# 84858      voucher                     1         161.32
#
#                      customer_unique_id  review_score  review_creation_date  \
# 84816  9a736b248f67d166d2fbb006bcb877c3             5                     6
# 84858  9a736b248f67d166d2fbb006bcb877c3             5                     6
#
#        review_answer_timestamp  product_name_lenght  \
# 84816                        9                 37.0
# 84858                        9                 56.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 84816                        86.0                   2            1300.0
# 84858                       548.0                   8             450.0
#
#        customer_geolocation_lat  customer_geolocation_lng  \
# 84816                -23.586366                -46.571079
# 84858                -23.586366                -46.571079
#
#       product_category_name_english  order_volume
# 84816                bed_bath_table       18450.0
# 84858                    housewares        6600.0

# %% [markdown]
# Now we reduced our data down from 63 rows to two rows per order item product_id each.
#
# How can we reduce it even further to one row?
#
# We can do so by averaging all number and on-hot-encoding the `payment_type` and the `product_category_name_english` columns. This will result in a sparse dataframe and an addition of north of 70 columns.

# %%
df_orders_translated.shape
# Out:
# (100510, 29)

# %% [markdown]
# - order_id                       : mean()
# - review_id                      : mean()
# - customer_id                    : -
# - order_approved_at              : mean()
# - order_delivered_carrier_date   : mean()
# - order_delivered_customer_date  : mean()
# - order_estimated_delivery_date  : mean()
# - order_item_id                  : max()
# - product_id                     : nunique()
# - seller_id                      : nunique()
# - shipping_limit_date            : mean()
# - price                          : mean()
# - freight_value                  : mean()
# - payment_sequential             : max()
# - payment_type                   : one-hot-encoding, then sum()
# - payment_installments           : max()
# - payment_value                  : mean()
# - customer_unique_id             : -
# - review_score                   : mean()
# - review_creation_date           : mean()
# - review_answer_timestamp        : mean()
# - product_name_lenght            : mean()
# - product_description_lenght     : mean()
# - product_photos_qty             : mean()
# - product_weight_g               : mean()
# - customer_geolocation_lat       : -
# - customer_geolocation_lng       : -
# - product_category_name_english  : one-hot-encoding, then sum()
# - order_volume                   : mean()

# %%
df_orders_translated['payment_type'].nunique()
# Out:
# 4

# %%
df_orders_translated['product_category_name_english'].nunique()
# Out:
# 71

# %% [markdown]
# Let us start by the one hot encoding for the following by using get_dummies:
# - payment_type                   : one-hot-encoding
# - product_category_name_english  : one-hot-encoding
#
# we will expect an addition of 75 - 2 columns.

# %%
df_orders_translated.shape
# Out:
# (100510, 29)

# %%
df_orders_translated = pd.get_dummies(df_orders_translated, columns = ['payment_type', 'product_category_name_english'])

# %%
df_orders_translated.shape
# Out:
# (100510, 102)

# %%
df_orders_translated.sample(1)
# Out:
#                                order_id                         review_id  \
# 97818  98c0f6e16f786f293db2cdf5388442f6  4bd99bd23412c408607cd56a9858cffd
#
#                             customer_id  order_approved_at  \
# 97818  b34c2bf47009c527fe2eee5362333591                  1
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 97818                             3                              6
#
#        order_estimated_delivery_date  order_item_id  \
# 97818                             17              1
#
#                              product_id                         seller_id  \
# 97818  0cc562350ea5915979a9d5f1f888f131  c6bda72e4dbf5c5866b13cb1810c6d03
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 97818                    4  529.9          19.68                   1
#
#        payment_installments  payment_value                customer_unique_id  \
# 97818                    10         549.58  fb482506a95394b3430b97dd4d5188fe
#
#        review_score  review_creation_date  review_answer_timestamp  \
# 97818             4                     7                        9
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 97818                 33.0                       924.0                   2
#
#        product_weight_g  customer_geolocation_lat  customer_geolocation_lng  \
# 97818            1700.0                -27.432686                -48.465857
#
#        order_volume  payment_type_boleto  payment_type_credit_card  \
# 97818       32000.0                    0                         1
#
#        payment_type_debit_card  payment_type_voucher  \
# 97818                        0                     0
#
#        product_category_name_english_agro_industry_and_commerce  \
# 97818                                                         0
#
#        product_category_name_english_air_conditioning  \
# 97818                                               0
#
#        product_category_name_english_art  \
# 97818                                  0
#
#        product_category_name_english_arts_and_craftmanship  \
# 97818                                                    0
#
#        product_category_name_english_audio  \
# 97818                                    0
#
#        product_category_name_english_auto  product_category_name_english_baby  \
# 97818                                   0                                   0
#
#        product_category_name_english_bed_bath_table  \
# 97818                                             0
#
#        product_category_name_english_books_general_interest  \
# 97818                                                     0
#
#        product_category_name_english_books_imported  \
# 97818                                             0
#
#        product_category_name_english_books_technical  \
# 97818                                              0
#
#        product_category_name_english_cds_dvds_musicals  \
# 97818                                                0
#
#        product_category_name_english_christmas_supplies  \
# 97818                                                 0
#
#        product_category_name_english_cine_photo  \
# 97818                                         0
#
#        product_category_name_english_computers  \
# 97818                                        0
#
#        product_category_name_english_computers_accessories  \
# 97818                                                    0
#
#        product_category_name_english_consoles_games  \
# 97818                                             0
#
#        product_category_name_english_construction_tools_construction  \
# 97818                                                              0
#
#        product_category_name_english_construction_tools_lights  \
# 97818                                                        0
#
#        product_category_name_english_construction_tools_safety  \
# 97818                                                        0
#
#        product_category_name_english_cool_stuff  \
# 97818                                         0
#
#        product_category_name_english_costruction_tools_garden  \
# 97818                                                       0
#
#        product_category_name_english_costruction_tools_tools  \
# 97818                                                      0
#
#        product_category_name_english_diapers_and_hygiene  \
# 97818                                                  0
#
#        product_category_name_english_drinks  \
# 97818                                     0
#
#        product_category_name_english_dvds_blu_ray  \
# 97818                                           0
#
#        product_category_name_english_electronics  \
# 97818                                          0
#
#        product_category_name_english_fashio_female_clothing  \
# 97818                                                     0
#
#        product_category_name_english_fashion_bags_accessories  \
# 97818                                                       0
#
#        product_category_name_english_fashion_childrens_clothes  \
# 97818                                                        0
#
#        product_category_name_english_fashion_male_clothing  \
# 97818                                                    0
#
#        product_category_name_english_fashion_shoes  \
# 97818                                            0
#
#        product_category_name_english_fashion_sport  \
# 97818                                            0
#
#        product_category_name_english_fashion_underwear_beach  \
# 97818                                                      0
#
#        product_category_name_english_fixed_telephony  \
# 97818                                              0
#
#        product_category_name_english_flowers  \
# 97818                                      0
#
#        product_category_name_english_food  \
# 97818                                   0
#
#        product_category_name_english_food_drink  \
# 97818                                         0
#
#        product_category_name_english_furniture_bedroom  \
# 97818                                                0
#
#        product_category_name_english_furniture_decor  \
# 97818                                              0
#
#        product_category_name_english_furniture_living_room  \
# 97818                                                    0
#
#        product_category_name_english_furniture_mattress_and_upholstery  \
# 97818                                                                0
#
#        product_category_name_english_garden_tools  \
# 97818                                           0
#
#        product_category_name_english_health_beauty  \
# 97818                                            0
#
#        product_category_name_english_home_appliances  \
# 97818                                              0
#
#        product_category_name_english_home_appliances_2  \
# 97818                                                0
#
#        product_category_name_english_home_comfort_2  \
# 97818                                             0
#
#        product_category_name_english_home_confort  \
# 97818                                           0
#
#        product_category_name_english_home_construction  \
# 97818                                                0
#
#        product_category_name_english_housewares  \
# 97818                                         0
#
#        product_category_name_english_industry_commerce_and_business  \
# 97818                                                             0
#
#        product_category_name_english_kitchen_dining_laundry_garden_furniture  \
# 97818                                                                      0
#
#        product_category_name_english_la_cuisine  \
# 97818                                         0
#
#        product_category_name_english_luggage_accessories  \
# 97818                                                  0
#
#        product_category_name_english_market_place  \
# 97818                                           0
#
#        product_category_name_english_music  \
# 97818                                    0
#
#        product_category_name_english_musical_instruments  \
# 97818                                                  0
#
#        product_category_name_english_office_furniture  \
# 97818                                               0
#
#        product_category_name_english_party_supplies  \
# 97818                                             0
#
#        product_category_name_english_perfumery  \
# 97818                                        0
#
#        product_category_name_english_pet_shop  \
# 97818                                       0
#
#        product_category_name_english_security_and_services  \
# 97818                                                    0
#
#        product_category_name_english_signaling_and_security  \
# 97818                                                     0
#
#        product_category_name_english_small_appliances  \
# 97818                                               0
#
#        product_category_name_english_small_appliances_home_oven_and_coffee  \
# 97818                                                                    0
#
#        product_category_name_english_sports_leisure  \
# 97818                                             0
#
#        product_category_name_english_stationery  \
# 97818                                         0
#
#        product_category_name_english_tablets_printing_image  \
# 97818                                                     0
#
#        product_category_name_english_telephony  \
# 97818                                        0
#
#        product_category_name_english_toys  \
# 97818                                   1
#
#        product_category_name_english_watches_gifts
# 97818                                            0

# %% [markdown]
# Now we can perform the groupby operations.

# %%
df_orders_translated.columns
# Out:
# Index(['order_id', 'review_id', 'customer_id', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'order_item_id', 'product_id',
#        'seller_id',
#        ...
#        'product_category_name_english_security_and_services',
#        'product_category_name_english_signaling_and_security',
#        'product_category_name_english_small_appliances',
#        'product_category_name_english_small_appliances_home_oven_and_coffee',
#        'product_category_name_english_sports_leisure',
#        'product_category_name_english_stationery',
#        'product_category_name_english_tablets_printing_image',
#        'product_category_name_english_telephony',
#        'product_category_name_english_toys',
#        'product_category_name_english_watches_gifts'],
#       dtype='object', length=102)

# %%
len(df_orders_translated.columns[-75:])
# Out:
# 75

# %%
# the last 75 columns
df_orders_translated.columns[-75:]
# Out:
# Index(['payment_type_boleto', 'payment_type_credit_card',
#        'payment_type_debit_card', 'payment_type_voucher',
#        'product_category_name_english_agro_industry_and_commerce',
#        'product_category_name_english_air_conditioning',
#        'product_category_name_english_art',
#        'product_category_name_english_arts_and_craftmanship',
#        'product_category_name_english_audio',
#        'product_category_name_english_auto',
#        'product_category_name_english_baby',
#        'product_category_name_english_bed_bath_table',
#        'product_category_name_english_books_general_interest',
#        'product_category_name_english_books_imported',
#        'product_category_name_english_books_technical',
#        'product_category_name_english_cds_dvds_musicals',
#        'product_category_name_english_christmas_supplies',
#        'product_category_name_english_cine_photo',
#        'product_category_name_english_computers',
#        'product_category_name_english_computers_accessories',
#        'product_category_name_english_consoles_games',
#        'product_category_name_english_construction_tools_construction',
#        'product_category_name_english_construction_tools_lights',
#        'product_category_name_english_construction_tools_safety',
#        'product_category_name_english_cool_stuff',
#        'product_category_name_english_costruction_tools_garden',
#        'product_category_name_english_costruction_tools_tools',
#        'product_category_name_english_diapers_and_hygiene',
#        'product_category_name_english_drinks',
#        'product_category_name_english_dvds_blu_ray',
#        'product_category_name_english_electronics',
#        'product_category_name_english_fashio_female_clothing',
#        'product_category_name_english_fashion_bags_accessories',
#        'product_category_name_english_fashion_childrens_clothes',
#        'product_category_name_english_fashion_male_clothing',
#        'product_category_name_english_fashion_shoes',
#        'product_category_name_english_fashion_sport',
#        'product_category_name_english_fashion_underwear_beach',
#        'product_category_name_english_fixed_telephony',
#        'product_category_name_english_flowers',
#        'product_category_name_english_food',
#        'product_category_name_english_food_drink',
#        'product_category_name_english_furniture_bedroom',
#        'product_category_name_english_furniture_decor',
#        'product_category_name_english_furniture_living_room',
#        'product_category_name_english_furniture_mattress_and_upholstery',
#        'product_category_name_english_garden_tools',
#        'product_category_name_english_health_beauty',
#        'product_category_name_english_home_appliances',
#        'product_category_name_english_home_appliances_2',
#        'product_category_name_english_home_comfort_2',
#        'product_category_name_english_home_confort',
#        'product_category_name_english_home_construction',
#        'product_category_name_english_housewares',
#        'product_category_name_english_industry_commerce_and_business',
#        'product_category_name_english_kitchen_dining_laundry_garden_furniture',
#        'product_category_name_english_la_cuisine',
#        'product_category_name_english_luggage_accessories',
#        'product_category_name_english_market_place',
#        'product_category_name_english_music',
#        'product_category_name_english_musical_instruments',
#        'product_category_name_english_office_furniture',
#        'product_category_name_english_party_supplies',
#        'product_category_name_english_perfumery',
#        'product_category_name_english_pet_shop',
#        'product_category_name_english_security_and_services',
#        'product_category_name_english_signaling_and_security',
#        'product_category_name_english_small_appliances',
#        'product_category_name_english_small_appliances_home_oven_and_coffee',
#        'product_category_name_english_sports_leisure',
#        'product_category_name_english_stationery',
#        'product_category_name_english_tablets_printing_image',
#        'product_category_name_english_telephony',
#        'product_category_name_english_toys',
#        'product_category_name_english_watches_gifts'],
#       dtype='object')

# %%
mean_list = [
'order_approved_at',
'order_delivered_carrier_date',
'order_delivered_customer_date',
'order_estimated_delivery_date',
'shipping_limit_date',   
'price',
'freight_value',
'payment_value',
'review_score',
'review_creation_date',
'review_answer_timestamp',
'product_name_lenght',
'product_description_lenght',
'product_photos_qty',
'product_weight_g',     
'order_volume'
]

nunique_list = [
'review_id',
'product_id', 
'seller_id' 
]  

max_list = [
'order_item_id',         
'payment_sequential',     
'payment_installments'            
]

sum_list = df_orders_translated.columns[-75:]

df_orders_translated[mean_list] = df_orders_translated.groupby(['customer_id'])[mean_list].transform('mean')
df_orders_translated[nunique_list] = df_orders_translated.groupby(['customer_id'])[nunique_list].transform('nunique')
df_orders_translated[max_list] = df_orders_translated.groupby(['customer_id'])[max_list].transform('max')
df_orders_translated[sum_list] = df_orders_translated.groupby(['customer_id'])[sum_list].transform('sum')
# df_orders_translated = df_orders_translated.groupby(['order_id'])[mean_list].transform('mean')

# %%
df_orders_translated.head()
# Out:
#                            order_id  review_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7          1
# 1  e481f51cbdc54678b7cc49136f2d6af7          1
# 3  53cdb2fc8bc7dce0b6741e2150273451          1
# 4  47770eb9100c2d0c44946d9cf07ec65d          1
# 5  949d5b44dbf5de918fe9c16f97b45f8a          1
#
#                         customer_id  order_approved_at  \
# 0  9ef432eb6251297304e76186b10a928d                0.0
# 1  9ef432eb6251297304e76186b10a928d                0.0
# 3  b0830fb4747a6c6d20dea0b8c802d7ef                1.0
# 4  41ce2a54c0b03bf3443c3d931a367089                0.0
# 5  f88197465ea7920adcdbec7375364d82                0.0
#
#    order_delivered_carrier_date  order_delivered_customer_date  \
# 0                           2.0                            8.0
# 1                           2.0                            8.0
# 3                           1.0                           13.0
# 4                           0.0                            9.0
# 5                           3.0                           13.0
#
#    order_estimated_delivery_date  order_item_id  product_id  seller_id  \
# 0                           15.0              1           1          1
# 1                           15.0              1           1          1
# 3                           19.0              1           1          1
# 4                           26.0              1           1          1
# 5                           26.0              1           1          1
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0                  4.0   29.99           8.72                   3
# 1                  4.0   29.99           8.72                   3
# 3                  5.0  118.70          22.76                   1
# 4                  5.0  159.90          19.22                   1
# 5                  5.0   45.00          27.20                   1
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                     1          38.71  7c396fd4830fd04220f754e42b4e5bff
# 1                     1          38.71  7c396fd4830fd04220f754e42b4e5bff
# 3                     1         141.46  af07308b275d755c9edb36a90c618231
# 4                     3         179.12  3a653a41f6f9fc3d2a113cf8398680e8
# 5                     1          72.20  7c142cf63193a1473d2e66489a9ae977
#
#    review_score  review_creation_date  review_answer_timestamp  \
# 0           4.0                   8.0                      9.0
# 1           4.0                   8.0                      9.0
# 3           4.0                  14.0                     14.0
# 4           5.0                   9.0                     14.0
# 5           5.0                  14.0                     16.0
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 3                 29.0                       178.0                 1.0
# 4                 46.0                       232.0                 1.0
# 5                 59.0                       468.0                 3.0
#
#    product_weight_g  customer_geolocation_lat  customer_geolocation_lng  \
# 0             500.0                -23.576983                -46.587161
# 1             500.0                -23.576983                -46.587161
# 3             400.0                -12.177924                -44.660711
# 4             420.0                -16.745150                -48.514783
# 5             450.0                 -5.774190                -35.271143
#
#    order_volume  payment_type_boleto  payment_type_credit_card  \
# 0        1976.0                    0                         1
# 1        1976.0                    0                         1
# 3        4693.0                    1                         0
# 4        9576.0                    0                         1
# 5        6000.0                    0                         1
#
#    payment_type_debit_card  payment_type_voucher  \
# 0                        0                     1
# 1                        0                     1
# 3                        0                     0
# 4                        0                     0
# 5                        0                     0
#
#    product_category_name_english_agro_industry_and_commerce  \
# 0                                                         0
# 1                                                         0
# 3                                                         0
# 4                                                         0
# 5                                                         0
#
#    product_category_name_english_air_conditioning  \
# 0                                               0
# 1                                               0
# 3                                               0
# 4                                               0
# 5                                               0
#
#    product_category_name_english_art  \
# 0                                  0
# 1                                  0
# 3                                  0
# 4                                  0
# 5                                  0
#
#    product_category_name_english_arts_and_craftmanship  \
# 0                                                    0
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
#
#    product_category_name_english_audio  product_category_name_english_auto  \
# 0                                    0                                   0
# 1                                    0                                   0
# 3                                    0                                   0
# 4                                    0                                   1
# 5                                    0                                   0
#
#    product_category_name_english_baby  \
# 0                                   0
# 1                                   0
# 3                                   0
# 4                                   0
# 5                                   0
#
#    product_category_name_english_bed_bath_table  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_books_general_interest  \
# 0                                                     0
# 1                                                     0
# 3                                                     0
# 4                                                     0
# 5                                                     0
#
#    product_category_name_english_books_imported  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_books_technical  \
# 0                                              0
# 1                                              0
# 3                                              0
# 4                                              0
# 5                                              0
#
#    product_category_name_english_cds_dvds_musicals  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    product_category_name_english_christmas_supplies  \
# 0                                                 0
# 1                                                 0
# 3                                                 0
# 4                                                 0
# 5                                                 0
#
#    product_category_name_english_cine_photo  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_computers  \
# 0                                        0
# 1                                        0
# 3                                        0
# 4                                        0
# 5                                        0
#
#    product_category_name_english_computers_accessories  \
# 0                                                    0
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
#
#    product_category_name_english_consoles_games  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_construction_tools_construction  \
# 0                                                              0
# 1                                                              0
# 3                                                              0
# 4                                                              0
# 5                                                              0
#
#    product_category_name_english_construction_tools_lights  \
# 0                                                        0
# 1                                                        0
# 3                                                        0
# 4                                                        0
# 5                                                        0
#
#    product_category_name_english_construction_tools_safety  \
# 0                                                        0
# 1                                                        0
# 3                                                        0
# 4                                                        0
# 5                                                        0
#
#    product_category_name_english_cool_stuff  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_costruction_tools_garden  \
# 0                                                       0
# 1                                                       0
# 3                                                       0
# 4                                                       0
# 5                                                       0
#
#    product_category_name_english_costruction_tools_tools  \
# 0                                                      0
# 1                                                      0
# 3                                                      0
# 4                                                      0
# 5                                                      0
#
#    product_category_name_english_diapers_and_hygiene  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
#
#    product_category_name_english_drinks  \
# 0                                     0
# 1                                     0
# 3                                     0
# 4                                     0
# 5                                     0
#
#    product_category_name_english_dvds_blu_ray  \
# 0                                           0
# 1                                           0
# 3                                           0
# 4                                           0
# 5                                           0
#
#    product_category_name_english_electronics  \
# 0                                          0
# 1                                          0
# 3                                          0
# 4                                          0
# 5                                          0
#
#    product_category_name_english_fashio_female_clothing  \
# 0                                                     0
# 1                                                     0
# 3                                                     0
# 4                                                     0
# 5                                                     0
#
#    product_category_name_english_fashion_bags_accessories  \
# 0                                                       0
# 1                                                       0
# 3                                                       0
# 4                                                       0
# 5                                                       0
#
#    product_category_name_english_fashion_childrens_clothes  \
# 0                                                        0
# 1                                                        0
# 3                                                        0
# 4                                                        0
# 5                                                        0
#
#    product_category_name_english_fashion_male_clothing  \
# 0                                                    0
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
#
#    product_category_name_english_fashion_shoes  \
# 0                                            0
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0
#
#    product_category_name_english_fashion_sport  \
# 0                                            0
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0
#
#    product_category_name_english_fashion_underwear_beach  \
# 0                                                      0
# 1                                                      0
# 3                                                      0
# 4                                                      0
# 5                                                      0
#
#    product_category_name_english_fixed_telephony  \
# 0                                              0
# 1                                              0
# 3                                              0
# 4                                              0
# 5                                              0
#
#    product_category_name_english_flowers  product_category_name_english_food  \
# 0                                      0                                   0
# 1                                      0                                   0
# 3                                      0                                   0
# 4                                      0                                   0
# 5                                      0                                   0
#
#    product_category_name_english_food_drink  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_furniture_bedroom  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    product_category_name_english_furniture_decor  \
# 0                                              0
# 1                                              0
# 3                                              0
# 4                                              0
# 5                                              0
#
#    product_category_name_english_furniture_living_room  \
# 0                                                    0
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
#
#    product_category_name_english_furniture_mattress_and_upholstery  \
# 0                                                                0
# 1                                                                0
# 3                                                                0
# 4                                                                0
# 5                                                                0
#
#    product_category_name_english_garden_tools  \
# 0                                           0
# 1                                           0
# 3                                           0
# 4                                           0
# 5                                           0
#
#    product_category_name_english_health_beauty  \
# 0                                            0
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0
#
#    product_category_name_english_home_appliances  \
# 0                                              0
# 1                                              0
# 3                                              0
# 4                                              0
# 5                                              0
#
#    product_category_name_english_home_appliances_2  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    product_category_name_english_home_comfort_2  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_home_confort  \
# 0                                           0
# 1                                           0
# 3                                           0
# 4                                           0
# 5                                           0
#
#    product_category_name_english_home_construction  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    product_category_name_english_housewares  \
# 0                                         2
# 1                                         2
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_industry_commerce_and_business  \
# 0                                                             0
# 1                                                             0
# 3                                                             0
# 4                                                             0
# 5                                                             0
#
#    product_category_name_english_kitchen_dining_laundry_garden_furniture  \
# 0                                                                      0
# 1                                                                      0
# 3                                                                      0
# 4                                                                      0
# 5                                                                      0
#
#    product_category_name_english_la_cuisine  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_luggage_accessories  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
#
#    product_category_name_english_market_place  \
# 0                                           0
# 1                                           0
# 3                                           0
# 4                                           0
# 5                                           0
#
#    product_category_name_english_music  \
# 0                                    0
# 1                                    0
# 3                                    0
# 4                                    0
# 5                                    0
#
#    product_category_name_english_musical_instruments  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 5                                                  0
#
#    product_category_name_english_office_furniture  \
# 0                                               0
# 1                                               0
# 3                                               0
# 4                                               0
# 5                                               0
#
#    product_category_name_english_party_supplies  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_perfumery  \
# 0                                        0
# 1                                        0
# 3                                        1
# 4                                        0
# 5                                        0
#
#    product_category_name_english_pet_shop  \
# 0                                       0
# 1                                       0
# 3                                       0
# 4                                       0
# 5                                       1
#
#    product_category_name_english_security_and_services  \
# 0                                                    0
# 1                                                    0
# 3                                                    0
# 4                                                    0
# 5                                                    0
#
#    product_category_name_english_signaling_and_security  \
# 0                                                     0
# 1                                                     0
# 3                                                     0
# 4                                                     0
# 5                                                     0
#
#    product_category_name_english_small_appliances  \
# 0                                               0
# 1                                               0
# 3                                               0
# 4                                               0
# 5                                               0
#
#    product_category_name_english_small_appliances_home_oven_and_coffee  \
# 0                                                                    0
# 1                                                                    0
# 3                                                                    0
# 4                                                                    0
# 5                                                                    0
#
#    product_category_name_english_sports_leisure  \
# 0                                             0
# 1                                             0
# 3                                             0
# 4                                             0
# 5                                             0
#
#    product_category_name_english_stationery  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 5                                         0
#
#    product_category_name_english_tablets_printing_image  \
# 0                                                     0
# 1                                                     0
# 3                                                     0
# 4                                                     0
# 5                                                     0
#
#    product_category_name_english_telephony  \
# 0                                        0
# 1                                        0
# 3                                        0
# 4                                        0
# 5                                        0
#
#    product_category_name_english_toys  \
# 0                                   0
# 1                                   0
# 3                                   0
# 4                                   0
# 5                                   0
#
#    product_category_name_english_watches_gifts
# 0                                            0
# 1                                            0
# 3                                            0
# 4                                            0
# 5                                            0

# %%
df_orders_translated[df_orders_translated['customer_id'] == '270c23a11d024a44c896d1894b261a83']
# Out:
#                                order_id  review_id  \
# 84816  895ab968e7bb0d5659d16cd74cd1650c          1
# 84858  895ab968e7bb0d5659d16cd74cd1650c          1
#
#                             customer_id  order_approved_at  \
# 84816  270c23a11d024a44c896d1894b261a83                0.0
# 84858  270c23a11d024a44c896d1894b261a83                0.0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 84816                           1.0                            5.0
# 84858                           1.0                            5.0
#
#        order_estimated_delivery_date  order_item_id  product_id  seller_id  \
# 84816                           21.0              3           2          2
# 84858                           21.0              3           2          2
#
#        shipping_limit_date   price  freight_value  payment_sequential  \
# 84816                  6.0  48.395         14.165                  21
# 84858                  6.0  48.395         14.165                  21
#
#        payment_installments  payment_value                customer_unique_id  \
# 84816                     1         161.32  9a736b248f67d166d2fbb006bcb877c3
# 84858                     1         161.32  9a736b248f67d166d2fbb006bcb877c3
#
#        review_score  review_creation_date  review_answer_timestamp  \
# 84816           5.0                   6.0                      9.0
# 84858           5.0                   6.0                      9.0
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 84816                 46.5                       317.0                 5.0
# 84858                 46.5                       317.0                 5.0
#
#        product_weight_g  customer_geolocation_lat  customer_geolocation_lng  \
# 84816             875.0                -23.586366                -46.571079
# 84858             875.0                -23.586366                -46.571079
#
#        order_volume  payment_type_boleto  payment_type_credit_card  \
# 84816       12525.0                    0                         0
# 84858       12525.0                    0                         0
#
#        payment_type_debit_card  payment_type_voucher  \
# 84816                        0                     2
# 84858                        0                     2
#
#        product_category_name_english_agro_industry_and_commerce  \
# 84816                                                         0
# 84858                                                         0
#
#        product_category_name_english_air_conditioning  \
# 84816                                               0
# 84858                                               0
#
#        product_category_name_english_art  \
# 84816                                  0
# 84858                                  0
#
#        product_category_name_english_arts_and_craftmanship  \
# 84816                                                    0
# 84858                                                    0
#
#        product_category_name_english_audio  \
# 84816                                    0
# 84858                                    0
#
#        product_category_name_english_auto  product_category_name_english_baby  \
# 84816                                   0                                   0
# 84858                                   0                                   0
#
#        product_category_name_english_bed_bath_table  \
# 84816                                             1
# 84858                                             1
#
#        product_category_name_english_books_general_interest  \
# 84816                                                     0
# 84858                                                     0
#
#        product_category_name_english_books_imported  \
# 84816                                             0
# 84858                                             0
#
#        product_category_name_english_books_technical  \
# 84816                                              0
# 84858                                              0
#
#        product_category_name_english_cds_dvds_musicals  \
# 84816                                                0
# 84858                                                0
#
#        product_category_name_english_christmas_supplies  \
# 84816                                                 0
# 84858                                                 0
#
#        product_category_name_english_cine_photo  \
# 84816                                         0
# 84858                                         0
#
#        product_category_name_english_computers  \
# 84816                                        0
# 84858                                        0
#
#        product_category_name_english_computers_accessories  \
# 84816                                                    0
# 84858                                                    0
#
#        product_category_name_english_consoles_games  \
# 84816                                             0
# 84858                                             0
#
#        product_category_name_english_construction_tools_construction  \
# 84816                                                              0
# 84858                                                              0
#
#        product_category_name_english_construction_tools_lights  \
# 84816                                                        0
# 84858                                                        0
#
#        product_category_name_english_construction_tools_safety  \
# 84816                                                        0
# 84858                                                        0
#
#        product_category_name_english_cool_stuff  \
# 84816                                         0
# 84858                                         0
#
#        product_category_name_english_costruction_tools_garden  \
# 84816                                                       0
# 84858                                                       0
#
#        product_category_name_english_costruction_tools_tools  \
# 84816                                                      0
# 84858                                                      0
#
#        product_category_name_english_diapers_and_hygiene  \
# 84816                                                  0
# 84858                                                  0
#
#        product_category_name_english_drinks  \
# 84816                                     0
# 84858                                     0
#
#        product_category_name_english_dvds_blu_ray  \
# 84816                                           0
# 84858                                           0
#
#        product_category_name_english_electronics  \
# 84816                                          0
# 84858                                          0
#
#        product_category_name_english_fashio_female_clothing  \
# 84816                                                     0
# 84858                                                     0
#
#        product_category_name_english_fashion_bags_accessories  \
# 84816                                                       0
# 84858                                                       0
#
#        product_category_name_english_fashion_childrens_clothes  \
# 84816                                                        0
# 84858                                                        0
#
#        product_category_name_english_fashion_male_clothing  \
# 84816                                                    0
# 84858                                                    0
#
#        product_category_name_english_fashion_shoes  \
# 84816                                            0
# 84858                                            0
#
#        product_category_name_english_fashion_sport  \
# 84816                                            0
# 84858                                            0
#
#        product_category_name_english_fashion_underwear_beach  \
# 84816                                                      0
# 84858                                                      0
#
#        product_category_name_english_fixed_telephony  \
# 84816                                              0
# 84858                                              0
#
#        product_category_name_english_flowers  \
# 84816                                      0
# 84858                                      0
#
#        product_category_name_english_food  \
# 84816                                   0
# 84858                                   0
#
#        product_category_name_english_food_drink  \
# 84816                                         0
# 84858                                         0
#
#        product_category_name_english_furniture_bedroom  \
# 84816                                                0
# 84858                                                0
#
#        product_category_name_english_furniture_decor  \
# 84816                                              0
# 84858                                              0
#
#        product_category_name_english_furniture_living_room  \
# 84816                                                    0
# 84858                                                    0
#
#        product_category_name_english_furniture_mattress_and_upholstery  \
# 84816                                                                0
# 84858                                                                0
#
#        product_category_name_english_garden_tools  \
# 84816                                           0
# 84858                                           0
#
#        product_category_name_english_health_beauty  \
# 84816                                            0
# 84858                                            0
#
#        product_category_name_english_home_appliances  \
# 84816                                              0
# 84858                                              0
#
#        product_category_name_english_home_appliances_2  \
# 84816                                                0
# 84858                                                0
#
#        product_category_name_english_home_comfort_2  \
# 84816                                             0
# 84858                                             0
#
#        product_category_name_english_home_confort  \
# 84816                                           0
# 84858                                           0
#
#        product_category_name_english_home_construction  \
# 84816                                                0
# 84858                                                0
#
#        product_category_name_english_housewares  \
# 84816                                         1
# 84858                                         1
#
#        product_category_name_english_industry_commerce_and_business  \
# 84816                                                             0
# 84858                                                             0
#
#        product_category_name_english_kitchen_dining_laundry_garden_furniture  \
# 84816                                                                      0
# 84858                                                                      0
#
#        product_category_name_english_la_cuisine  \
# 84816                                         0
# 84858                                         0
#
#        product_category_name_english_luggage_accessories  \
# 84816                                                  0
# 84858                                                  0
#
#        product_category_name_english_market_place  \
# 84816                                           0
# 84858                                           0
#
#        product_category_name_english_music  \
# 84816                                    0
# 84858                                    0
#
#        product_category_name_english_musical_instruments  \
# 84816                                                  0
# 84858                                                  0
#
#        product_category_name_english_office_furniture  \
# 84816                                               0
# 84858                                               0
#
#        product_category_name_english_party_supplies  \
# 84816                                             0
# 84858                                             0
#
#        product_category_name_english_perfumery  \
# 84816                                        0
# 84858                                        0
#
#        product_category_name_english_pet_shop  \
# 84816                                       0
# 84858                                       0
#
#        product_category_name_english_security_and_services  \
# 84816                                                    0
# 84858                                                    0
#
#        product_category_name_english_signaling_and_security  \
# 84816                                                     0
# 84858                                                     0
#
#        product_category_name_english_small_appliances  \
# 84816                                               0
# 84858                                               0
#
#        product_category_name_english_small_appliances_home_oven_and_coffee  \
# 84816                                                                    0
# 84858                                                                    0
#
#        product_category_name_english_sports_leisure  \
# 84816                                             0
# 84858                                             0
#
#        product_category_name_english_stationery  \
# 84816                                         0
# 84858                                         0
#
#        product_category_name_english_tablets_printing_image  \
# 84816                                                     0
# 84858                                                     0
#
#        product_category_name_english_telephony  \
# 84816                                        0
# 84858                                        0
#
#        product_category_name_english_toys  \
# 84816                                   0
# 84858                                   0
#
#        product_category_name_english_watches_gifts
# 84816                                            0
# 84858                                            0

# %% [markdown]
# Now delete duplicates.

# %%
df_orders_translated.drop_duplicates(inplace = True)

# %%
df_orders_translated.shape
# Out:
# (93996, 102)

# %% [markdown]
# Noe, we got to a customer-level dataframe with a 93,996 customers, we need to delete unnecessary columns and reset the index.

# %%
df_orders_translated = df_orders_translated.reset_index(drop=True)

# %%
df_orders_translated.sample(1)
# Out:
#                                order_id  review_id  \
# 65393  6b6a02cd68662e796263b55aeced16ad          1
#
#                             customer_id  order_approved_at  \
# 65393  f1295cf50f85831a3c9e37651cba8792                1.0
#
#        order_delivered_carrier_date  order_delivered_customer_date  \
# 65393                           2.0                            7.0
#
#        order_estimated_delivery_date  order_item_id  product_id  seller_id  \
# 65393                           27.0              1           1          1
#
#        shipping_limit_date   price  freight_value  payment_sequential  \
# 65393                  7.0  215.56          18.08                   1
#
#        payment_installments  payment_value                customer_unique_id  \
# 65393                     4         233.64  dae89ff4574b8811d0698010c326665a
#
#        review_score  review_creation_date  review_answer_timestamp  \
# 65393           5.0                   7.0                     10.0
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 65393                 29.0                      3758.0                 1.0
#
#        product_weight_g  customer_geolocation_lat  customer_geolocation_lng  \
# 65393            1100.0                 -5.637682                 -35.42299
#
#        order_volume  payment_type_boleto  payment_type_credit_card  \
# 65393        8064.0                    0                         1
#
#        payment_type_debit_card  payment_type_voucher  \
# 65393                        0                     0
#
#        product_category_name_english_agro_industry_and_commerce  \
# 65393                                                         0
#
#        product_category_name_english_air_conditioning  \
# 65393                                               0
#
#        product_category_name_english_art  \
# 65393                                  0
#
#        product_category_name_english_arts_and_craftmanship  \
# 65393                                                    0
#
#        product_category_name_english_audio  \
# 65393                                    0
#
#        product_category_name_english_auto  product_category_name_english_baby  \
# 65393                                   0                                   0
#
#        product_category_name_english_bed_bath_table  \
# 65393                                             0
#
#        product_category_name_english_books_general_interest  \
# 65393                                                     0
#
#        product_category_name_english_books_imported  \
# 65393                                             0
#
#        product_category_name_english_books_technical  \
# 65393                                              0
#
#        product_category_name_english_cds_dvds_musicals  \
# 65393                                                0
#
#        product_category_name_english_christmas_supplies  \
# 65393                                                 0
#
#        product_category_name_english_cine_photo  \
# 65393                                         0
#
#        product_category_name_english_computers  \
# 65393                                        0
#
#        product_category_name_english_computers_accessories  \
# 65393                                                    0
#
#        product_category_name_english_consoles_games  \
# 65393                                             0
#
#        product_category_name_english_construction_tools_construction  \
# 65393                                                              0
#
#        product_category_name_english_construction_tools_lights  \
# 65393                                                        0
#
#        product_category_name_english_construction_tools_safety  \
# 65393                                                        0
#
#        product_category_name_english_cool_stuff  \
# 65393                                         0
#
#        product_category_name_english_costruction_tools_garden  \
# 65393                                                       0
#
#        product_category_name_english_costruction_tools_tools  \
# 65393                                                      0
#
#        product_category_name_english_diapers_and_hygiene  \
# 65393                                                  0
#
#        product_category_name_english_drinks  \
# 65393                                     0
#
#        product_category_name_english_dvds_blu_ray  \
# 65393                                           0
#
#        product_category_name_english_electronics  \
# 65393                                          0
#
#        product_category_name_english_fashio_female_clothing  \
# 65393                                                     0
#
#        product_category_name_english_fashion_bags_accessories  \
# 65393                                                       0
#
#        product_category_name_english_fashion_childrens_clothes  \
# 65393                                                        0
#
#        product_category_name_english_fashion_male_clothing  \
# 65393                                                    0
#
#        product_category_name_english_fashion_shoes  \
# 65393                                            0
#
#        product_category_name_english_fashion_sport  \
# 65393                                            0
#
#        product_category_name_english_fashion_underwear_beach  \
# 65393                                                      0
#
#        product_category_name_english_fixed_telephony  \
# 65393                                              0
#
#        product_category_name_english_flowers  \
# 65393                                      0
#
#        product_category_name_english_food  \
# 65393                                   0
#
#        product_category_name_english_food_drink  \
# 65393                                         1
#
#        product_category_name_english_furniture_bedroom  \
# 65393                                                0
#
#        product_category_name_english_furniture_decor  \
# 65393                                              0
#
#        product_category_name_english_furniture_living_room  \
# 65393                                                    0
#
#        product_category_name_english_furniture_mattress_and_upholstery  \
# 65393                                                                0
#
#        product_category_name_english_garden_tools  \
# 65393                                           0
#
#        product_category_name_english_health_beauty  \
# 65393                                            0
#
#        product_category_name_english_home_appliances  \
# 65393                                              0
#
#        product_category_name_english_home_appliances_2  \
# 65393                                                0
#
#        product_category_name_english_home_comfort_2  \
# 65393                                             0
#
#        product_category_name_english_home_confort  \
# 65393                                           0
#
#        product_category_name_english_home_construction  \
# 65393                                                0
#
#        product_category_name_english_housewares  \
# 65393                                         0
#
#        product_category_name_english_industry_commerce_and_business  \
# 65393                                                             0
#
#        product_category_name_english_kitchen_dining_laundry_garden_furniture  \
# 65393                                                                      0
#
#        product_category_name_english_la_cuisine  \
# 65393                                         0
#
#        product_category_name_english_luggage_accessories  \
# 65393                                                  0
#
#        product_category_name_english_market_place  \
# 65393                                           0
#
#        product_category_name_english_music  \
# 65393                                    0
#
#        product_category_name_english_musical_instruments  \
# 65393                                                  0
#
#        product_category_name_english_office_furniture  \
# 65393                                               0
#
#        product_category_name_english_party_supplies  \
# 65393                                             0
#
#        product_category_name_english_perfumery  \
# 65393                                        0
#
#        product_category_name_english_pet_shop  \
# 65393                                       0
#
#        product_category_name_english_security_and_services  \
# 65393                                                    0
#
#        product_category_name_english_signaling_and_security  \
# 65393                                                     0
#
#        product_category_name_english_small_appliances  \
# 65393                                               0
#
#        product_category_name_english_small_appliances_home_oven_and_coffee  \
# 65393                                                                    0
#
#        product_category_name_english_sports_leisure  \
# 65393                                             0
#
#        product_category_name_english_stationery  \
# 65393                                         0
#
#        product_category_name_english_tablets_printing_image  \
# 65393                                                     0
#
#        product_category_name_english_telephony  \
# 65393                                        0
#
#        product_category_name_english_toys  \
# 65393                                   0
#
#        product_category_name_english_watches_gifts
# 65393                                            0

# %% [markdown]
# The following is to check if there are customers with more than one row on the dataframe.

# %%
(df_orders_translated['customer_id'].value_counts() > 1).sum()
# Out:
# 0

# %% [markdown]
# We need to delete the following columns:
# - order_id
# - customer_id
# - customer_unique_id

# %%
df_orders_translated.drop(['order_id', 'customer_id', 'customer_unique_id'], inplace = True, axis = 1)

# %%
df_orders_translated.shape
# Out:
# (93996, 99)

# %% [markdown]
# Now let us have a final look on our data to make sure it is ready for clustering.

# %%
df_orders_translated.iloc[:,0:24].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93996 entries, 0 to 93995
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   review_id                      93996 non-null  int64
#  1   order_approved_at              93996 non-null  float64
#  2   order_delivered_carrier_date   93996 non-null  float64
#  3   order_delivered_customer_date  93996 non-null  float64
#  4   order_estimated_delivery_date  93996 non-null  float64
#  5   order_item_id                  93996 non-null  int32
#  6   product_id                     93996 non-null  int64
#  7   seller_id                      93996 non-null  int64
#  8   shipping_limit_date            93996 non-null  float64
#  9   price                          93996 non-null  float64
#  10  freight_value                  93996 non-null  float64
#  11  payment_sequential             93996 non-null  int32
#  12  payment_installments           93996 non-null  int32
#  13  payment_value                  93996 non-null  float64
#  14  review_score                   93996 non-null  float64
#  15  review_creation_date           93996 non-null  float64
#  16  review_answer_timestamp        93996 non-null  float64
#  17  product_name_lenght            93996 non-null  float64
#  18  product_description_lenght     93996 non-null  float64
#  19  product_photos_qty             93996 non-null  float64
#  20  product_weight_g               93996 non-null  float64
#  21  customer_geolocation_lat       93996 non-null  float64
#  22  customer_geolocation_lng       93996 non-null  float64
#  23  order_volume                   93996 non-null  float64
# dtypes: float64(18), int32(3), int64(3)
# memory usage: 16.1 MB

# %%
df_orders_translated.iloc[:,0:24].describe().transpose()
# Out:
#                                  count          mean           std  \
# review_id                      93996.0      1.005479      0.074392
# order_approved_at              93996.0      0.264511      0.731052
# order_delivered_carrier_date   93996.0      2.725648      3.573503
# order_delivered_customer_date  93996.0     12.039310      9.457644
# order_estimated_delivery_date  93996.0     23.369463      8.775239
# order_item_id                  93996.0      1.141612      0.535539
# product_id                     93996.0      1.038140      0.226784
# seller_id                      93996.0      1.013692      0.122711
# shipping_limit_date            93996.0      6.400288      4.662419
# price                          93996.0    125.143419    188.102644
# freight_value                  93996.0     20.165826     15.725454
# payment_sequential             93996.0      1.045002      0.369795
# payment_installments           93996.0      2.929465      2.714173
# payment_value                  93996.0    160.518201    218.464216
# review_score                   93996.0      4.157434      1.282280
# review_creation_date           93996.0     11.901893      7.344748
# review_answer_timestamp        93996.0     14.958810     12.341053
# product_name_lenght            93996.0     48.861875      9.941617
# product_description_lenght     93996.0    793.521520    652.623736
# product_photos_qty             93996.0      2.245938      1.736241
# product_weight_g               93996.0   2098.959513   3736.797471
# customer_geolocation_lat       93996.0    -21.203417      5.599472
# customer_geolocation_lng       93996.0    -46.191838      4.054277
# order_volume                   93996.0  15200.033943  23213.443350
#
#                                       min          25%          50%  \
# review_id                        1.000000     1.000000     1.000000
# order_approved_at                0.000000     0.000000     0.000000
# order_delivered_carrier_date  -172.000000     1.000000     2.000000
# order_delivered_customer_date    0.000000     6.000000    10.000000
# order_estimated_delivery_date    2.000000    18.000000    23.000000
# order_item_id                    1.000000     1.000000     1.000000
# product_id                       1.000000     1.000000     1.000000
# seller_id                        1.000000     1.000000     1.000000
# shipping_limit_date              2.000000     5.000000     6.000000
# price                            0.850000    41.990000    79.000000
# freight_value                    0.000000    13.360000    16.370000
# payment_sequential               1.000000     1.000000     1.000000
# payment_installments             0.000000     1.000000     2.000000
# payment_value                    9.590000    62.060000   105.290000
# review_score                     1.000000     4.000000     5.000000
# review_creation_date           -37.000000     7.000000    10.000000
# review_answer_timestamp        -33.000000     9.000000    13.000000
# product_name_lenght              5.000000    43.000000    52.000000
# product_description_lenght       4.000000   351.000000   607.000000
# product_photos_qty               1.000000     1.000000     2.000000
# product_weight_g                 0.000000   300.000000   700.000000
# customer_geolocation_lat       -33.689948   -23.590285   -22.926257
# customer_geolocation_lng       -72.668881   -48.119196   -46.632890
# order_volume                   168.000000  2816.000000  6480.000000
#
#                                         75%            max
# review_id                          1.000000       3.000000
# order_approved_at                  0.000000      30.000000
# order_delivered_carrier_date       4.000000     107.000000
# order_delivered_customer_date     15.000000     208.000000
# order_estimated_delivery_date     28.000000     155.000000
# order_item_id                      1.000000      21.000000
# product_id                         1.000000       8.000000
# seller_id                          1.000000       5.000000
# shipping_limit_date                7.000000    1052.000000
# price                            139.900000    6735.000000
# freight_value                     21.180000     409.680000
# payment_sequential                 1.000000      26.000000
# payment_installments               4.000000      24.000000
# payment_value                    177.440000   13664.080000
# review_score                       5.000000       5.000000
# review_creation_date              16.000000      77.000000
# review_answer_timestamp           19.000000     528.000000
# product_name_lenght               57.000000      76.000000
# product_description_lenght       995.000000    3992.000000
# product_photos_qty                 3.000000      20.000000
# product_weight_g                1813.000000   40425.000000
# customer_geolocation_lat         -20.140324      42.184003
# customer_geolocation_lng         -43.635297      -8.723762
# order_volume                   18400.000000  296208.000000

# %%
plt.subplots(nrows=8, ncols=3, figsize=(12, 18))

for i in range(1,25):
    plt.subplot(8, 3, i)
    plt.hist(df_orders_translated.iloc[:,i-1], bins = 50)
    plt.xlabel('Range')
    plt.ylabel('Frequeny')
    plt.title(df_orders_translated.columns[i-1])
    
plt.tight_layout()    
plt.show()

# %% [markdown]
# ### Modelling & Evaluation

# %% [markdown]
# We will start by utilizing K-mean to cluster our data and try to find customer with similarities.

# %% [markdown]
# First, since K-means is a distance based model, we have to scale our data before modelling.

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
df_orders_translated_ss = s_scaler.fit_transform(df_orders_translated)

# %% [markdown]
# let us look at the data in a dataframe.

# %%
pd.DataFrame(df_orders_translated_ss, columns = df_orders_translated.columns)
# Out:
#        review_id  order_approved_at  order_delivered_carrier_date  \
# 0      -0.073651          -0.361825                     -0.203065
# 1      -0.073651           1.006074                     -0.482903
# 2      -0.073651          -0.361825                     -0.762742
# 3      -0.073651          -0.361825                      0.076774
# 4      -0.073651          -0.361825                     -0.762742
# ...          ...                ...                           ...
# 93991  -0.073651          -0.361825                     -0.482903
# 93992  -0.073651          -0.361825                     -0.482903
# 93993  -0.073651          -0.361825                     -0.482903
# 93994  -0.073651          -0.361825                      0.076774
# 93995  -0.073651          -0.361825                     -0.482903
#
#        order_delivered_customer_date  order_estimated_delivery_date  \
# 0                          -0.427097                      -0.953764
# 1                           0.101579                      -0.497934
# 2                          -0.321362                       0.299770
# 3                           0.101579                       0.299770
# 4                          -1.061508                      -1.295637
# ...                              ...                            ...
# 93991                      -0.427097                      -0.611891
# 93992                       1.053195                      -0.042103
# 93993                       1.264665                       0.755600
# 93994                       0.524519                       1.553304
# 93995                      -0.532832                       0.185812
#
#        order_item_id  product_id  seller_id  shipping_limit_date     price  \
# 0          -0.264431   -0.168178   -0.11158            -0.514819 -0.505862
# 1          -0.264431   -0.168178   -0.11158            -0.300337 -0.034255
# 2          -0.264431   -0.168178   -0.11158            -0.300337  0.184776
# 3          -0.264431   -0.168178   -0.11158            -0.300337 -0.426064
# 4          -0.264431   -0.168178   -0.11158            -0.300337 -0.559503
# ...              ...         ...        ...                  ...       ...
# 93991      -0.264431   -0.168178   -0.11158            -0.085855 -0.282525
# 93992      -0.264431   -0.168178   -0.11158            -0.085855  0.264520
# 93993      -0.264431   -0.168178   -0.11158             0.557592  0.429803
# 93994       1.602855   -0.168178   -0.11158            -0.514819  0.291579
# 93995      -0.264431   -0.168178   -0.11158            -0.085855 -0.301132
#
#        freight_value  payment_sequential  payment_installments  payment_value  \
# 0          -0.727857            5.286740             -0.710889      -0.557569
# 1           0.164967           -0.121695             -0.710889      -0.087238
# 2          -0.060147           -0.121695              0.025988       0.085148
# 3           0.447314           -0.121695             -0.710889      -0.404271
# 4          -0.727857           -0.121695             -0.710889      -0.603755
# ...              ...                 ...                   ...            ...
# 93991      -0.450598           -0.121695              0.025988      -0.345313
# 93992      -0.004186           -0.121695              0.025988       0.157838
# 93993       2.852345           -0.121695              0.762864       0.505769
# 93994       1.298804           -0.121695              0.394426       1.284619
# 93995      -0.114835           -0.121695             -0.710889      -0.337165
#
#        review_score  review_creation_date  review_answer_timestamp  \
# 0         -0.122777             -0.531252                -0.482847
# 1         -0.122777              0.285662                -0.077693
# 2          0.657088             -0.395100                -0.077693
# 3          0.657088              0.285662                 0.084368
# 4          0.657088             -1.212014                -0.888001
# ...             ...                   ...                      ...
# 93991      0.657088              0.013358                -0.077693
# 93992     -0.122777              1.374882                 0.732615
# 93993      0.657088              1.783339                 0.894676
# 93994     -1.682507              0.694120                 0.246430
# 93995      0.657088             -0.531252                -0.563878
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                -0.891396                   -0.805249            1.010269
# 1                -1.997862                   -0.943154           -0.717610
# 2                -0.287870                   -0.860411           -0.717610
# 3                 1.019772                   -0.498792            0.434310
# 4                -1.092572                   -0.731699            1.010269
# ...                    ...                         ...                 ...
# 93991             0.114482                    1.108575           -0.717610
# 93992             0.315657                    0.052831            1.010269
# 93993             0.215069                   -0.449759           -0.141650
# 93994             1.019772                    1.684714           -0.717610
# 93995            -0.388457                   -0.344031           -0.717610
#
#        product_weight_g  customer_geolocation_lat  customer_geolocation_lng  \
# 0             -0.427898                 -0.423893                 -0.097508
# 1             -0.454659                  1.611856                  0.377659
# 2             -0.449307                  0.796199                 -0.572965
# 3             -0.441278                  2.755494                  2.693637
# 4             -0.494801                 -0.441643                 -0.079617
# ...                 ...                       ...                       ...
# 93991         -0.247261                 -0.352639                  0.075975
# 93992          0.762968                 -0.499707                 -0.063643
# 93993          2.997513                  0.590248                  1.681741
# 93994          1.191144                 -0.242776                  0.862616
# 93995         -0.521562                 -0.814526                 -0.870329
#
#        order_volume  payment_type_boleto  payment_type_credit_card  \
# 0         -0.569674            -0.482631                  0.391601
# 1         -0.452630             1.847860                 -1.631202
# 2         -0.242276            -0.482631                  0.391601
# 3         -0.396326            -0.482631                  0.391601
# 4         -0.160470            -0.482631                  0.391601
# ...             ...                  ...                       ...
# 93991     -0.433029            -0.482631                  0.391601
# 93992      0.034462            -0.482631                  0.391601
# 93993      2.074669            -0.482631                  0.391601
# 93994     -0.310168            -0.482631                  0.391601
# 93995     -0.582426            -0.482631                 -1.631202
#
#        payment_type_debit_card  payment_type_voucher  \
# 0                    -0.121263              4.689344
# 1                    -0.121263             -0.193775
# 2                    -0.121263             -0.193775
# 3                    -0.121263             -0.193775
# 4                    -0.121263             -0.193775
# ...                        ...                   ...
# 93991                -0.121263             -0.193775
# 93992                -0.121263             -0.193775
# 93993                -0.121263             -0.193775
# 93994                -0.121263             -0.193775
# 93995                 7.402318             -0.193775
#
#        product_category_name_english_agro_industry_and_commerce  \
# 0                                                     -0.042881
# 1                                                     -0.042881
# 2                                                     -0.042881
# 3                                                     -0.042881
# 4                                                     -0.042881
# ...                                                         ...
# 93991                                                 -0.042881
# 93992                                                 -0.042881
# 93993                                                 -0.042881
# 93994                                                 -0.042881
# 93995                                                 -0.042881
#
#        product_category_name_english_air_conditioning  \
# 0                                            -0.05041
# 1                                            -0.05041
# 2                                            -0.05041
# 3                                            -0.05041
# 4                                            -0.05041
# ...                                               ...
# 93991                                        -0.05041
# 93992                                        -0.05041
# 93993                                        -0.05041
# 93994                                        -0.05041
# 93995                                        -0.05041
#
#        product_category_name_english_art  \
# 0                              -0.044638
# 1                              -0.044638
# 2                              -0.044638
# 3                              -0.044638
# 4                              -0.044638
# ...                                  ...
# 93991                          -0.044638
# 93992                          -0.044638
# 93993                          -0.044638
# 93994                          -0.044638
# 93995                          -0.044638
#
#        product_category_name_english_arts_and_craftmanship  \
# 0                                                -0.015354
# 1                                                -0.015354
# 2                                                -0.015354
# 3                                                -0.015354
# 4                                                -0.015354
# ...                                                    ...
# 93991                                            -0.015354
# 93992                                            -0.015354
# 93993                                            -0.015354
# 93994                                            -0.015354
# 93995                                            -0.015354
#
#        product_category_name_english_audio  \
# 0                                -0.059605
# 1                                -0.059605
# 2                                -0.059605
# 3                                -0.059605
# 4                                -0.059605
# ...                                    ...
# 93991                            -0.059605
# 93992                            -0.059605
# 93993                            -0.059605
# 93994                            -0.059605
# 93995                            -0.059605
#
#        product_category_name_english_auto  product_category_name_english_baby  \
# 0                               -0.198499                           -0.170312
# 1                               -0.198499                           -0.170312
# 2                                4.487114                           -0.170312
# 3                               -0.198499                           -0.170312
# 4                               -0.198499                           -0.170312
# ...                                   ...                                 ...
# 93991                           -0.198499                           -0.170312
# 93992                           -0.198499                            5.340416
# 93993                           -0.198499                           -0.170312
# 93994                           -0.198499                           -0.170312
# 93995                           -0.198499                           -0.170312
#
#        product_category_name_english_bed_bath_table  \
# 0                                         -0.304334
# 1                                         -0.304334
# 2                                         -0.304334
# 3                                         -0.304334
# 4                                         -0.304334
# ...                                             ...
# 93991                                     -0.304334
# 93992                                     -0.304334
# 93993                                     -0.304334
# 93994                                     -0.304334
# 93995                                     -0.304334
#
#        product_category_name_english_books_general_interest  \
# 0                                                 -0.070162
# 1                                                 -0.070162
# 2                                                 -0.070162
# 3                                                 -0.070162
# 4                                                 -0.070162
# ...                                                     ...
# 93991                                             -0.070162
# 93992                                             -0.070162
# 93993                                             -0.070162
# 93994                                             -0.070162
# 93995                                             -0.070162
#
#        product_category_name_english_books_imported  \
# 0                                         -0.021156
# 1                                         -0.021156
# 2                                         -0.021156
# 3                                         -0.021156
# 4                                         -0.021156
# ...                                             ...
# 93991                                     -0.021156
# 93992                                     -0.021156
# 93993                                     -0.021156
# 93994                                     -0.021156
# 93995                                     -0.021156
#
#        product_category_name_english_books_technical  \
# 0                                          -0.051345
# 1                                          -0.051345
# 2                                          -0.051345
# 3                                          -0.051345
# 4                                          -0.051345
# ...                                              ...
# 93991                                      -0.051345
# 93992                                      -0.051345
# 93993                                      -0.051345
# 93994                                      -0.051345
# 93995                                      -0.051345
#
#        product_category_name_english_cds_dvds_musicals  \
# 0                                              -0.0113
# 1                                              -0.0113
# 2                                              -0.0113
# 3                                              -0.0113
# 4                                              -0.0113
# ...                                                ...
# 93991                                          -0.0113
# 93992                                          -0.0113
# 93993                                          -0.0113
# 93994                                          -0.0113
# 93995                                          -0.0113
#
#        product_category_name_english_christmas_supplies  \
# 0                                             -0.035675
# 1                                             -0.035675
# 2                                             -0.035675
# 3                                             -0.035675
# 4                                             -0.035675
# ...                                                 ...
# 93991                                         -0.035675
# 93992                                         -0.035675
# 93993                                         -0.035675
# 93994                                         -0.035675
# 93995                                         -0.035675
#
#        product_category_name_english_cine_photo  \
# 0                                     -0.025378
# 1                                     -0.025378
# 2                                     -0.025378
# 3                                     -0.025378
# 4                                     -0.025378
# ...                                         ...
# 93991                                 -0.025378
# 93992                                 -0.025378
# 93993                                 -0.025378
# 93994                                 -0.025378
# 93995                                 -0.025378
#
#        product_category_name_english_computers  \
# 0                                     -0.04193
# 1                                     -0.04193
# 2                                     -0.04193
# 3                                     -0.04193
# 4                                     -0.04193
# ...                                        ...
# 93991                                 -0.04193
# 93992                                 -0.04193
# 93993                                 -0.04193
# 93994                                 -0.04193
# 93995                                 -0.04193
#
#        product_category_name_english_computers_accessories  \
# 0                                                -0.263639
# 1                                                -0.263639
# 2                                                -0.263639
# 3                                                -0.263639
# 4                                                -0.263639
# ...                                                    ...
# 93991                                            -0.263639
# 93992                                            -0.263639
# 93993                                            -0.263639
# 93994                                             3.346120
# 93995                                            -0.263639
#
#        product_category_name_english_consoles_games  \
# 0                                         -0.101704
# 1                                         -0.101704
# 2                                         -0.101704
# 3                                         -0.101704
# 4                                         -0.101704
# ...                                             ...
# 93991                                     -0.101704
# 93992                                     -0.101704
# 93993                                     -0.101704
# 93994                                     -0.101704
# 93995                                     -0.101704
#
#        product_category_name_english_construction_tools_construction  \
# 0                                                          -0.081688
# 1                                                          -0.081688
# 2                                                          -0.081688
# 3                                                          -0.081688
# 4                                                          -0.081688
# ...                                                              ...
# 93991                                                      -0.081688
# 93992                                                      -0.081688
# 93993                                                      -0.081688
# 93994                                                      -0.081688
# 93995                                                      -0.081688
#
#        product_category_name_english_construction_tools_lights  \
# 0                                                    -0.049443
# 1                                                    -0.049443
# 2                                                    -0.049443
# 3                                                    -0.049443
# 4                                                    -0.049443
# ...                                                        ...
# 93991                                                -0.049443
# 93992                                                -0.049443
# 93993                                                -0.049443
# 93994                                                -0.049443
# 93995                                                -0.049443
#
#        product_category_name_english_construction_tools_safety  \
# 0                                                    -0.040222
# 1                                                    -0.040222
# 2                                                    -0.040222
# 3                                                    -0.040222
# 4                                                    -0.040222
# ...                                                        ...
# 93991                                                -0.040222
# 93992                                                -0.040222
# 93993                                                -0.040222
# 93994                                                -0.040222
# 93995                                                -0.040222
#
#        product_category_name_english_cool_stuff  \
# 0                                     -0.192308
# 1                                     -0.192308
# 2                                     -0.192308
# 3                                     -0.192308
# 4                                     -0.192308
# ...                                         ...
# 93991                                 -0.192308
# 93992                                 -0.192308
# 93993                                 -0.192308
# 93994                                 -0.192308
# 93995                                 -0.192308
#
#        product_category_name_english_costruction_tools_garden  \
# 0                                                   -0.042638
# 1                                                   -0.042638
# 2                                                   -0.042638
# 3                                                   -0.042638
# 4                                                   -0.042638
# ...                                                       ...
# 93991                                               -0.042638
# 93992                                               -0.042638
# 93993                                               -0.042638
# 93994                                               -0.042638
# 93995                                               -0.042638
#
#        product_category_name_english_costruction_tools_tools  \
# 0                                                  -0.031328
# 1                                                  -0.031328
# 2                                                  -0.031328
# 3                                                  -0.031328
# 4                                                  -0.031328
# ...                                                      ...
# 93991                                              -0.031328
# 93992                                              -0.031328
# 93993                                              -0.031328
# 93994                                              -0.031328
# 93995                                              -0.031328
#
#        product_category_name_english_diapers_and_hygiene  \
# 0                                              -0.016311
# 1                                              -0.016311
# 2                                              -0.016311
# 3                                              -0.016311
# 4                                              -0.016311
# ...                                                  ...
# 93991                                          -0.016311
# 93992                                          -0.016311
# 93993                                          -0.016311
# 93994                                          -0.016311
# 93995                                          -0.016311
#
#        product_category_name_english_drinks  \
# 0                                 -0.051075
# 1                                 -0.051075
# 2                                 -0.051075
# 3                                 -0.051075
# 4                                 -0.051075
# ...                                     ...
# 93991                             -0.051075
# 93992                             -0.051075
# 93993                             -0.051075
# 93994                             -0.051075
# 93995                             -0.051075
#
#        product_category_name_english_dvds_blu_ray  \
# 0                                       -0.023739
# 1                                       -0.023739
# 2                                       -0.023739
# 3                                       -0.023739
# 4                                       -0.023739
# ...                                           ...
# 93991                                   -0.023739
# 93992                                   -0.023739
# 93993                                   -0.023739
# 93994                                   -0.023739
# 93995                                   -0.023739
#
#        product_category_name_english_electronics  \
# 0                                      -0.160186
# 1                                      -0.160186
# 2                                      -0.160186
# 3                                      -0.160186
# 4                                      -0.160186
# ...                                          ...
# 93991                                  -0.160186
# 93992                                  -0.160186
# 93993                                  -0.160186
# 93994                                  -0.160186
# 93995                                  -0.160186
#
#        product_category_name_english_fashio_female_clothing  \
# 0                                                 -0.019129
# 1                                                 -0.019129
# 2                                                 -0.019129
# 3                                                 -0.019129
# 4                                                 -0.019129
# ...                                                     ...
# 93991                                             -0.019129
# 93992                                             -0.019129
# 93993                                             -0.019129
# 93994                                             -0.019129
# 93995                                             -0.019129
#
#        product_category_name_english_fashion_bags_accessories  \
# 0                                                   -0.131071
# 1                                                   -0.131071
# 2                                                   -0.131071
# 3                                                   -0.131071
# 4                                                   -0.131071
# ...                                                       ...
# 93991                                               -0.131071
# 93992                                               -0.131071
# 93993                                               -0.131071
# 93994                                               -0.131071
# 93995                                               -0.131071
#
#        product_category_name_english_fashion_childrens_clothes  \
# 0                                                     -0.00863
# 1                                                     -0.00863
# 2                                                     -0.00863
# 3                                                     -0.00863
# 4                                                     -0.00863
# ...                                                        ...
# 93991                                                 -0.00863
# 93992                                                 -0.00863
# 93993                                                 -0.00863
# 93994                                                 -0.00863
# 93995                                                 -0.00863
#
#        product_category_name_english_fashion_male_clothing  \
# 0                                                -0.029993
# 1                                                -0.029993
# 2                                                -0.029993
# 3                                                -0.029993
# 4                                                -0.029993
# ...                                                    ...
# 93991                                            -0.029993
# 93992                                            -0.029993
# 93993                                            -0.029993
# 93994                                            -0.029993
# 93995                                            -0.029993
#
#        product_category_name_english_fashion_shoes  \
# 0                                         -0.04604
# 1                                         -0.04604
# 2                                         -0.04604
# 3                                         -0.04604
# 4                                         -0.04604
# ...                                            ...
# 93991                                     -0.04604
# 93992                                     -0.04604
# 93993                                     -0.04604
# 93994                                     -0.04604
# 93995                                     -0.04604
#
#        product_category_name_english_fashion_sport  \
# 0                                        -0.016311
# 1                                        -0.016311
# 2                                        -0.016311
# 3                                        -0.016311
# 4                                        -0.016311
# ...                                            ...
# 93991                                    -0.016311
# 93992                                    -0.016311
# 93993                                    -0.016311
# 93994                                    -0.016311
# 93995                                    -0.016311
#
#        product_category_name_english_fashion_underwear_beach  \
# 0                                                  -0.034396
# 1                                                  -0.034396
# 2                                                  -0.034396
# 3                                                  -0.034396
# 4                                                  -0.034396
# ...                                                      ...
# 93991                                              -0.034396
# 93992                                              -0.034396
# 93993                                              -0.034396
# 93994                                              -0.034396
# 93995                                              -0.034396
#
#        product_category_name_english_fixed_telephony  \
# 0                                          -0.046481
# 1                                          -0.046481
# 2                                          -0.046481
# 3                                          -0.046481
# 4                                          -0.046481
# ...                                              ...
# 93991                                      -0.046481
# 93992                                      -0.046481
# 93993                                      -0.046481
# 93994                                      -0.046481
# 93995                                      -0.046481
#
#        product_category_name_english_flowers  \
# 0                                  -0.017262
# 1                                  -0.017262
# 2                                  -0.017262
# 3                                  -0.017262
# 4                                  -0.017262
# ...                                      ...
# 93991                              -0.017262
# 93992                              -0.017262
# 93993                              -0.017262
# 93994                              -0.017262
# 93995                              -0.017262
#
#        product_category_name_english_food  \
# 0                                -0.06745
# 1                                -0.06745
# 2                                -0.06745
# 3                                -0.06745
# 4                                -0.06745
# ...                                   ...
# 93991                            -0.06745
# 93992                            -0.06745
# 93993                            -0.06745
# 93994                            -0.06745
# 93995                            -0.06745
#
#        product_category_name_english_food_drink  \
# 0                                     -0.046328
# 1                                     -0.046328
# 2                                     -0.046328
# 3                                     -0.046328
# 4                                     -0.046328
# ...                                         ...
# 93991                                 -0.046328
# 93992                                 -0.046328
# 93993                                 -0.046328
# 93994                                 -0.046328
# 93995                                 -0.046328
#
#        product_category_name_english_furniture_bedroom  \
# 0                                            -0.030793
# 1                                            -0.030793
# 2                                            -0.030793
# 3                                            -0.030793
# 4                                            -0.030793
# ...                                                ...
# 93991                                        -0.030793
# 93992                                        -0.030793
# 93993                                        -0.030793
# 93994                                        -0.030793
# 93995                                        -0.030793
#
#        product_category_name_english_furniture_decor  \
# 0                                          -0.251897
# 1                                          -0.251897
# 2                                          -0.251897
# 3                                          -0.251897
# 4                                          -0.251897
# ...                                              ...
# 93991                                      -0.251897
# 93992                                      -0.251897
# 93993                                      -0.251897
# 93994                                      -0.251897
# 93995                                      -0.251897
#
#        product_category_name_english_furniture_living_room  \
# 0                                                -0.062019
# 1                                                -0.062019
# 2                                                -0.062019
# 3                                                -0.062019
# 4                                                -0.062019
# ...                                                    ...
# 93991                                            -0.062019
# 93992                                            -0.062019
# 93993                                            -0.062019
# 93994                                            -0.062019
# 93995                                            -0.062019
#
#        product_category_name_english_furniture_mattress_and_upholstery  \
# 0                                                            -0.019601
# 1                                                            -0.019601
# 2                                                            -0.019601
# 3                                                            -0.019601
# 4                                                            -0.019601
# ...                                                                ...
# 93991                                                        -0.019601
# 93992                                                        -0.019601
# 93993                                                        -0.019601
# 93994                                                        -0.019601
# 93995                                                        -0.019601
#
#        product_category_name_english_garden_tools  \
# 0                                       -0.187985
# 1                                       -0.187985
# 2                                       -0.187985
# 3                                       -0.187985
# 4                                       -0.187985
# ...                                           ...
# 93991                                   -0.187985
# 93992                                   -0.187985
# 93993                                   -0.187985
# 93994                                   -0.187985
# 93995                                   -0.187985
#
#        product_category_name_english_health_beauty  \
# 0                                        -0.309253
# 1                                        -0.309253
# 2                                        -0.309253
# 3                                        -0.309253
# 4                                        -0.309253
# ...                                            ...
# 93991                                     2.938268
# 93992                                    -0.309253
# 93993                                    -0.309253
# 93994                                    -0.309253
# 93995                                     2.938268
#
#        product_category_name_english_home_appliances  \
# 0                                          -0.086395
# 1                                          -0.086395
# 2                                          -0.086395
# 3                                          -0.086395
# 4                                          -0.086395
# ...                                              ...
# 93991                                      -0.086395
# 93992                                      -0.086395
# 93993                                      -0.086395
# 93994                                      -0.086395
# 93995                                      -0.086395
#
#        product_category_name_english_home_appliances_2  \
# 0                                            -0.048391
# 1                                            -0.048391
# 2                                            -0.048391
# 3                                            -0.048391
# 4                                            -0.048391
# ...                                                ...
# 93991                                        -0.048391
# 93992                                        -0.048391
# 93993                                        19.642232
# 93994                                        -0.048391
# 93995                                        -0.048391
#
#        product_category_name_english_home_comfort_2  \
# 0                                         -0.015354
# 1                                         -0.015354
# 2                                         -0.015354
# 3                                         -0.015354
# 4                                         -0.015354
# ...                                             ...
# 93991                                     -0.015354
# 93992                                     -0.015354
# 93993                                     -0.015354
# 93994                                     -0.015354
# 93995                                     -0.015354
#
#        product_category_name_english_home_confort  \
# 0                                       -0.063082
# 1                                       -0.063082
# 2                                       -0.063082
# 3                                       -0.063082
# 4                                       -0.063082
# ...                                           ...
# 93991                                   -0.063082
# 93992                                   -0.063082
# 93993                                   -0.063082
# 93994                                   -0.063082
# 93995                                   -0.063082
#
#        product_category_name_english_home_construction  \
# 0                                            -0.070141
# 1                                            -0.070141
# 2                                            -0.070141
# 3                                            -0.070141
# 4                                            -0.070141
# ...                                                ...
# 93991                                        -0.070141
# 93992                                        -0.070141
# 93993                                        -0.070141
# 93994                                        -0.070141
# 93995                                        -0.070141
#
#        product_category_name_english_housewares  \
# 0                                      7.452007
# 1                                     -0.246231
# 2                                     -0.246231
# 3                                     -0.246231
# 4                                     -0.246231
# ...                                         ...
# 93991                                 -0.246231
# 93992                                 -0.246231
# 93993                                 -0.246231
# 93994                                 -0.246231
# 93995                                 -0.246231
#
#        product_category_name_english_industry_commerce_and_business  \
# 0                                                         -0.048386
# 1                                                         -0.048386
# 2                                                         -0.048386
# 3                                                         -0.048386
# 4                                                         -0.048386
# ...                                                             ...
# 93991                                                     -0.048386
# 93992                                                     -0.048386
# 93993                                                     -0.048386
# 93994                                                     -0.048386
# 93995                                                     -0.048386
#
#        product_category_name_english_kitchen_dining_laundry_garden_furniture  \
# 0                                                                  -0.049984
# 1                                                                  -0.049984
# 2                                                                  -0.049984
# 3                                                                  -0.049984
# 4                                                                  -0.049984
# ...                                                                      ...
# 93991                                                              -0.049984
# 93992                                                              -0.049984
# 93993                                                              -0.049984
# 93994                                                              -0.049984
# 93995                                                              -0.049984
#
#        product_category_name_english_la_cuisine  \
# 0                                     -0.010764
# 1                                     -0.010764
# 2                                     -0.010764
# 3                                     -0.010764
# 4                                     -0.010764
# ...                                         ...
# 93991                                 -0.010764
# 93992                                 -0.010764
# 93993                                 -0.010764
# 93994                                 -0.010764
# 93995                                 -0.010764
#
#        product_category_name_english_luggage_accessories  \
# 0                                              -0.101951
# 1                                              -0.101951
# 2                                              -0.101951
# 3                                              -0.101951
# 4                                              -0.101951
# ...                                                  ...
# 93991                                          -0.101951
# 93992                                          -0.101951
# 93993                                          -0.101951
# 93994                                          -0.101951
# 93995                                          -0.101951
#
#        product_category_name_english_market_place  \
# 0                                       -0.052585
# 1                                       -0.052585
# 2                                       -0.052585
# 3                                       -0.052585
# 4                                       -0.052585
# ...                                           ...
# 93991                                   -0.052585
# 93992                                   -0.052585
# 93993                                   -0.052585
# 93994                                   -0.052585
# 93995                                   -0.052585
#
#        product_category_name_english_music  \
# 0                                 -0.01987
# 1                                 -0.01987
# 2                                 -0.01987
# 3                                 -0.01987
# 4                                 -0.01987
# ...                                    ...
# 93991                             -0.01987
# 93992                             -0.01987
# 93993                             -0.01987
# 93994                             -0.01987
# 93995                             -0.01987
#
#        product_category_name_english_musical_instruments  \
# 0                                              -0.079233
# 1                                              -0.079233
# 2                                              -0.079233
# 3                                              -0.079233
# 4                                              -0.079233
# ...                                                  ...
# 93991                                          -0.079233
# 93992                                          -0.079233
# 93993                                          -0.079233
# 93994                                          -0.079233
# 93995                                          -0.079233
#
#        product_category_name_english_office_furniture  \
# 0                                           -0.112746
# 1                                           -0.112746
# 2                                           -0.112746
# 3                                           -0.112746
# 4                                           -0.112746
# ...                                               ...
# 93991                                       -0.112746
# 93992                                       -0.112746
# 93993                                       -0.112746
# 93994                                       -0.112746
# 93995                                       -0.112746
#
#        product_category_name_english_party_supplies  \
# 0                                          -0.01987
# 1                                          -0.01987
# 2                                          -0.01987
# 3                                          -0.01987
# 4                                          -0.01987
# ...                                             ...
# 93991                                      -0.01987
# 93992                                      -0.01987
# 93993                                      -0.01987
# 93994                                      -0.01987
# 93995                                      -0.01987
#
#        product_category_name_english_perfumery  \
# 0                                    -0.177826
# 1                                     5.003503
# 2                                    -0.177826
# 3                                    -0.177826
# 4                                    -0.177826
# ...                                        ...
# 93991                                -0.177826
# 93992                                -0.177826
# 93993                                -0.177826
# 93994                                -0.177826
# 93995                                -0.177826
#
#        product_category_name_english_pet_shop  \
# 0                                   -0.129984
# 1                                   -0.129984
# 2                                   -0.129984
# 3                                    6.772850
# 4                                   -0.129984
# ...                                       ...
# 93991                               -0.129984
# 93992                               -0.129984
# 93993                               -0.129984
# 93994                               -0.129984
# 93995                               -0.129984
#
#        product_category_name_english_security_and_services  \
# 0                                                -0.004613
# 1                                                -0.004613
# 2                                                -0.004613
# 3                                                -0.004613
# 4                                                -0.004613
# ...                                                    ...
# 93991                                            -0.004613
# 93992                                            -0.004613
# 93993                                            -0.004613
# 93994                                            -0.004613
# 93995                                            -0.004613
#
#        product_category_name_english_signaling_and_security  \
# 0                                                 -0.037394
# 1                                                 -0.037394
# 2                                                 -0.037394
# 3                                                 -0.037394
# 4                                                 -0.037394
# ...                                                     ...
# 93991                                             -0.037394
# 93992                                             -0.037394
# 93993                                             -0.037394
# 93994                                             -0.037394
# 93995                                             -0.037394
#
#        product_category_name_english_small_appliances  \
# 0                                            -0.07938
# 1                                            -0.07938
# 2                                            -0.07938
# 3                                            -0.07938
# 4                                            -0.07938
# ...                                               ...
# 93991                                        -0.07938
# 93992                                        -0.07938
# 93993                                        -0.07938
# 93994                                        -0.07938
# 93995                                        -0.07938
#
#        product_category_name_english_small_appliances_home_oven_and_coffee  \
# 0                                                                -0.027504
# 1                                                                -0.027504
# 2                                                                -0.027504
# 3                                                                -0.027504
# 4                                                                -0.027504
# ...                                                                    ...
# 93991                                                            -0.027504
# 93992                                                            -0.027504
# 93993                                                            -0.027504
# 93994                                                            -0.027504
# 93995                                                            -0.027504
#
#        product_category_name_english_sports_leisure  \
# 0                                         -0.285484
# 1                                         -0.285484
# 2                                         -0.285484
# 3                                         -0.285484
# 4                                         -0.285484
# ...                                             ...
# 93991                                     -0.285484
# 93992                                     -0.285484
# 93993                                     -0.285484
# 93994                                     -0.285484
# 93995                                     -0.285484
#
#        product_category_name_english_stationery  \
# 0                                     -0.152037
# 1                                     -0.152037
# 2                                     -0.152037
# 3                                     -0.152037
# 4                                      5.888065
# ...                                         ...
# 93991                                 -0.152037
# 93992                                 -0.152037
# 93993                                 -0.152037
# 93994                                 -0.152037
# 93995                                 -0.152037
#
#        product_category_name_english_tablets_printing_image  \
# 0                                                 -0.028149
# 1                                                 -0.028149
# 2                                                 -0.028149
# 3                                                 -0.028149
# 4                                                 -0.028149
# ...                                                     ...
# 93991                                             -0.028149
# 93992                                             -0.028149
# 93993                                             -0.028149
# 93994                                             -0.028149
# 93995                                             -0.028149
#
#        product_category_name_english_telephony  \
# 0                                    -0.207116
# 1                                    -0.207116
# 2                                    -0.207116
# 3                                    -0.207116
# 4                                    -0.207116
# ...                                        ...
# 93991                                -0.207116
# 93992                                -0.207116
# 93993                                -0.207116
# 93994                                -0.207116
# 93995                                -0.207116
#
#        product_category_name_english_toys  \
# 0                               -0.197585
# 1                               -0.197585
# 2                               -0.197585
# 3                               -0.197585
# 4                               -0.197585
# ...                                   ...
# 93991                           -0.197585
# 93992                           -0.197585
# 93993                           -0.197585
# 93994                           -0.197585
# 93995                           -0.197585
#
#        product_category_name_english_watches_gifts
# 0                                        -0.240516
# 1                                        -0.240516
# 2                                        -0.240516
# 3                                        -0.240516
# 4                                        -0.240516
# ...                                            ...
# 93991                                    -0.240516
# 93992                                    -0.240516
# 93993                                    -0.240516
# 93994                                    -0.240516
# 93995                                    -0.240516
#
# [93996 rows x 99 columns]

# %%
from sklearn.cluster import KMeans

# %%
# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_ss)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %% [markdown]
# Now let us use the elbow method to use the most appropriate k value.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %% [markdown]
# The StandardScaler results seems strange. there is no elbow on the graph above until 19 clusters, there is no point on going beyond that. Let us use MinMaxscaler instead and check the results.

# %%
from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
df_orders_translated_mm = mm_scaler.fit_transform(df_orders_translated)

# %%
# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_mm)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %% [markdown]
# Perfect, it is clear here that we can safely say there are **6 clusters** on our data. We will come back later and see as to why MinMaxscaler resulted in 6 clusters while StandardScaler did not. For now we will keep moving on out analysis.

# %% [markdown]
# Now let us use Silhouette Score to evaluate our clusters. It measures how similar the points in the same clusters which is a composition of the mean distances int he cluster and the mean distances in other clusters.

# %%
from sklearn.metrics import silhouette_score

# %%
# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of silhouette scores
silhouette_scores = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k)

    # Fit
    k_means_model.fit(df_orders_translated_mm)
    
    # Get cluster labels and calculate silhouette score
    cluster_labels = k_means_model.predict(df_orders_translated_mm)
    silhouette = silhouette_score(df_orders_translated_mm, cluster_labels)
    
    # Append to list
    silhouette_scores.append(silhouette)
    print(f'silhouette_scores for k =  {k} finished.', end='\r')
# Out:
# silhouette_scores for k =  19 finished.

# %%
# plot the Silhouette score 
plt.figure()
plt.plot(k_range, silhouette_scores, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette score Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(3, 2, figsize=(15,8))
for i in [2, 3, 4, 5, 6, 7]:
    '''
    Create KMeans instance for different number of clusters
    '''
    k_means_model = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(k_means_model, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df_orders_translated_mm)

# %% [markdown]
# davies_bouldin_score = a ratio between the cluster scatter and the cluster’s separation.

# %%
from sklearn.metrics import davies_bouldin_score


# Instantiate an empty list of Davies Bouldin Index
DB_scores = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k)

    # Fit
    k_means_model.fit(df_orders_translated_mm)
    
    # Get cluster labels and calculate silhouette score
    cluster_labels = k_means_model.predict(df_orders_translated_mm)
    DB = davies_bouldin_score(df_orders_translated_mm, cluster_labels)
    
    # Append to list
    DB_scores.append(DB)
    print(f'Davies Bouldin Index for k =  {k} finished.', end='\r')
# Out:
# Davies Bouldin Index for k =  19 finished.

# %%
# plot the Davies Bouldin Index
plt.figure()
plt.plot(k_range, DB_scores, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Davies Bouldin Index')
plt.title('Davies Bouldin Index Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %% [markdown]
# Let us try the DBScan algorithm, trying to look for some consistency across different algorithms.

# %% [markdown]
# Try without the geolocation data

# %%
df_orders_translated_ng = df_orders_translated.drop(['customer_geolocation_lat', 'customer_geolocation_lng'], axis = 1)

# %%
df_orders_translated.shape, df_orders_translated_ng.shape
# Out:
# ((93996, 99), (93996, 97))

# %%
s_scaler = StandardScaler()
df_orders_translated_ng_ss = s_scaler.fit_transform(df_orders_translated_ng)

# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_ng_ss)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %%
mm_scaler = MinMaxScaler()
df_orders_translated_ng_mm = mm_scaler.fit_transform(df_orders_translated_ng)

# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_ng_mm)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %% [markdown]
# Try without the sparse data

# %%
df_orders_translated.columns[:-75]
# Out:
# Index(['review_id', 'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'payment_sequential', 'payment_installments',
#        'payment_value', 'review_score', 'review_creation_date',
#        'review_answer_timestamp', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'customer_geolocation_lat', 'customer_geolocation_lng', 'order_volume'],
#       dtype='object')

# %%
df_orders_translated_ns = df_orders_translated[df_orders_translated.columns[:-75]]

# %%
df_orders_translated.shape, df_orders_translated_ns.shape
# Out:
# ((93996, 99), (93996, 24))

# %%
s_scaler = StandardScaler()
df_orders_translated_ns_ss = s_scaler.fit_transform(df_orders_translated_ns)

# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_ns_ss)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %%
mm_scaler = MinMaxScaler()
df_orders_translated_ns_mm = mm_scaler.fit_transform(df_orders_translated_ns)

# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=1, 2,... 19

    # Fit
    k_means_model.fit(df_orders_translated_ns_mm)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  19 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %%
# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of silhouette scores
silhouette_scores = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k)

    # Fit
    k_means_model.fit(df_orders_translated_ns_mm)
    
    # Get cluster labels and calculate silhouette score
    cluster_labels = k_means_model.predict(df_orders_translated_ns_mm)
    silhouette = silhouette_score(df_orders_translated_ns_mm, cluster_labels)
    
    # Append to list
    silhouette_scores.append(silhouette)
    print(f'silhouette_scores for k =  {k} finished.', end='\r')

# %%
# plot the Silhouette score 
plt.figure()
plt.plot(k_range, silhouette_scores, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette score Vs Different K-values')
plt.xticks(k_range)
plt.show();

# %% [markdown]
# GMM

# %%
from sklearn import mixture

# %%
# Look over a range of K values
k_range = np.arange(2, 20)

# Instantiate an empty list of silhouette scores
silhouette_scores = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    gmm = mixture.GaussianMixture(n_components=k, covariance_type='full')

    # Fit
    gmm.fit(df_orders_translated_ns_mm)
    
    # Get cluster labels and calculate silhouette score
    cluster_labels = gmm.predict(df_orders_translated_ns_mm)
    silhouette = silhouette_score(df_orders_translated_ns_mm, cluster_labels)
    
    # Append to list
    silhouette_scores.append(silhouette)
    print(f'silhouette_scores for k =  {k} finished.', end='\r')
# Out:
# silhouette_scores for k =  19 finished.

# %%
# plot the Silhouette score 
plt.figure()
plt.plot(k_range, silhouette_scores, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette score Vs Different GMM Clusters')
plt.xticks(k_range)
plt.show();

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93996 entries, 0 to 93995
# Data columns (total 99 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   review_id                                                              93996 non-null  int32
#  1   order_approved_at                                                      93996 non-null  float32
#  2   order_delivered_carrier_date                                           93996 non-null  float32
#  3   order_delivered_customer_date                                          93996 non-null  float32
#  4   order_estimated_delivery_date                                          93996 non-null  float32
#  5   order_item_id                                                          93996 non-null  int32
#  6   product_id                                                             93996 non-null  int32
#  7   seller_id                                                              93996 non-null  int32
#  8   shipping_limit_date                                                    93996 non-null  float32
#  9   price                                                                  93996 non-null  float32
#  10  freight_value                                                          93996 non-null  float32
#  11  payment_sequential                                                     93996 non-null  int32
#  12  payment_installments                                                   93996 non-null  int32
#  13  payment_value                                                          93996 non-null  float32
#  14  review_score                                                           93996 non-null  float32
#  15  review_creation_date                                                   93996 non-null  float32
#  16  review_answer_timestamp                                                93996 non-null  float32
#  17  product_name_lenght                                                    93996 non-null  float32
#  18  product_description_lenght                                             93996 non-null  float32
#  19  product_photos_qty                                                     93996 non-null  float32
#  20  product_weight_g                                                       93996 non-null  float32
#  21  customer_geolocation_lat                                               93996 non-null  float32
#  22  customer_geolocation_lng                                               93996 non-null  float32
#  23  order_volume                                                           93996 non-null  float32
#  24  payment_type_boleto                                                    93996 non-null  uint8
#  25  payment_type_credit_card                                               93996 non-null  uint8
#  26  payment_type_debit_card                                                93996 non-null  uint8
#  27  payment_type_voucher                                                   93996 non-null  uint8
#  28  product_category_name_english_agro_industry_and_commerce               93996 non-null  uint8
#  29  product_category_name_english_air_conditioning                         93996 non-null  uint8
#  30  product_category_name_english_art                                      93996 non-null  uint8
#  31  product_category_name_english_arts_and_craftmanship                    93996 non-null  uint8
#  32  product_category_name_english_audio                                    93996 non-null  uint8
#  33  product_category_name_english_auto                                     93996 non-null  uint8
#  34  product_category_name_english_baby                                     93996 non-null  uint8
#  35  product_category_name_english_bed_bath_table                           93996 non-null  uint8
#  36  product_category_name_english_books_general_interest                   93996 non-null  uint8
#  37  product_category_name_english_books_imported                           93996 non-null  uint8
#  38  product_category_name_english_books_technical                          93996 non-null  uint8
#  39  product_category_name_english_cds_dvds_musicals                        93996 non-null  uint8
#  40  product_category_name_english_christmas_supplies                       93996 non-null  uint8
#  41  product_category_name_english_cine_photo                               93996 non-null  uint8
#  42  product_category_name_english_computers                                93996 non-null  uint8
#  43  product_category_name_english_computers_accessories                    93996 non-null  uint8
#  44  product_category_name_english_consoles_games                           93996 non-null  uint8
#  45  product_category_name_english_construction_tools_construction          93996 non-null  uint8
#  46  product_category_name_english_construction_tools_lights                93996 non-null  uint8
#  47  product_category_name_english_construction_tools_safety                93996 non-null  uint8
#  48  product_category_name_english_cool_stuff                               93996 non-null  uint8
#  49  product_category_name_english_costruction_tools_garden                 93996 non-null  uint8
#  50  product_category_name_english_costruction_tools_tools                  93996 non-null  uint8
#  51  product_category_name_english_diapers_and_hygiene                      93996 non-null  uint8
#  52  product_category_name_english_drinks                                   93996 non-null  uint8
#  53  product_category_name_english_dvds_blu_ray                             93996 non-null  uint8
#  54  product_category_name_english_electronics                              93996 non-null  uint8
#  55  product_category_name_english_fashio_female_clothing                   93996 non-null  uint8
#  56  product_category_name_english_fashion_bags_accessories                 93996 non-null  uint8
#  57  product_category_name_english_fashion_childrens_clothes                93996 non-null  uint8
#  58  product_category_name_english_fashion_male_clothing                    93996 non-null  uint8
#  59  product_category_name_english_fashion_shoes                            93996 non-null  uint8
#  60  product_category_name_english_fashion_sport                            93996 non-null  uint8
#  61  product_category_name_english_fashion_underwear_beach                  93996 non-null  uint8
#  62  product_category_name_english_fixed_telephony                          93996 non-null  uint8
#  63  product_category_name_english_flowers                                  93996 non-null  uint8
#  64  product_category_name_english_food                                     93996 non-null  uint8
#  65  product_category_name_english_food_drink                               93996 non-null  uint8
#  66  product_category_name_english_furniture_bedroom                        93996 non-null  uint8
#  67  product_category_name_english_furniture_decor                          93996 non-null  uint8
#  68  product_category_name_english_furniture_living_room                    93996 non-null  uint8
#  69  product_category_name_english_furniture_mattress_and_upholstery        93996 non-null  uint8
#  70  product_category_name_english_garden_tools                             93996 non-null  uint8
#  71  product_category_name_english_health_beauty                            93996 non-null  uint8
#  72  product_category_name_english_home_appliances                          93996 non-null  uint8
#  73  product_category_name_english_home_appliances_2                        93996 non-null  uint8
#  74  product_category_name_english_home_comfort_2                           93996 non-null  uint8
#  75  product_category_name_english_home_confort                             93996 non-null  uint8
#  76  product_category_name_english_home_construction                        93996 non-null  uint8
#  77  product_category_name_english_housewares                               93996 non-null  uint8
#  78  product_category_name_english_industry_commerce_and_business           93996 non-null  uint8
#  79  product_category_name_english_kitchen_dining_laundry_garden_furniture  93996 non-null  uint8
#  80  product_category_name_english_la_cuisine                               93996 non-null  uint8
#  81  product_category_name_english_luggage_accessories                      93996 non-null  uint8
#  82  product_category_name_english_market_place                             93996 non-null  uint8
#  83  product_category_name_english_music                                    93996 non-null  uint8
#  84  product_category_name_english_musical_instruments                      93996 non-null  uint8
#  85  product_category_name_english_office_furniture                         93996 non-null  uint8
#  86  product_category_name_english_party_supplies                           93996 non-null  uint8
#  87  product_category_name_english_perfumery                                93996 non-null  uint8
#  88  product_category_name_english_pet_shop                                 93996 non-null  uint8
#  89  product_category_name_english_security_and_services                    93996 non-null  uint8
#  90  product_category_name_english_signaling_and_security                   93996 non-null  uint8
#  91  product_category_name_english_small_appliances                         93996 non-null  uint8
#  92  product_category_name_english_small_appliances_home_oven_and_coffee    93996 non-null  uint8
#  93  product_category_name_english_sports_leisure                           93996 non-null  uint8
#  94  product_category_name_english_stationery                               93996 non-null  uint8
#  95  product_category_name_english_tablets_printing_image                   93996 non-null  uint8
#  96  product_category_name_english_telephony                                93996 non-null  uint8
#  97  product_category_name_english_toys                                     93996 non-null  uint8
#  98  product_category_name_english_watches_gifts                            93996 non-null  uint8
# dtypes: float32(18), int32(6), uint8(75)
# memory usage: 15.3 MB

# %% [markdown]
# DBScan

# %%
df_temp = df_orders_translated.copy()

# %%
## downcasting loop
for column in df_temp:
    if df_temp[column].dtype == 'float64':
        df_temp[column]=pd.to_numeric(df_temp[column], downcast = 'float')
    elif df_temp[column].dtype == 'int64':
         df_temp[column]=pd.to_numeric(df_temp[column], downcast = 'int')

# %%
mm_scaler = MinMaxScaler()
df_temp_mm = mm_scaler.fit_transform(df_temp)

# %%
from numpy import where
from numpy import unique
from sklearn.cluster import DBSCAN

# Define model
dbscan_model = DBSCAN(eps=0.25, min_samples=200)

# Train the model
dbscan_model.fit(df_temp_mm)

# Assign each data point to a cluster
dbscan_res = dbscan_model.fit_predict(df_temp_mm)

# obtain all the unique clusters
dbscan_clstrs = unique(dbscan_res)

# %%
dbscan_clstrs.max()
# Out:
# 18

# %%
# Plot the DBSCAN clusters
for dbscan_clstr in dbscan_clstrs:
    # Obtain data point that belong in this cluster
    index = where(dbscan_res == dbscan_clstr)
    # plot
    plt.scatter(df_orders_translated_ns_mm[index, 0], df_orders_translated_ns_mm[index, 1])
    
# show plot
plt.show()

# %%
from numpy import where
from numpy import unique
from sklearn.cluster import DBSCAN

# Define model
dbscan_model = DBSCAN(eps=0.25, min_samples=9)

# Train the model
dbscan_model.fit(df_orders_translated_ns_mm)

# Assign each data point to a cluster
dbscan_res = dbscan_model.fit_predict(df_orders_translated_ns_mm)

# obtain all the unique clusters
dbscan_clstrs = unique(dbscan_res)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_56892/77433758.py in <module>
#       7
#       8 # Train the model
# ----> 9 dbscan_model.fit(df_orders_translated_ns_mm)
#      10
#      11 # Assign each data point to a cluster
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     373         neighbors_model.fit(X)
#     374         # This has worst case O(n^2) memory complexity
# --> 375         neighborhoods = neighbors_model.radius_neighbors(X, return_distance=False)
#     376
#     377         if sample_weight is None:
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\neighbors\_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#    1079                 results = neigh_dist, neigh_ind
#    1080             else:
# -> 1081                 neigh_ind_list = sum(chunked_results, [])
#    1082                 results = _to_object_array(neigh_ind_list)
#    1083
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1710         else:
#    1711             X_chunk = X[sl]
# -> 1712         D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1713         if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1714             metric, None
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1882         func = partial(distance.cdist, metric=metric, **kwds)
#    1883
# -> 1884     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1885
#    1886
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1423
#    1424     if effective_n_jobs(n_jobs) == 1:
# -> 1425         return func(X, Y, **kwds)
#    1426
#    1427     # enforce a threading backend to prevent data communication overhead
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     325             )
#     326
# --> 327     return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     328
#     329
#
# ~\anaconda3\envs\deeplearning\lib\site-packages\sklearn\metrics\pairwise.py in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     366     else:
#     367         # if dtype is already float64, no need to chunk and upcast
# --> 368         distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     369         distances += XX
#     370         distances += YY
#
# MemoryError: Unable to allocate 1023. MiB for an array with shape (1427, 93996) and data type float64

# %%
# Plot the DBSCAN clusters
for dbscan_clstr in dbscan_clstrs:
    # Obtain data point that belong in this cluster
    index = where(dbscan_res == dbscan_clstr)
    # plot
    plot.scatter(df_orders_translated_ns_mm[index, 0], df_orders_translated_ns_mm[index, 1])
    
# show plot
plot.show()

# %%
mm_scaler = MinMaxScaler()
df_orders_translated_ns_mm = mm_scaler.fit_transform(df_orders_translated_ns)

# Look over a range of K values
k_range = np.arange(1, 11)

# Instantiate an empty list of inertias
inertia_list = []

# Iterate over ks
for k in k_range:
    
    # Instantiate
    k_means_model = KMeans(n_clusters=k) # k=2, 2,... 11

    # Fit
    k_means_model.fit(df_orders_translated_ns_mm)
    
    # Get inertia and add to list
    inertia_list.append(k_means_model.inertia_)
    print(f'K-means for k =  {k} finished.', end='\r')
# Out:
# K-means for k =  10 finished.

# %%
# Visualize different k values
plt.figure()
plt.plot(k_range, inertia_list, marker="o")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Inertia Vs Different K-values')
plt.xticks(k_range)
plt.show();
